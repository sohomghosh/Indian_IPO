# %%
import pandas as pd
y = 'Success_Open'
deberta_probab = pd.read_csv("/content/drive/MyDrive/datasets/Indian_IPO_Prediction/deberta_probabilities/deberta_probabilities_mainboard_success_open_23Oct.csv")

# %%
import numpy as np
import pickle

# %%
#text_features = ['full_text_content', 'full_text_context_with_news', 'answer_of_question_1',	'answer_of_question_2',	'answer_of_question_3','answer_of_question_4','answer_of_question_5','answer_of_question_6','answer_of_question_7','answer_of_question_8','answer_of_question_9','answer_of_question_10','answer_of_question_11','answer_of_question_12','answer_of_question_13','answer_of_question_14','answer_of_question_15','answer_of_question_16','answer_of_question_17','answer_of_question_18','answer_of_question_19','answer_of_question_20','answer_of_question_21','answer_of_question_22','answer_of_question_23','answer_of_question_24','answer_of_question_25']

# %%
# !pip install -q h2o
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.6/265.6 MB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for h2o (setup.py) ... done

# %%
import h2o
from h2o.automl import H2OAutoML

# Start the H2O cluster (locally)
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.24" 2024-07-16; OpenJDK Runtime Environment (build 11.0.24+8-post-Ubuntu-1ubuntu322.04); OpenJDK 64-Bit Server VM (build 11.0.24+8-post-Ubuntu-1ubuntu322.04, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.10/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmp6reyx7al
#   JVM stdout: /tmp/tmp6reyx7al/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmp6reyx7al/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------------------------------------------------------------------
# H2O_cluster_uptime:         07 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.5
# H2O_cluster_version_age:    1 month and 25 days
# H2O_cluster_name:           H2O_from_python_unknownUser_2iaubg
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.170 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null, "colab_language_server": "/usr/colab/bin/language_service"}
# H2O_internal_security:      False
# Python_version:             3.10.12 final
# --------------------------  -----------------------------------------------------------------------------------------

# %%
numeric_features = ['Final_Issue_Price',
 'Issue Size (Rs Cr.)',
 'Lot Size',
 'GDP per capita growth (annual %)',
 'GDP growth (annual %)',
 'GDP (current US$)',
 'Unemployment, total (% of total labor force) (modeled ILO estimate)',
 'Stocks traded, total value (% of GDP)',
 'Personal remittances, received (% of GDP)',
 'Net trade in goods and services (BoP, current US$)',
 'GNI per capita growth (annual %)',
 'Inflation, consumer prices (annual %)',
 'GNI (current US$)',
 'Foreign direct investment, net inflows (BoP, current US$)',
 'Foreign direct investment, net (BoP, current US$)',
 'Price_nifty50_daily',
 'Open_nifty50_daily',
 'High_nifty50_daily',
 'Low_nifty50_daily',
 'Volume_nifty50_daily',
 'Chg%_nifty50_daily',
 'Price_nifty50_weekly',
 'Open_nifty50_weekly',
 'High_nifty50_weekly',
 'Low_nifty50_weekly',
 'Volume_nifty50_weekly',
 'Chg%_nifty50_weekly',
 'Price_nifty50_monthly',
 'Open_nifty50_monthly',
 'High_nifty50_monthly',
 'Low_nifty50_monthly',
 'Volume_nifty50_monthly',
 'Chg%_nifty50_monthly',
 'Price_vix_daily',
 'Open_vix_daily',
 'High_vix_daily',
 'Low_vix_daily',
 'Chg%_vix_daily',
 'Price_vix_weekly',
 'Open_vix_weekly',
 'High_vix_weekly',
 'Low_vix_weekly',
 'Chg%_vix_weekly',
 'Price_vix_monthly',
 'Open_vix_monthly',
 'High_vix_monthly',
 'Low_vix_monthly',
 'Chg%_vix_monthly',
 'previous_quarter_success_open',
 'previous_quarter_success_close',
 'previous_quarter_success_high',
 'dynamic_last_90Day_success_open',
 'dynamic_last_90Day_success_close',
 'dynamic_last_90Day_success_high',
 'day_1_qib',
 'day_1_nii',
 'day_1_retail',
 'day_1_total',
 'day_2_qib',
 'day_2_nii',
 'day_2_retail',
 'day_2_total',
 'day_3_qib',
 'day_3_nii',
 'day_3_retail',
 'day_3_total',
 'day_4_qib',
 'day_4_nii',
 'day_4_retail',
 'day_4_total',
 'day_5_qib',
 'day_5_nii',
 'day_5_retail',
 'day_5_total',
 'day_6_qib',
 'day_6_nii',
 'day_6_retail',
 'day_6_total',
 'Brokers_Subscribe',
 'Brokers_Neutral',
 'Brokers_Avoid',
 'Members_Subscribe',
 'Members_Neutral',
 'Members_Avoid',
 'Face Value per share',
 'Retail (Min)_Lots',
 'Retail (Min)_Shares',
 'Retail (Min)_Amount',
 'Retail (Max)_Lots',
 'Retail (Max)_Shares',
 'Retail (Max)_Amount',
 'S-HNI (Min)_Lots',
 'S-HNI (Min)_Shares',
 'S-HNI (Min)_Amount',
 'S-HNI (Max)_Lots',
 'S-HNI (Max)_Shares',
 'S-HNI (Max)_Amount',
 'B-HNI (Min)_Lots',
 'B-HNI (Min)_Shares',
 'B-HNI (Min)_Amount',
 'Share Holding Pre Issue',
 'Share Holding Post Issue',
 '0_assets',
 '0_revenue',
 '0_profit after tax',
 '0_net worth',
 '0_reserves and surplus',
 '0_total borrowing',
 '0_total income',
 '1_assets',
 '1_revenue',
 '1_profit after tax',
 '1_net worth',
 '1_reserves and surplus',
 '1_total borrowing',
 '1_total income',
 '2_assets',
 '2_revenue',
 '2_profit after tax',
 '2_net worth',
 '2_reserves and surplus',
 '2_total borrowing',
 '2_total income',
 '3_assets',
 '3_revenue',
 '3_profit after tax',
 '3_net worth',
 '3_reserves and surplus',
 '3_total borrowing',
 '3_total income',
 '4_assets',
 '4_revenue',
 '4_profit after tax',
 '4_net worth',
 '4_reserves and surplus',
 '4_total borrowing',
 '4_total income',
 '5_assets',
 '5_revenue',
 '5_profit after tax',
 '5_total income']

categorical_features = ['Sector',	'Industry',	'Total Issue Size',	'Issue Type',	'Fresh Issue',	'Offer for Sale',	'Price Band']

# %%
def clean_numbers(txt):
    num =  str(txt).replace(',','').replace(' ','')
    if len(num.split('.')) > 2:
        num = '.'.join(num.split('.')[0:2])
    if num == '':
        return np.nan
    if num == 'nan':
        return np.nan
    if num == '-':
        return np.nan
    if '%' in num:
        num = float(num.replace('%',''))/100
    elif 'Cr' in num:
        num = float(num.replace('Cr',''))*10000000
    elif 'B' in num:
        num = float(num.replace('B',''))*1000000000

    elif 'M' in num:
        num = float(num.replace('M',''))*1000000

    elif 'K' in num:
        num = float(num.replace('K',''))*1000
    else:
        num = float(num)

    return num

# %% [markdown]
# # Main Board

# %%
main = pd.read_excel("/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/ipo_mainline_final_data_v18.xlsx")
main.shape
# Out:
# (418, 217)

# %%
main = pd.concat([main,deberta_probab],axis=1)

# %%
train = main[main['Close Year'] < 2023]
test = main[main['Close Year'] == 2023]

# %% [markdown]
# ## Without News

# %%
text_features_probab = [i for i in deberta_probab.columns if 'class_1_prob' in i]

# %%
train_use_X = train[numeric_features + categorical_features + text_features_probab]
test_use_X = test[numeric_features + categorical_features + text_features_probab]
for i in numeric_features:
  if train_use_X[i].dtype != 'int64' and train_use_X[i].dtype !='float64':
    train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
    test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')

for col in  categorical_features:
  train_use_X[col] = train_use_X[col].str.replace('"', '', regex=False)  # Remove double quotes
  train_use_X[col] = train_use_X[col].str.replace('\n', ' ', regex=False)
  test_use_X[col] = test_use_X[col].str.replace('"', '', regex=False)  # Remove double quotes
  test_use_X[col] = test_use_X[col].str.replace('\n', ' ', regex=False)
# Out:
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-18-25082cdf839e>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[col] = train_use_X[col].str.replace('"', '', regex=False)  # Remove double quotes
# <ipython-input-18-25082cdf839e>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[col] = train_use_X[col].str.replace('\n', ' ', regex=False)
# <ipython-input-18-25082cdf839e>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[col] = test_use_X[col].str.replace('"', '', regex=False)  # Remove double quotes
# <ipython-input-18-25082cdf839e>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[col] = test_use_X[col].str.replace('\n', ' ', regex=False)

# %%
h2o_train = h2o.H2OFrame(train_use_X)  # Convert train DataFrame to H2OFrame
h2o_test = h2o.H2OFrame(test_use_X)  # Convert test DataFrame to H2OFrame

# Identify predictors and response
# x = train.columns
# y = "response"
# x.remove(y)

x= numeric_features + categorical_features + text_features_probab #+ text_features


h2o_train[y] = h2o.H2OFrame(train[y].to_list()).asfactor()  # Convert Pandas Series to H2OFrame before assigning
h2o_test[y] = h2o.H2OFrame(test[y].to_list()).asfactor()  # Convert Pandas Series to H2OFrame before assigning

# For binary classification, response should be a factor
# train[y] = train[y].asfactor()
# test[y] = test[y].asfactor()

# Run AutoML for 20 base models
aml = H2OAutoML(max_models=20, seed=1)
aml.train(x=x, y=y, training_frame=h2o_train)

# View the AutoML Leaderboard
lb = aml.leaderboard
lb.head(rows=lb.nrows)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 04:45:01.128: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 04:45:08.758: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ███
# 04:46:25.785: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
#
# 04:46:34.744: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 04:46:39.499: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ██
# 04:46:47.387: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 04:46:59.59: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 04:47:09.180: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ██
# 04:47:17.531: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 04:47:23.729: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 04:47:31.832: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 04:47:40.382: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ████████████████████████████████████████████
# 04:54:52.402: _train param, Dropping unused columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ██
# 04:54:56.292: _train param, Dropping unused columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ███| (done) 100%
# model_id                                                     auc    logloss     aucpr    mean_per_class_error      rmse       mse
# ------------------------------------------------------  --------  ---------  --------  ----------------------  --------  --------
# DeepLearning_grid_1_AutoML_1_20241025_44500_model_1     0.879752   0.516504  0.924361                0.23401   0.371552  0.138051
# StackedEnsemble_AllModels_1_AutoML_1_20241025_44500     0.879542   0.407216  0.921992                0.176013  0.356431  0.127043
# StackedEnsemble_BestOfFamily_1_AutoML_1_20241025_44500  0.878461   0.412559  0.916815                0.169474  0.356637  0.12719
# DeepLearning_grid_3_AutoML_1_20241025_44500_model_1     0.874486   0.641805  0.930209                0.1972    0.38898   0.151306
# XGBoost_grid_1_AutoML_1_20241025_44500_model_2          0.872637   0.420143  0.930578                0.20604   0.364699  0.133005
# DeepLearning_grid_2_AutoML_1_20241025_44500_model_1     0.870824   0.612566  0.917956                0.203861  0.382988  0.14668
# GLM_1_AutoML_1_20241025_44500                           0.868592   0.412547  0.917494                0.163301  0.357054  0.127487
# XGBoost_grid_1_AutoML_1_20241025_44500_model_1          0.861826   0.44359   0.926356                0.24442   0.376194  0.141522
# XGBoost_2_AutoML_1_20241025_44500                       0.852096   0.463061  0.915756                0.201437  0.379825  0.144267
# XGBoost_grid_1_AutoML_1_20241025_44500_model_3          0.850596   0.49868   0.916861                0.248657  0.392818  0.154306
# GBM_grid_1_AutoML_1_20241025_44500_model_1              0.805608   0.62007   0.868395                0.230854  0.461805  0.213264
# GBM_4_AutoML_1_20241025_44500                           0.776714   0.749508  0.84682                 0.251796  0.505257  0.255285
# GBM_3_AutoML_1_20241025_44500                           0.775162   0.747173  0.847738                0.195857  0.504264  0.254282
# GBM_grid_1_AutoML_1_20241025_44500_model_2              0.772093   0.741461  0.856411                0.228186  0.503581  0.253594
# GBM_2_AutoML_1_20241025_44500                           0.770925   0.762473  0.84986                 0.198159  0.507657  0.257716
# GBM_1_AutoML_1_20241025_44500                           0.770907   0.712043  0.838706                0.215352  0.498003  0.248007
# GBM_5_AutoML_1_20241025_44500                           0.765205   0.826599  0.845574                0.215108  0.523645  0.274204
# [22 rows x 7 columns]

# %%
lb = h2o.automl.get_leaderboard(aml, extra_columns = "ALL")
lb
# Out:
# model_id                                                     auc    logloss     aucpr    mean_per_class_error      rmse       mse    training_time_ms    predict_time_per_row_ms  algo
# ------------------------------------------------------  --------  ---------  --------  ----------------------  --------  --------  ------------------  -------------------------  ---------------
# DeepLearning_grid_1_AutoML_1_20241025_44500_model_1     0.879752   0.516504  0.924361                0.23401   0.371552  0.138051               22159                   0.515116  DeepLearning
# StackedEnsemble_AllModels_1_AutoML_1_20241025_44500     0.879542   0.407216  0.921992                0.176013  0.356431  0.127043                3617                   1.2026    StackedEnsemble
# StackedEnsemble_BestOfFamily_1_AutoML_1_20241025_44500  0.878461   0.412559  0.916815                0.169474  0.356637  0.12719                 3806                   0.458197  StackedEnsemble
# DeepLearning_grid_3_AutoML_1_20241025_44500_model_1     0.874486   0.641805  0.930209                0.1972    0.38898   0.151306               22042                   0.370411  DeepLearning
# XGBoost_grid_1_AutoML_1_20241025_44500_model_2          0.872637   0.420143  0.930578                0.20604   0.364699  0.133005                3956                   0.030175  XGBoost
# DeepLearning_grid_2_AutoML_1_20241025_44500_model_1     0.870824   0.612566  0.917956                0.203861  0.382988  0.14668                16864                   0.373324  DeepLearning
# GLM_1_AutoML_1_20241025_44500                           0.868592   0.412547  0.917494                0.163301  0.357054  0.127487                6717                   0.046964  GLM
# XGBoost_grid_1_AutoML_1_20241025_44500_model_1          0.861826   0.44359   0.926356                0.24442   0.376194  0.141522                 694                   0.038898  XGBoost
# XGBoost_2_AutoML_1_20241025_44500                       0.852096   0.463061  0.915756                0.201437  0.379825  0.144267                 784                   0.041576  XGBoost
# XGBoost_grid_1_AutoML_1_20241025_44500_model_3          0.850596   0.49868   0.916861                0.248657  0.392818  0.154306                 838                   0.040441  XGBoost
# [22 rows x 10 columns]

# %%
# Get the best model using the metric
m = aml.leader
print(m)
# Out:
# Model Details
# =============
# H2ODeepLearningEstimator : Deep Learning
# Model Key: DeepLearning_grid_1_AutoML_1_20241025_44500_model_1
#
#
# Status of Neuron Layers: predicting Success_Open, 2-class classification, bernoulli distribution, CrossEntropy loss, 276,902 weights/biases, 3.3 MB, 23,461 training samples, mini-batch size 1
#     layer    units    type              dropout    l1    l2    mean_rate             rate_rms               momentum    mean_weight             weight_rms            mean_bias              bias_rms
#     2024-10-25 04:50:30  2 min  8.780 sec  1084 obs/sec      48.7396   30            17595      0.0580379        0.0253569           0.984691       0.999965        0.999983           1.4856           0.00277008
#     2024-10-25 04:50:35  2 min 13.832 sec  1110 obs/sec      64.9889   40            23461      0.0255402        0.0121161           0.997035       1               1                  1.4856           0
#
# Variable Importances:
# variable                            relative_importance    scaled_importance    percentage
# ----------------------------------  ---------------------  -------------------  ---------------------
# day_2_total                         1.0                    1.0                  0.0010048066490271537
# Face Value per share                0.5701061487197876     0.5701061487197876   0.0005728464488849058
# Chg%_nifty50_daily                  0.5607739090919495     0.5607739090919495   0.0005634693524565394
# Sector.Producer Manufacturing       0.540582001209259      0.540582001209259    0.0005431803891594683
# answer_of_question_18_class_1_prob  0.5246687531471252     0.5246687531471252   0.0005271906516990177
# answer_of_question_7_class_1_prob   0.5228493213653564     0.5228493213653564   0.0005253624745472452
# answer_of_question_11_class_1_prob  0.5195903182029724     0.5195903182029724   0.0005220878065004812
# dynamic_last_90Day_success_open     0.5147719383239746     0.5147719383239746   0.0005172462663605255
# answer_of_question_4_class_1_prob   0.5119588971138        0.5119588971138      0.0005144197038485548
# day_2_nii                           0.5054358243942261     0.5054358243942261   0.0005078652770078391
# ---                                 ---                    ---                  ---
# day_6_retail.missing(NA)            0.0                    0.0                  0.0
# 0_net worth.missing(NA)             0.0                    0.0                  0.0
# 3_net worth.missing(NA)             0.0                    0.0                  0.0
# day_6_total.missing(NA)             0.0                    0.0                  0.0
# 1_net worth.missing(NA)             0.0                    0.0                  0.0
# day_6_qib.missing(NA)               0.0                    0.0                  0.0
# Issue Type.missing(NA)              0.0                    0.0                  0.0
# 2_net worth.missing(NA)             0.0                    0.0                  0.0
# 4_net worth.missing(NA)             0.0                    0.0                  0.0
# day_6_nii.missing(NA)               0.0                    0.0                  0.0
# [2766 rows x 4 columns]

# %%
# this is equivalent to
m = aml.get_best_model()
print(m)
# Out:
# Model Details
# =============
# H2ODeepLearningEstimator : Deep Learning
# Model Key: DeepLearning_grid_1_AutoML_1_20241025_44500_model_1
#
#
# Status of Neuron Layers: predicting Success_Open, 2-class classification, bernoulli distribution, CrossEntropy loss, 276,902 weights/biases, 3.3 MB, 23,461 training samples, mini-batch size 1
#     layer    units    type              dropout    l1    l2    mean_rate             rate_rms               momentum    mean_weight             weight_rms            mean_bias              bias_rms
# --  -------  -------  ----------------  ---------  ----  ----  --------------------  ---------------------  ----------  ----------------------  --------------------  ---------------------  --------------------
#     1        2766     Input             15.0
#     2        100      RectifierDropout  10.0       0.0   0.0   0.0883762516666438    0.22183305025100708    0.0         0.00013025416600913697  0.027074255049228668  0.4695372141505516     0.04010465741157532
#     3        2        Softmax                      0.0   0.0   0.004543625381775201  0.0020083338022232056  0.0         -0.0178773480351083     0.5257697105407715    0.0006245438627519983  0.022347889840602875
#
# ModelMetricsBinomial: deeplearning
# ** Reported on train data. **
#
# MSE: 0.0006523036981821293
# RMSE: 0.02554023684663338
# LogLoss: 0.012116084031053725
# Mean Per-Class Error: 0.0
# AUC: 1.0
# AUCPR: 1.0
# Gini: 1.0
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.7630352892036572
#        0    1    Error    Rate
# -----  ---  ---  -------  -----------
# 0      118  0    0        (0.0/118.0)
# 1      0    243  0        (0.0/243.0)
# Total  118  243  0        (0.0/361.0)
#
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0
# answer_of_question_11_class_1_prob  0.5195903182029724     0.5195903182029724   0.0005220878065004812
# dynamic_last_90Day_success_open     0.5147719383239746     0.5147719383239746   0.0005172462663605255
# answer_of_question_4_class_1_prob   0.5119588971138        0.5119588971138      0.0005144197038485548
# day_2_nii                           0.5054358243942261     0.5054358243942261   0.0005078652770078391
# ---                                 ---                    ---                  ---
# day_6_retail.missing(NA)            0.0                    0.0                  0.0
# 0_net worth.missing(NA)             0.0                    0.0                  0.0
# 3_net worth.missing(NA)             0.0                    0.0                  0.0
# day_6_total.missing(NA)             0.0                    0.0                  0.0
# 1_net worth.missing(NA)             0.0                    0.0                  0.0
# day_6_qib.missing(NA)               0.0                    0.0                  0.0
# Issue Type.missing(NA)              0.0                    0.0                  0.0
# 2_net worth.missing(NA)             0.0                    0.0                  0.0
# 4_net worth.missing(NA)             0.0                    0.0                  0.0
# day_6_nii.missing(NA)               0.0                    0.0                  0.0
# [2766 rows x 4 columns]

# %%
# Get the best model using a non-default metric
m = aml.get_best_model(criterion="logloss")
print(m)
# Out:
# Model Details
# =============
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_AllModels_1_AutoML_1_20241025_44500
#
#
# Model Summary for Stacked Ensemble:
# key                                        value
# -----------------------------------------  ----------------
# Stacking strategy                          cross_validation
# Number of base models (used / total)       7/20
# # GBM base models (used / total)           0/7
# # XGBoost base models (used / total)       2/6
# # DeepLearning base models (used / total)  3/4
# # GLM base models (used / total)           0/1
# # DRF base models (used / total)           2/2
# Metalearner algorithm                      GLM
# Metalearner fold assignment scheme         Random
# Metalearner nfolds                         5
# Metalearner fold_column
# Custom metalearner hyperparameters         None
#
# ModelMetricsBinomialGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.009488360925776106
# RMSE: 0.09740821795811741
# LogLoss: 0.07331280049197987
# AUC: 1.0
# AUCPR: 1.0
# Gini: 1.0
# Null degrees of freedom: 360
# Residual degrees of freedom: 353
# Null deviance: 456.2604530789376
# Residual deviance: 52.931841955209464
# AIC: 68.93184195520946
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.6954134878244481
#        0    1    Error    Rate
# -----  ---  ---  -------  -----------
# 0      118  0    0        (0.0/118.0)
# 1      0    243  0        (0.0/243.0)
# Total  118  243  0        (0.0/361.0)
#
# Maximum Metrics: Maximum metrics at their respective thresholds
# metric                       threshold    value     idx
# ---------------------------  -----------  --------  -----
# max f1                       0.695413     1         242
# max f2                       0.695413     1         242
# max f0point5                 0.695413     1         242
# max accuracy                 0.695413     1         242
# max precision                0.999534     1         0
# max recall                   0.695413     1         242
# max specificity              0.999534     1         0
# max absolute_mcc             0.695413     1         242
# max min_per_class_accuracy   0.695413     1         242
# max mean_per_class_accuracy  0.695413     1         242
# max tns                      0.999534     118       0
# max fns                      0.999534     242       0
# max fps                      0.00359674   118       360
# max tps                      0.695413     243       242
# max tnr                      0.999534     1         0
# max fnr                      0.999534     0.995885  0
# max fpr                      0.00359674   1         360
# max tpr                      0.695413     1         242
#
# Gains/Lift Table: Avg response rate: 67.31 %, avg score: 67.41 %
# group    cumulative_data_fraction    lower_threshold    lift     cumulative_lift    response_rate    score      cumulative_response_rate    cumulative_score    capture_rate    cumulative_capture_rate    gain     cumulative_gain    kolmogorov_smirnov
# -------  --------------------------  -----------------  -------  -----------------  ---------------  ---------  --------------------------  ------------------  --------------  -------------------------  -------  -----------------  --------------------
# 1        0.0110803                   0.999244           1.4856   1.4856             1                0.999439   1                           0.999439            0.0164609       0.0164609                  48.5597  48.5597            0.0164609
# 2        0.0221607                   0.999091           1.4856   1.4856             1                0.999181   1                           0.99931             0.0164609       0.0329218                  48.5597  48.5597            0.0329218
# 3        0.0304709                   0.998606           1.4856   1.4856             1                0.998829   1                           0.999179            0.0123457       0.0452675                  48.5597  48.5597            0.0452675
# 4        0.0415512                   0.998278           1.4856   1.4856             1                0.998477   1                           0.998992            0.0164609       0.0617284                  48.5597  48.5597            0.0617284
# 5        0.0526316                   0.997974           1.4856   1.4856             1                0.998086   1                           0.998801            0.0164609       0.0781893                  48.5597  48.5597            0.0781893
# 6        0.102493                    0.99573            1.4856   1.4856             1                0.997117   1                           0.997982            0.0740741       0.152263                   48.5597  48.5597            0.152263
# 7        0.152355                    0.993315           1.4856   1.4856             1                0.994385   1                           0.996805            0.0740741       0.226337                   48.5597  48.5597            0.226337
# rmse                  0.35654116  0.031554557  0.3767804     0.35269618    0.36342883    0.3851487     0.30465168
# specificity           0.64041406  0.22005576   0.52380955    0.65217394    0.8666667     0.33333334    0.82608694
# [24 rows x 8 columns]

# %%
# Get AutoML event log
log = aml.event_log
print(log)
# Out:
# timestamp     level    stage       message                                                                                                                                                         name    value
# 04:45:00.921  INFO     Workflow    Project: AutoML_1_20241025_44500
# 04:45:00.924  INFO     Validation  5-fold cross-validation will be used.
# 04:45:00.928  INFO     Validation  Setting stopping tolerance adaptively based on the training frame: 0.05
# 04:45:00.928  INFO     Validation  Build control seed: 1
# 04:45:00.929  INFO     DataImport  training frame: Frame key: AutoML_1_20241025_44500_training_py_1_sid_be74    cols: 175    rows: 361  chunks: 1    size: 462625  checksum: -2807537760740454309
# 04:45:00.929  INFO     DataImport  validation frame: NULL
# 04:45:00.930  INFO     DataImport  leaderboard frame: NULL
# 04:45:00.930  INFO     DataImport  blending frame: NULL
# 04:45:00.930  INFO     DataImport  response column: Success_Open
# 04:45:00.930  INFO     DataImport  fold column: null
# [150 rows x 6 columns]

# %%
# Get training timing info
info = aml.training_info
print(info)
# Out:
# {'creation_epoch': '1729831501', 'start_epoch': '1729831501', 'start_XGBoost_def_2': '1729831501', 'start_GLM_def_1': '1729831509', 'start_GBM_def_5': '1729831586', 'start_XGBoost_def_1': '1729831595', 'start_DRF_def_1': '1729831599', 'start_GBM_def_2': '1729831607', 'start_GBM_def_3': '1729831619', 'start_GBM_def_4': '1729831629', 'start_XGBoost_def_3': '1729831638', 'start_DRF_XRT': '1729831644', 'start_GBM_def_1': '1729831652', 'start_DeepLearning_def_1': '1729831660', 'start_XGBoost_grid_1': '1729831669', 'start_GBM_grid_1': '1729831690', 'start_DeepLearning_grid_1': '1729831702', 'start_DeepLearning_grid_2': '1729831836', 'start_DeepLearning_grid_3': '1729831967', 'start_StackedEnsemble_best_of_family_xglm': '1729832092', 'start_StackedEnsemble_all_xglm': '1729832096', 'stop_epoch': '1729832100', 'duration_secs': '599'}

# %%
aml.leader.model_id
# Out:
# 'DeepLearning_grid_1_AutoML_1_20241025_44500_model_1'

# %%
aml.leader.confusion_matrix()
# Out:
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.7630352892036572
#        0    1    Error    Rate
# -----  ---  ---  -------  -----------
# 0      118  0    0        (0.0/118.0)
# 1      0    243  0        (0.0/243.0)
# Total  118  243  0        (0.0/361.0)

# %%
cols = ['3_assets',  '3_revenue', 'Share Holding Post Issue', 'Share Holding Pre Issue', 'S-HNI (Max)_Shares',  'B-HNI (Min)_Shares', 'S-HNI (Min)_Amount', 'B-HNI (Min)_Amount', 'S-HNI (Min)_Shares', 'S-HNI (Max)_Amount', 'B-HNI (Min)_Lots', 'S-HNI (Max)_Lots', 'S-HNI (Min)_Lots', '0_net worth',  '3_net worth', '1_net worth', '2_net worth']
for col in cols:
  h2o_test[col] = h2o_test[col].ascharacter().asfactor()

# %%
preds_leader = aml.leader.predict(h2o_test)
preds_leader
# Out:
# deeplearning prediction progress: |██████████████████████████████████████████████| (done) 100%
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Price Band' has levels not trained on: ["102 to 108 per share", "1026 to 1080 per share", "113 to 119 per share", "119 to 126 per share", "133 to 140 per share", "135 to 142 per share", "151 to 166 per share", "156 to 164 per share", "160 to 169 per share", "187 to 197 per share", ...30 not listed..., "617 to 648 per share", "627 to 660 per share", "638 to 672 per share", "695 to 735 per share", "705 to 741 per share", "750 to 790 per share", "808 to 850 per share", "93 to 98 per share", "95 to 100 per share", "983 to 1035 per share"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Offer for Sale' has levels not trained on: ["10,449,816 shares of 1 (aggregating up to 171.38 Cr)", "10,759,493 shares of 10 (aggregating up to 850.00 Cr)", "11,756,910 shares of 2 (aggregating up to 198.69 Cr)", "12,050,000 shares of 10 (aggregating up to 72.30 Cr)", "12,183,099 shares of 1 (aggregating up to 173.00 Cr)", "12,500,000 shares of 2 (aggregating up to 545.00 Cr)", "13,500,000 shares of 1 (aggregating up to 170.10 Cr)", "14,213,198 shares of 1 (aggregating up to 280.00 Cr)", "17,236,808 shares of 5 (aggregating up to 1,784.01 Cr)", "17,500,000 shares of 2 (aggregating up to 189.00 Cr)", ...25 not listed..., "7,159,920 shares of 2 (aggregating up to 608.59 Cr)", "8,000,000 shares of 10 (aggregating up to 240.00 Cr)", "8,113,590 shares of 5 (aggregating up to 400.00 Cr)", "8,294,118 shares of 10 (aggregating up to 175.00 Cr)", "8,500,000 shares of 2 (aggregating up to 425.00 Cr)", "9,000,000 shares of 10 (aggregating up to 256.50 Cr)", "9,428,178 shares of 10 (aggregating up to 415.78 Cr)", "9,541,985 shares of 2 (aggregating up to 500.00 Cr)", "9,901,315 shares of 5 (aggregating up to 301.00 Cr)", "[.] shares of 10 (aggregating up to 425.00 Cr)"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '4_profit after tax' has levels not trained on: ["19.24", "21.07", "65.77"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '3_assets' has levels not trained on: ["1077.86", "1097.7", "1146.51", "123.74", "12338.65", "19117.54", "213.98", "2462.64", "256.05", "2633.62", ...11 not listed..., "5746.44", "5999.13", "6210.92", "638.72", "687.2", "692.76", "792", "876.38", "9450.66", "948.25"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '3_revenue' has levels not trained on: ["10311.01", "1059.58", "107.71", "1178.62", "125.03", "1567.77", "1585.88", "1768.42", "2031.3", "2069.58", ...11 not listed..., "402.59", "408.79", "412.03", "472.1", "543.28", "5633.64", "590.81", "608.99", "697.57", "740.36"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Share Holding Post Issue' has levels not trained on: ["0.3019", "0.3534", "0.4091", "0.416", "0.4408", "0.4817", "0.5124", "0.5366", "0.5539", "0.5547", ...21 not listed..., "0.7494", "0.7495", "0.7497", "0.7545", "0.765", "0.7859", "0.792", "0.8561", "64.46", "78.06"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Fresh Issue' has levels not trained on: ["1,700,680 shares (aggregating up to 75.00 Cr)", "1,739,131 shares (aggregating up to 180.00 Cr)", "10,000,000 shares (aggregating up to 100.00 Cr)", "10,200,000 shares (aggregating up to 66.30 Cr)", "10,800,000 shares (aggregating up to 545.40 Cr)", "10,890,000 shares (aggregating up to 152.46 Cr)", "11,111,111 shares (aggregating up to 400.00 Cr)", "11,268,580 shares (aggregating up to 365.00 Cr)", "12,280,701 shares (aggregating up to 350.00 Cr)", "13,200,158 shares (aggregating up to 71.28 Cr)", ...27 not listed..., "6,930,806 shares (aggregating up to 146.24 Cr)", "65,116,667 shares (aggregating up to 390.70 Cr
]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '3_net worth' has levels not trained on: ["-1765.14", "100.96", "114.09", "116.89", "117.6", "1352.06", "1390.47", "144.78", "1466.88", "192.33", ...10 not listed..., "375.76", "3934.64", "47.54", "487.83", "55.55", "622.23", "645.16", "723.55", "834.73", "937.27"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '1_net worth' has levels not trained on: ["-206.87", "-702.63", "100.93", "1033.38", "1103.22", "1240.53", "1336.58", "1355.68", "1368.35", "137.4", ...23 not listed..., "65.97", "665.73", "681.49", "71.39", "71.46", "75.2", "760.21", "92.47", "944.72", "988.31"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '2_net worth' has levels not trained on: ["-352.22", "-871.43", "100.49", "1026.78", "106.05", "107.25", "1076.13", "115.45", "1153.52", "1237.05", ...23 not listed..., "5268.11", "560.71", "631.91", "70.03", "705.62", "714", "72.46", "787.62", "86.22", "889.89"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '4_net worth' has levels not trained on: ["182.96", "363.65", "74.74"]
#   warnings.warn(w)
#   predict           p0         p1
# ---------  -----------  ---------
#         1  0.000682523  0.999317
#         1  0.00675887   0.993241
#         0  0.934502     0.0654978
#         0  0.989396     0.0106037
#         0  0.72202      0.27798
#         1  0.0731256    0.926874
#         1  5.58784e-06  0.999994
#         1  0.000460663  0.999539
#         1  7.08685e-06  0.999993
#         1  5.21651e-12  1
# [57 rows x 3 columns]

# %%
best_model = aml.get_best_model()
model_path = h2o.save_model(model=best_model, path="/content/drive/MyDrive/datasets/Indian_IPO_Prediction/mainboard_h2o_best_stacked_model_" + y + "_ALL_features_with_deberta_predprobab/", force=True)
print(model_path)
# Out:
# /content/drive/MyDrive/datasets/Indian_IPO_Prediction/mainboard_h2o_best_stacked_model_Success_Open_ALL_features_with_deberta_predprobab/DeepLearning_grid_1_AutoML_1_20241025_44500_model_1

# %%
performance = best_model.model_performance(test_data=h2o_test)
print("AUC:", performance.auc())
print("Log Loss:", performance.logloss())
print("Mean Per Class Error:", performance.mean_per_class_error())
print("Precision Per Class:", performance.precision())
print("Recall Per Class:", performance.recall())
print("F1 Per Class:", performance.F1())
print("Accuracy Per Class:", performance.accuracy())
# Out:
# AUC: 0.9664031620553359
# Log Loss: 0.21617204399246367
# Mean Per Class Error: [[0.3799624750668523, 0.06719367588932812]]
# Precision Per Class: [[1.0, 1.0]]
# Recall Per Class: [[0.0654977568821818, 1.0]]
# F1 Per Class: [[0.3799624750668523, 0.967032967032967]]
# Accuracy Per Class: [[0.3799624750668523, 0.9473684210526315]]

# %%
for model_id in lb['model_id'].as_data_frame()['model_id']:
    model = h2o.get_model(model_id)
    performance = model.model_performance(test_data=h2o_test)
    print(f"Performance for model {model_id}:")
    print(f"AUC: {performance.auc()}")
    print(f"Log Loss: {performance.logloss()}")
    print(f"Mean Per Class Error: {performance.mean_per_class_error()}")
    print("Precision Per Class:", performance.precision())
    print("Recall Per Class:", performance.recall())
    print("F1 Per Class:", performance.F1())
    print("Accuracy Per Class:", performance.accuracy())
    print(f"RMSE: {performance.rmse()}")
    print(f"MSE: {performance.mse()}")
    print("\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/h2o/frame.py:1981: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# Performance for model DeepLearning_grid_1_AutoML_1_20241025_44500_model_1:
# AUC: 0.9664031620553359
# Log Loss: 0.21617204399246367
# Mean Per Class Error: [[0.3799624750668523, 0.06719367588932812]]
# Precision Per Class: [[1.0, 1.0]]
# Recall Per Class: [[0.0654977568821818, 1.0]]
# F1 Per Class: [[0.3799624750668523, 0.967032967032967]]
# Accuracy Per Class: [[0.3799624750668523, 0.9473684210526315]]
# RMSE: 0.2445450387719627
# MSE: 0.05980227598798075
#
#
# Performance for model StackedEnsemble_AllModels_1_AutoML_1_20241025_44500:
# AUC: 0.9624505928853755
# Log Loss: 0.19571475042390318
# Mean Per Class Error: [[0.7862362150831644, 0.08893280632411071]]
# Precision Per Class: [[0.9995094077000886, 1.0]]
# Recall Per Class: [[0.4076376715414574, 1.0]]
# F1 Per Class: [[0.4076376715414574, 0.9583333333333334]]
# Accuracy Per Class: [[0.577223357928549, 0.9298245614035088]]
# RMSE: 0.24207833014975635
# MSE: 0.05860191792809443
#
#
# Performance for model StackedEnsemble_BestOfFamily_1_AutoML_1_20241025_44500:
# AUC: 0.9723320158102766
# Log Loss: 0.18897261015675906
# Mean Per Class Error: [[0.6426654228911929, 0.07806324110671936]]
# Precision Per Class: [[0.9995314165511022, 1.0]]
# Recall Per Class: [[0.4457578328953414, 1.0]]
# F1 Per Class: [[0.4457578328953414, 0.968421052631579]]
# Accuracy Per Class: [[0.4457578328953414, 0.9473684210526315]]
# RMSE: 0.23397853336671903
# MSE: 0.05474595407644085
#
#
# Performance for model DeepLearning_grid_3_AutoML_1_20241025_44500_model_1:
# AUC: 0.9347826086956522
# Log Loss: 0.5035950606498697
# Mean Per Class Error: [[0.9818587843312502, 0.07806324110671936]]
# Precision Per Class: [[1.0, 1.0]]
# Recall Per Class: [[0.0038379649392456423, 1.0]]
# F1 Per Class: [[0.9818587843312502, 0.9555555555555557]]
# Accuracy Per Class: [[0.9818587843312502, 0.9298245614035088]]
# RMSE: 0.31041475402100666
# MSE: 0.09635731951392207
#
#
# Performance for model XGBoost_grid_1_AutoML_1_20241025_44500_model_2:
# AUC: 0.9545454545454546
# Log Loss: 0.24020437492941046
# Mean Per Class Error: [[0.8330516815185547, 0.09782608695652173]]
# Precision Per Class: [[0.9875392913818359, 1.0]]
# Recall Per Class: [[0.13610006868839264, 1.0]]
# F1 Per Class: [[0.303686261177063, 0.9574468085106383]]
# Accuracy Per Class: [[0.303686261177063, 0.9298245614035088]]
# RMSE: 0.2680172744813646
# MSE: 0.07183325942041913
#
#
# Performance for model DeepLearning_grid_2_AutoML_1_20241025_44500_model_1:
# AUC: 0.9565217391304348
# Log Loss: 0.2783788684752394
# Mean Per Class Error: [[0.9843304370683398, 0.08893280632411071]]
# Precision Per Class: [[1.0, 1.0]]
# Recall Per Class: [[0.3249165915011057, 1.0]]
# F1 Per Class: [[0.7175415959279892, 0.9565217391304348]]
# Accuracy Per Class: [[0.7175415959279892, 0.9298245614035088]]
# RMSE: 0.24341018293140226
# MSE: 0.05924851715469872
#
#
# Performance for model GLM_1_AutoML_1_20241025_44500:
# AUC: 0.9782608695652173
# Log Loss: 0.23257942167690215
# Mean Per Class Error: [[0.8421225824397782, 0.05434782608695654]]
# Precision Per Class: [[0.998606474497414, 1.0]]
# Recall Per Class: [[0.4806376810050404, 1.0]]
# F1 Per Class: [[0.4806376810050404, 0.968421052631579]]
# Accuracy Per Class: [[0.4806376810050404, 0.9473684210526315]]
# RMSE: 0.24893064495988898
# MSE: 0.0619664660001463
#
#
# Performance for model XGBoost_grid_1_AutoML_1_20241025_44500_model_1:
# AUC: 0.9090909090909091
# Log Loss: 0.263496064983425
# Mean Per Class Error: [[0.5156275033950806, 0.15810276679841895]]
# Precision Per Class: [[0.990760087966919, 1.0]]
# Recall Per Class: [[0.26722782850265503, 1.0]]
# F1 Per Class: [[0.3709908723831177, 0.9473684210526316]]
# Accuracy Per Class: [[0.5156275033950806, 0.9122807017543859]]
# RMSE: 0.28026522795065273
# MSE: 0.07854859799823133
#
#
# Performance for model XGBoost_2_AutoML_1_20241025_44500:
# AUC: 0.9090909090909091
# Log Loss: 0.30460365674368983
# Mean Per Class Error: [[0.9398927688598633, 0.15217391304347827]]
# Precision Per Class: [[0.9958245754241943, 1.0]]
# Recall Per Class: [[0.07700622081756592, 1.0]]
# F1 Per Class: [[0.4411937892436981, 0.9361702127659574]]
# Accuracy Per Class: [[0.4411937892436981, 0.8947368421052632]]
# RMSE: 0.3074393640584144
# MSE: 0.09451896257264226
#
#
# Performance for model XGBoost_grid_1_AutoML_1_20241025_44500_model_3:
# AUC: 0.9169960474308301
# Log Loss: 0.2853158595171742
# Mean Per Class Error: [[0.7045956254005432, 0.11264822134387353]]
# Precision Per Class: [[0.9976363182067871, 1.0]]
# Recall Per Class: [[0.09713337570428848, 1.0]]
# F1 Per Class: [[0.7045956254005432, 0.9565217391304348]]
# Accuracy Per Class: [[0.7045956254005432, 0.9298245614035088]]
# RMSE: 0.2906978108145257
# MSE: 0.08450521721235778
#
#
# Performance for model XGBoost_1_AutoML_1_20241025_44500:
# AUC: 0.9545454545454546
# Log Loss: 0.24207327873188966
# Mean Per Class Error: [[0.7717335820198059, 0.11067193675889331]]
# Precision Per Class: [[0.9857010841369629, 1.0]]
# Recall Per Class: [[0.2778070271015167, 1.0]]
# F1 Per Class: [[0.2778070271015167, 0.968421052631579]]
# Accuracy Per Class: [[0.2778070271015167, 0.9473684210526315]]
# RMSE: 0.2670817923167298
# MSE: 0.07133268378711678
#
#
# Performance for model XGBoost_3_AutoML_1_20241025_44500:
# AUC: 0.9486166007905138
# Log Loss: 0.2441166824186153
# Mean Per Class Error: [[0.7173243165016174, 0.09980237154150196]]
# Precision Per Class: [[0.9951446652412415, 1.0]]
# Recall Per Class: [[0.08113838732242584, 1.0]]
# F1 Per Class: [[0.5847060680389404, 0.9462365591397849]]
# Accuracy Per Class: [[0.5847060680389404, 0.9122807017543859]]
# RMSE: 0.2709391059410726
# MSE: 0.07340799912814779
#
#
# Performance for model DRF_1_AutoML_1_20241025_44500:
# AUC: 0.9476284584980238
# Log Loss: 0.2436384049031632
# Mean Per Class Error: [[0.8695652173913043, 0.12154150197628466]]
# Precision Per Class: [[1.0, 1.0]]
# Recall Per Class: [[0.4130434782608695, 1.0]]
# F1 Per Class: [[0.4130434782608695, 0.9583333333333334]]
# Accuracy Per Class: [[0.4565217391304348, 0.9298245614035088]]
# RMSE: 0.2660308142364423
# MSE: 0.07077239412330447
#
#
# Performance for model XRT_1_AutoML_1_20241025_44500:
# AUC: 0.9090909090909091
# Log Loss: 0.27583411701600563
# Mean Per Class Error: [[0.782051282051282, 0.13438735177865613]]
# Precision Per Class: [[0.9985679840095915, 1.0]]
# Recall Per Class: [[0.31223635795788884, 1.0]]
# F1 Per Class: [[0.4339564331831076, 0.9574468085106383]]
# Accuracy Per Class: [[0.4339564331831076, 0.9298245614035088]]
# RMSE: 0.2763628362776792
# MSE: 0.07637641727544332
#
#
# Performance for model DeepLearning_1_AutoML_1_20241025_44500:
# AUC: 0.9268774703557312
# Log Loss: 0.3020093324145364
# Mean Per Class Error: [[0.6511269234797733, 0.12351778656126478]]
# Precision Per Class: [[0.9999593588660778, 1.0]]
# Recall Per Class: [[0.011392993854153008, 1.0]]
# F1 Per Class: [[0.4569376233522251, 0.9462365591397849]]
# Accuracy Per Class: [[0.6511269234797733, 0.9122807017543859]]
# RMSE: 0.2884485629712228
# MSE: 0.0832025734801635
#
#
# Performance for model GBM_grid_1_AutoML_1_20241025_44500_model_1:
# AUC: 0.9229249011857708
# Log Loss: 0.373271738808789
# Mean Per Class Error: [[0.8836289436252245, 0.12154150197628466]]
# Precision Per Class: [[0.9552029712494542, 1.0]]
# Recall Per Class: [[0.5382569230714962, 1.0]]
# F1 Per Class: [[0.8397729161383843, 0.945054945054945]]
# Accuracy Per Class: [[0.8397729161383843, 0.9122807017543859]]
# RMSE: 0.3517963822826676
# MSE: 0.12376069458717279
#
#
# Performance for model GBM_4_AutoML_1_20241025_44500:
# AUC: 0.8181818181818182
# Log Loss: 0.48362616839421707
# Mean Per Class Error: [[0.8768600835347695, 0.1689723320158103]]
# Precision Per Class: [[0.957123918834881, 1.0]]
# Recall Per Class: [[0.34221858949824274, 1.0]]
# F1 Per Class: [[0.8768600835347695, 0.9347826086956522]]
# Accuracy Per Class: [[0.8768600835347695, 0.8947368421052632]]
# RMSE: 0.3972769540444402
# MSE: 0.15782897821482825
#
#
# Performance for model GBM_3_AutoML_1_20241025_44500:
# AUC: 0.9328063241106719
# Log Loss: 0.44747514707462716
# Mean Per Class Error: [[0.9427653008973814, 0.11956521739130432]]
# Precision Per Class: [[0.957142488988762, 1.0]]
# Recall Per Class: [[0.43409802185090884, 1.0]]
# F1 Per Class: [[0.8456168781638138, 0.9473684210526316]]
# Accuracy Per Class: [[0.8456168781638138, 0.9122807017543859]]
# RMSE: 0.3867414404195019
# MSE: 0.14956894173775118
#
#
# Performance for model GBM_grid_1_AutoML_1_20241025_44500_model_2:
# AUC: 0.8488142292490118
# Log Loss: 0.43582212427763234
# Mean Per Class Error: [[0.9371976760493866, 0.16699604743083007]]
# Precision Per Class: [[0.9371976760493866, 0.9512195121951219]]
# Recall Per Class: [[0.3329667897042555, 1.0]]
# F1 Per Class: [[0.8560074859110893, 0.9347826086956522]]
# Accuracy Per Class: [[0.8560074859110893, 0.8947368421052632]]
# RMSE: 0.37849878188960256
# MSE: 0.14326132789191295
#
#
# Performance for model GBM_2_AutoML_1_20241025_44500:
# AUC: 0.9051383399209487
# Log Loss: 0.42643134648093994
# Mean Per Class Error: [[0.9486375983859165, 0.11956521739130432]]
# Precision Per Class: [[0.9568623192402685, 1.0]]
# Recall Per Class: [[0.4417863082319166, 1.0]]
# F1 Per Class: [[0.9000835520964457, 0.9347826086956522]]
# Accuracy Per Class: [[0.9000835520964457, 0.8947368421052632]]
# RMSE: 0.3752513262673106
# MSE: 0.1408135578653756
#
#
# Performance for model GBM_1_AutoML_1_20241025_44500:
# AUC: 0.7915019762845851
# Log Loss: 0.4354667526638469
# Mean Per Class Error: [[0.8357053387704657, 0.1689723320158103]]
# Precision Per Class: [[0.9288350237547669, 1.0]]
# Recall Per Class: [[0.34606349627716165, 1.0]]
# F1 Per Class: [[0.8357053387704657, 0.9347826086956522]]
# Accuracy Per Class: [[0.8357053387704657, 0.8947368421052632]]
# RMSE: 0.3771652393266781
# MSE: 0.1422536177563504
#
#
# Performance for model GBM_5_AutoML_1_20241025_44500:
# AUC: 0.8715415019762847
# Log Loss: 0.47645965719180206
# Mean Per Class Error: [[0.9449812996205997, 0.16699604743083007]]
# Precision Per Class: [[0.956649102249996, 0.96875]]
# Recall Per Class: [[0.2385161257862027, 1.0]]
# F1 Per Class: [[0.906459075511284, 0.9347826086956522]]
# Accuracy Per Class: [[0.906459075511284, 0.8947368421052632]]
# RMSE: 0.39567898454610384
# MSE: 0.15656185881143586

# %%
for model_id in lb['model_id'].as_data_frame()['model_id']:
    model = h2o.get_model(model_id)
    hyperparameters = model.get_params()
    print(f"Hyperparameters for model {model_id}:")
    print(hyperparameters)
    print("\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/h2o/frame.py:1981: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# Hyperparameters for model DeepLearning_grid_1_AutoML_1_20241025_44500_model_1:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'score_each_iteration': False, 'weights_column': None, 'offset_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'checkpoint': None, 'pretrained_autoencoder': None, 'overwrite_with_best_model': True, 'use_all_factor_levels': True, 'standardize': True, 'activation': 'rectifier', 'hidden': [200, 200], 'epochs': 10.0, 'train_samples_per_iteration': -2, 'target_ratio_comm_to_comp': 0.05, 'seed': -1, 'adaptive_rate': True, 'rho': 0.99, 'epsilon': 1e-08, 'rate': 0.005, 'rate_annealing': 1e-06, 'rate_decay': 1.0, 'momentum_start': 0.0, 'momentum_ramp': 1000000.0, 'momentum_stable': 0.0, 'nesterov_accelerated_gradient': True, 'input_dropout_ratio': 0.0, 'hidden_dropout_ratios': None, 'l1': 0.0, 'l2': 0.0, 'max_w2': 3.4028235e+38, 'initial_weight_distribution': 'uniform_adaptive', 'initial_weight_scale': 1.0, 'initial_weights': None, 'initial_biases': None, 'loss': 'automatic', 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'score_interval': 5.0, 'score_training_samples': 10000, 'score_validation_samples': 0, 'score_duty_cycle': 0.1, 'classification_stop': 0.0, 'regression_stop': 1e-06, 'stopping_rounds': 5, 'stopping_metric': 'auto', 'stopping_tolerance': 0.0, 'max_runtime_secs': 0.0, 'score_validation_sampling': 'uniform', 'diagnostics': True, 'fast_mode': True, 'force_load_balance': True, 'variable_importances': True, 'replicate_training_data': True, 'single_node_mode': False, 'shuffle_training_data': False, 'missing_values_handling': 'mean_imputation', 'quiet_mode': False, 'autoencoder': False, 'sparse': False, 'col_major': False, 'average_activation': 0.0, 'sparsity_beta': 0.0, 'max_categorical_features': 2147483647, 'reproducible': False, 'export_weights_and_biases': False, 'mini_batch_size': 1, 'categorical_encoding': 'auto', 'elastic_averaging': False, 'elastic_averaging_moving_rate': 0.9, 'elastic_averaging_regularization': 0.001, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'custom_metric_func': None, 'gainslift_bins': -1}
#
#
# Hyperparameters for model StackedEnsemble_AllModels_1_AutoML_1_20241025_44500:
# {'model_id': None, 'training_frame': None, 'response_column': None, 'validation_frame': None, 'blending_frame': None, 'base_models': [], 'metalearner_algorithm': 'auto', 'metalearner_nfolds': 0, 'metalearner_fold_assignment': None, 'metalearner_fold_column': None, 'metalearner_params': None, 'metalearner_transform': 'none', 'max_runtime_secs': 0.0, 'weights_column': None, 'offset_column': None, 'custom_metric_func': None, 'seed': -1, 'score_training_samples': 10000, 'keep_levelone_frame': False, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'gainslift_bins': -1}
#
#
# Hyperparameters for model StackedEnsemble_BestOfFamily_1_AutoML_1_20241025_44500:
# {'model_id': None, 'training_frame': None, 'response_column': None, 'validation_frame': None, 'blending_frame': None, 'base_models': [], 'metalearner_algorithm': 'auto', 'metalearner_nfolds': 0, 'metalearner_fold_assignment': None, 'metalearner_fold_column': None, 'metalearner_params': None, 'metalearner_transform': 'none', 'max_runtime_secs': 0.0, 'weights_column': None, 'offset_column': None, 'custom_metric_func': None, 'seed': -1, 'score_training_samples': 10000, 'keep_levelone_frame': False, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'gainslift_bins': -1}
#
#
# Hyperparameters for model DeepLearning_grid_3_AutoML_1_20241025_44500_model_1:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'score_each_iteration': False, 'weights_column': None, 'offset_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'checkpoint': None, 'pretrained_autoencoder': None, 'overwrite_with_best_model': True, 'use_all_factor_levels': True, 'standardize': True, 'activation': 'rectifier', 'hidden': [200, 200], 'epochs': 10.0, 'train_samples_per_iteration': -2, 'target_ratio_comm_to_comp': 0.05, 'seed': -1, 'adaptive_rate': True, 'rho': 0.99, 'epsilon': 1e-08, 'rate': 0.005, 'rate_annealing': 1e-06, 'rate_decay': 1.0, 'momentum_start': 0.0, 'momentum_ramp': 1000000.0, 'momentum_stable': 0.0, 'nesterov_accelerated_gradient': True, 'input_dropout_ratio': 0.0, 'hidden_dropout_ratios': None, 'l1': 0.0, 'l2': 0.0, 'max_w2': 3.4028235e+38, 'initial_weight_distribution': 'uniform_adaptive', 'initial_weight_scale': 1.0, 'initial_weights': None, 'initial_biases': None, 'loss': 'automatic', 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'score_interval': 5.0, 'score_training_samples': 10000, 'score_validation_samples': 0, 'score_duty_cycle': 0.1, 'classification_stop': 0.0, 'regression_stop': 1e-06, 'stopping_rounds': 5, 'stopping_metric': 'auto', 'stopping_tolerance': 0.0, 'max_runtime_secs': 0.0, 'score_validation_sampling': 'uniform', 'diagnostics': True, 'fast_mode': True, 'force_load_balance': True, 'variable_importances': True, 'replicate_training_data': True, 'single_node_mode': False, 'shuffle_training_data': False, 'missing_values_handling': 'mean_imputation', 'quiet_mode': False, 'autoencoder': False, 'sparse': False, 'col_major': False, 'average_activation': 0.0, 'sparsity_beta': 0.0, 'max_categorical_features': 2147483647, 'reproducible': False, 'export_weights_and_biases': False, 'mini_batch_size': 1, 'categorical_encoding': 'auto', 'elastic_averaging': False, 'elastic_averaging_moving_rate': 0.9, 'elastic_averaging_regularization': 0.001, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'custom_metric_func': None, 'gainslift_bins': -1}
#
#
# Hyperparameters for model XGBoost_grid_1_AutoML_1_20241025_44500_model_2:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'distribution': 'auto', 'tweedie_power': 1.5, 'categorical_encoding': 'auto', 'quiet_mode': True, 'checkpoint': None, 'export_checkpoints_dir': None, 'custom_metric_func': None, 'ntrees': 50, 'max_depth': 6, 'min_rows': 1.0, 'min_child_weight': 1.0, 'learn_rate': 0.3, 'eta': 0.3, 'sample_rate': 1.0, 'subsample': 1.0, 'col_sample_rate': 1.0, 'colsample_bylevel': 1.0, 'col_sample_rate_per_tree': 1.0, 'colsample_bytree': 1.0, 'colsample_bynode': 1.0, 'max_abs_leafnode_pred': 0.0, 'max_delta_step': 0.0, 'monotone_constraints': None, 'interaction_constraints': None, 'score_tree_interval': 0, 'min_split_improvement': 0.0, 'gamma': 0.0, 'nthread': -1, 'save_matrix_directory': None, 'build_tree_one_node': False, 'parallelize_cross_validation': True, 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'max_bins': 256, 'max_leaves': 0, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.0, 'one_drop': False, 'skip_drop': 0.0, 'tree_method': 'auto', 'grow_policy': 'depthwise', 'booster': 'gbtree', 'reg_lambda': 1.0, 'reg_alpha': 0.0, 'dmatrix_type': 'auto', 'backend': 'auto', 'gpu_id': None, 'gainslift_bins': -1, 'auc_type': 'auto', 'scale_pos_weight': 1.0, 'eval_metric': None, 'score_eval_metric_only': False}
#
#
# Hyperparameters for model DeepLearning_grid_2_AutoML_1_20241025_44500_model_1:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'score_each_iteration': False, 'weights_column': None, 'offset_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'checkpoint': None, 'pretrained_autoencoder': None, 'overwrite_with_best_model': True, 'use_all_factor_levels': True, 'standardize': True, 'activation': 'rectifier', 'hidden': [200, 200], 'epochs': 10.0, 'train_samples_per_iteration': -2, 'target_ratio_comm_to_comp': 0.05, 'seed': -1, 'adaptive_rate': True, 'rho': 0.99, 'epsilon': 1e-08, 'rate': 0.005, 'rate_annealing': 1e-06, 'rate_decay': 1.0, 'momentum_start': 0.0, 'momentum_ramp': 1000000.0, 'momentum_stable': 0.0, 'nesterov_accelerated_gradient': True, 'input_dropout_ratio': 0.0, 'hidden_dropout_ratios': None, 'l1': 0.0, 'l2': 0.0, 'max_w2': 3.4028235e+38, 'initial_weight_distribution': 'uniform_adaptive', 'initial_weight_scale': 1.0, 'initial_weights': None, 'initial_biases': None, 'loss': 'automatic', 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'score_interval': 5.0, 'score_training_samples': 10000, 'score_validation_samples': 0, 'score_duty_cycle': 0.1, 'classification_stop': 0.0, 'regression_stop': 1e-06, 'stopping_rounds': 5, 'stopping_metric': 'auto', 'stopping_tolerance': 0.0, 'max_runtime_secs': 0.0, 'score_validation_sampling': 'uniform', 'diagnostics': True, 'fast_mode': True, 'force_load_balance': True, 'variable_importances': True, 'replicate_training_data': True, 'single_node_mode': False, 'shuffle_training_data': False, 'missing_values_handling': 'mean_imputation', 'quiet_mode': False, 'autoencoder': False, 'sparse': False, 'col_major': False, 'average_activation': 0.0, 'sparsity_beta': 0.0, 'max_categorical_features': 2147483647, 'reproducible': False, 'export_weights_and_biases': False, 'mini_batch_size': 1, 'categorical_encoding': 'auto', 'elastic_averaging': False, 'elastic_averaging_moving_rate': 0.9, 'elastic_averaging_regularization': 0.001, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'custom_metric_func': None, 'gainslift_bins': -1}
#
#
# Hyperparameters for model GLM_1_AutoML_1_20241025_44500:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'checkpoint': None, 'export_checkpoints_dir': None, 'seed': -1, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'random_columns': None, 'ignore_const_cols': True, 'score_each_iteration': False, 'score_iteration_interval': -1, 'offset_column': None, 'weights_column': None, 'family': 'auto', 'rand_family': None, 'tweedie_variance_power': 0.0, 'tweedie_link_power': 1.0, 'theta': 1e-10, 'solver': 'auto', 'alpha': None, 'lambda': None, 'lambda_search': False, 'early_stopping': True, 'nlambdas': -1, 'standardize': True, 'missing_values_handling': 'mean_imputation', 'plug_values': None, 'compute_p_values': False, 'dispersion_parameter_method': 'pearson', 'init_dispersion_parameter': 1.0, 'remove_collinear_columns': False, 'intercept': True, 'non_negative': False, 'max_iterations': -1, 'objective_epsilon': -1.0, 'beta_epsilon': 0.0001, 'gradient_epsilon': -1.0, 'link': 'family_default', 'rand_link': None, 'startval': None, 'calc_like': False, 'HGLM': False, 'prior': -1.0, 'cold_start': False, 'lambda_min_ratio': -1.0, 'max_active_predictors': -1, 'interactions': None, 'interaction_pairs': None, 'obj_reg': -1.0, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'max_runtime_secs': 0.0, 'custom_metric_func': None, 'generate_scoring_history': False, 'auc_type': 'auto', 'dispersion_epsilon': 0.0001, 'tweedie_epsilon': 8e-17, 'max_iterations_dispersion': 3000, 'build_null_model': False, 'fix_dispersion_parameter': False, 'generate_variable_inflation_factors': False, 'fix_tweedie_variance_power': True, 'dispersion_learning_rate': 0.5, 'influence': None, 'gainslift_bins': -1, 'linear_constraints': None, 'init_optimal_glm': False, 'separate_linear_beta': False, 'constraint_eta0': 0.1258925, 'constraint_tau': 10.0, 'constraint_alpha': 0.1, 'constraint_beta': 0.9, 'constraint_c0': 10.0}
#
#
# Hyperparameters for model XGBoost_grid_1_AutoML_1_20241025_44500_model_1:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'distribution': 'auto', 'tweedie_power': 1.5, 'categorical_encoding': 'auto', 'quiet_mode': True, 'checkpoint': None, 'export_checkpoints_dir': None, 'custom_metric_func': None, 'ntrees': 50, 'max_depth': 6, 'min_rows': 1.0, 'min_child_weight': 1.0, 'learn_rate': 0.3, 'eta': 0.3, 'sample_rate': 1.0, 'subsample': 1.0, 'col_sample_rate': 1.0, 'colsample_bylevel': 1.0, 'col_sample_rate_per_tree': 1.0, 'colsample_bytree': 1.0, 'colsample_bynode': 1.0, 'max_abs_leafnode_pred': 0.0, 'max_delta_step': 0.0, 'monotone_constraints': None, 'interaction_constraints': None, 'score_tree_interval': 0, 'min_split_improvement': 0.0, 'gamma': 0.0, 'nthread': -1, 'save_matrix_directory': None, 'build_tree_one_node': False, 'parallelize_cross_validation': True, 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'max_bins': 256, 'max_leaves': 0, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.0, 'one_drop': False, 'skip_drop': 0.0, 'tree_method': 'auto', 'grow_policy': 'depthwise', 'booster': 'gbtree', 'reg_lambda': 1.0, 'reg_alpha': 0.0, 'dmatrix_type': 'auto', 'backend': 'auto', 'gpu_id': None, 'gainslift_bins': -1, 'auc_type': 'auto', 'scale_pos_weight': 1.0, 'eval_metric': None, 'score_eval_metric_only': False}
#
#
# Hyperparameters for model XGBoost_2_AutoML_1_20241025_44500:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'distribution': 'auto', 'tweedie_power': 1.5, 'categorical_encoding': 'auto', 'quiet_mode': True, 'checkpoint': None, 'export_checkpoints_dir': None, 'custom_metric_func': None, 'ntrees': 50, 'max_depth': 6, 'min_rows': 1.0, 'min_child_weight': 1.0, 'learn_rate': 0.3, 'eta': 0.3, 'sample_rate': 1.0, 'subsample': 1.0, 'col_sample_rate': 1.0, 'colsample_bylevel': 1.0, 'col_sample_rate_per_tree': 1.0, 'colsample_bytree': 1.0, 'colsample_bynode': 1.0, 'max_abs_leafnode_pred': 0.0, 'max_delta_step': 0.0, 'monotone_constraints': None, 'interaction_constraints': None, 'score_tree_interval': 0, 'min_split_improvement': 0.0, 'gamma': 0.0, 'nthread': -1, 'save_matrix_directory': None, 'build_tree_one_node': False, 'parallelize_cross_validation': True, 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'max_bins': 256, 'max_leaves': 0, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.0, 'one_drop': False, 'skip_drop': 0.0, 'tree_method': 'auto', 'grow_policy': 'depthwise', 'booster': 'gbtree', 'reg_lambda': 1.0, 'reg_alpha': 0.0, 'dmatrix_type': 'auto', 'backend': 'auto', 'gpu_id': None, 'gainslift_bins': -1, 'auc_type': 'auto', 'scale_pos_weight': 1.0, 'eval_metric': None, 'score_eval_metric_only': False}
#
#
# Hyperparameters for model XGBoost_grid_1_AutoML_1_20241025_44500_model_3:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'distribution': 'auto', 'tweedie_power': 1.5, 'categorical_encoding': 'auto', 'quiet_mode': True, 'checkpoint': None, 'export_checkpoints_dir': None, 'custom_metric_func': None, 'ntrees': 50, 'max_depth': 6, 'min_rows': 1.0, 'min_child_weight': 1.0, 'learn_rate': 0.3, 'eta': 0.3, 'sample_rate': 1.0, 'subsample': 1.0, 'col_sample_rate': 1.0, 'colsample_bylevel': 1.0, 'col_sample_rate_per_tree': 1.0, 'colsample_bytree': 1.0, 'colsample_bynode': 1.0, 'max_abs_leafnode_pred': 0.0, 'max_delta_step': 0.0, 'monotone_constraints': None, 'interaction_constraints': None, 'score_tree_interval': 0, 'min_split_improvement': 0.0, 'gamma': 0.0, 'nthread': -1, 'save_matrix_directory': None, 'build_tree_one_node': False, 'parallelize_cross_validation': True, 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'max_bins': 256, 'max_leaves': 0, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.0, 'one_drop': False, 'skip_drop': 0.0, 'tree_method': 'auto', 'grow_policy': 'depthwise', 'booster': 'gbtree', 'reg_lambda': 1.0, 'reg_alpha': 0.0, 'dmatrix_type': 'auto', 'backend': 'auto', 'gpu_id': None, 'gainslift_bins': -1, 'auc_type': 'auto', 'scale_pos_weight': 1.0, 'eval_metric': None, 'score_eval_metric_only': False}
#
#
# Hyperparameters for model XGBoost_1_AutoML_1_20241025_44500:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'distribution': 'auto', 'tweedie_power': 1.5, 'categorical_encoding': 'auto', 'quiet_mode': True, 'checkpoint': None, 'export_checkpoints_dir': None, 'custom_metric_func': None, 'ntrees': 50, 'max_depth': 6, 'min_rows': 1.0, 'min_child_weight': 1.0, 'learn_rate': 0.3, 'eta': 0.3, 'sample_rate': 1.0, 'subsample': 1.0, 'col_sample_rate': 1.0, 'colsample_bylevel': 1.0, 'col_sample_rate_per_tree': 1.0, 'colsample_bytree': 1.0, 'colsample_bynode': 1.0, 'max_abs_leafnode_pred': 0.0, 'max_delta_step': 0.0, 'monotone_constraints': None, 'interaction_constraints': None, 'score_tree_interval': 0, 'min_split_improvement': 0.0, 'gamma': 0.0, 'nthread': -1, 'save_matrix_directory': None, 'build_tree_one_node': False, 'parallelize_cross_validation': True, 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'max_bins': 256, 'max_leaves': 0, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.0, 'one_drop': False, 'skip_drop': 0.0, 'tree_method': 'auto', 'grow_policy': 'depthwise', 'booster': 'gbtree', 'reg_lambda': 1.0, 'reg_alpha': 0.0, 'dmatrix_type': 'auto', 'backend': 'auto', 'gpu_id': None, 'gainslift_bins': -1, 'auc_type': 'auto', 'scale_pos_weight': 1.0, 'eval_metric': None, 'score_eval_metric_only': False}
#
#
# Hyperparameters for model XGBoost_3_AutoML_1_20241025_44500:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'distribution': 'auto', 'tweedie_power': 1.5, 'categorical_encoding': 'auto', 'quiet_mode': True, 'checkpoint': None, 'export_checkpoints_dir': None, 'custom_metric_func': None, 'ntrees': 50, 'max_depth': 6, 'min_rows': 1.0, 'min_child_weight': 1.0, 'learn_rate': 0.3, 'eta': 0.3, 'sample_rate': 1.0, 'subsample': 1.0, 'col_sample_rate': 1.0, 'colsample_bylevel': 1.0, 'col_sample_rate_per_tree': 1.0, 'colsample_bytree': 1.0, 'colsample_bynode': 1.0, 'max_abs_leafnode_pred': 0.0, 'max_delta_step': 0.0, 'monotone_constraints': None, 'interaction_constraints': None, 'score_tree_interval': 0, 'min_split_improvement': 0.0, 'gamma': 0.0, 'nthread': -1, 'save_matrix_directory': None, 'build_tree_one_node': False, 'parallelize_cross_validation': True, 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'max_bins': 256, 'max_leaves': 0, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.0, 'one_drop': False, 'skip_drop': 0.0, 'tree_method': 'auto', 'grow_policy': 'depthwise', 'booster': 'gbtree', 'reg_lambda': 1.0, 'reg_alpha': 0.0, 'dmatrix_type': 'auto', 'backend': 'auto', 'gpu_id': None, 'gainslift_bins': -1, 'auc_type': 'auto', 'scale_pos_weight': 1.0, 'eval_metric': None, 'score_eval_metric_only': False}
#
#
# Hyperparameters for model DRF_1_AutoML_1_20241025_44500:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 20, 'min_rows': 1.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'mtries': -1, 'sample_rate': 0.632, 'sample_rate_per_class': None, 'binomial_double_trees': False, 'checkpoint': None, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'distribution': 'auto', 'custom_metric_func': None, 'export_checkpoints_dir': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto'}
#
#
# Hyperparameters for model XRT_1_AutoML_1_20241025_44500:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 20, 'min_rows': 1.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'mtries': -1, 'sample_rate': 0.632, 'sample_rate_per_class': None, 'binomial_double_trees': False, 'checkpoint': None, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'distribution': 'auto', 'custom_metric_func': None, 'export_checkpoints_dir': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto'}
#
#
# Hyperparameters for model DeepLearning_1_AutoML_1_20241025_44500:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'score_each_iteration': False, 'weights_column': None, 'offset_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'checkpoint': None, 'pretrained_autoencoder': None, 'overwrite_with_best_model': True, 'use_all_factor_levels': True, 'standardize': True, 'activation': 'rectifier', 'hidden': [200, 200], 'epochs': 10.0, 'train_samples_per_iteration': -2, 'target_ratio_comm_to_comp': 0.05, 'seed': -1, 'adaptive_rate': True, 'rho': 0.99, 'epsilon': 1e-08, 'rate': 0.005, 'rate_annealing': 1e-06, 'rate_decay': 1.0, 'momentum_start': 0.0, 'momentum_ramp': 1000000.0, 'momentum_stable': 0.0, 'nesterov_accelerated_gradient': True, 'input_dropout_ratio': 0.0, 'hidden_dropout_ratios': None, 'l1': 0.0, 'l2': 0.0, 'max_w2': 3.4028235e+38, 'initial_weight_distribution': 'uniform_adaptive', 'initial_weight_scale': 1.0, 'initial_weights': None, 'initial_biases': None, 'loss': 'automatic', 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'score_interval': 5.0, 'score_training_samples': 10000, 'score_validation_samples': 0, 'score_duty_cycle': 0.1, 'classification_stop': 0.0, 'regression_stop': 1e-06, 'stopping_rounds': 5, 'stopping_metric': 'auto', 'stopping_tolerance': 0.0, 'max_runtime_secs': 0.0, 'score_validation_sampling': 'uniform', 'diagnostics': True, 'fast_mode': True, 'force_load_balance': True, 'variable_importances': True, 'replicate_training_data': True, 'single_node_mode': False, 'shuffle_training_data': False, 'missing_values_handling': 'mean_imputation', 'quiet_mode': False, 'autoencoder': False, 'sparse': False, 'col_major': False, 'average_activation': 0.0, 'sparsity_beta': 0.0, 'max_categorical_features': 2147483647, 'reproducible': False, 'export_weights_and_biases': False, 'mini_batch_size': 1, 'categorical_encoding': 'auto', 'elastic_averaging': False, 'elastic_averaging_moving_rate': 0.9, 'elastic_averaging_regularization': 0.001, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'custom_metric_func': None, 'gainslift_bins': -1}
#
#
# Hyperparameters for model GBM_grid_1_AutoML_1_20241025_44500_model_1:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}
#
#
# Hyperparameters for model GBM_4_AutoML_1_20241025_44500:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}
#
#
# Hyperparameters for model GBM_3_AutoML_1_20241025_44500:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}
#
#
# Hyperparameters for model GBM_grid_1_AutoML_1_20241025_44500_model_2:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}
#
#
# Hyperparameters for model GBM_2_AutoML_1_20241025_44500:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}
#
#
# Hyperparameters for model GBM_1_AutoML_1_20241025_44500:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}
#
#
# Hyperparameters for model GBM_5_AutoML_1_20241025_44500:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}

# %%
model = aml.get_best_model()
hyperparameters = model.get_params()
print(f"Hyperparameters for model {model_id}:")
print(hyperparameters)
print("\n")
# Out:
# Hyperparameters for model GBM_5_AutoML_1_20241025_44500:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'score_each_iteration': False, 'weights_column': None, 'offset_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'checkpoint': None, 'pretrained_autoencoder': None, 'overwrite_with_best_model': True, 'use_all_factor_levels': True, 'standardize': True, 'activation': 'rectifier', 'hidden': [200, 200], 'epochs': 10.0, 'train_samples_per_iteration': -2, 'target_ratio_comm_to_comp': 0.05, 'seed': -1, 'adaptive_rate': True, 'rho': 0.99, 'epsilon': 1e-08, 'rate': 0.005, 'rate_annealing': 1e-06, 'rate_decay': 1.0, 'momentum_start': 0.0, 'momentum_ramp': 1000000.0, 'momentum_stable': 0.0, 'nesterov_accelerated_gradient': True, 'input_dropout_ratio': 0.0, 'hidden_dropout_ratios': None, 'l1': 0.0, 'l2': 0.0, 'max_w2': 3.4028235e+38, 'initial_weight_distribution': 'uniform_adaptive', 'initial_weight_scale': 1.0, 'initial_weights': None, 'initial_biases': None, 'loss': 'automatic', 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'score_interval': 5.0, 'score_training_samples': 10000, 'score_validation_samples': 0, 'score_duty_cycle': 0.1, 'classification_stop': 0.0, 'regression_stop': 1e-06, 'stopping_rounds': 5, 'stopping_metric': 'auto', 'stopping_tolerance': 0.0, 'max_runtime_secs': 0.0, 'score_validation_sampling': 'uniform', 'diagnostics': True, 'fast_mode': True, 'force_load_balance': True, 'variable_importances': True, 'replicate_training_data': True, 'single_node_mode': False, 'shuffle_training_data': False, 'missing_values_handling': 'mean_imputation', 'quiet_mode': False, 'autoencoder': False, 'sparse': False, 'col_major': False, 'average_activation': 0.0, 'sparsity_beta': 0.0, 'max_categorical_features': 2147483647, 'reproducible': False, 'export_weights_and_biases': False, 'mini_batch_size': 1, 'categorical_encoding': 'auto', 'elastic_averaging': False, 'elastic_averaging_moving_rate': 0.9, 'elastic_averaging_regularization': 0.001, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'custom_metric_func': None, 'gainslift_bins': -1}
