# %%
y = 'Success_Open'
save_path_name = '_Undepricing_Success_Open_Numeric_Only/'

# %%
import pandas as pd

# %%
import numpy as np

# %%
main = pd.read_excel("/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/ipo_mainline_final_data_v18.xlsx")
main
# Out:
#      mapping_key                                                url  \
# 0            433  https://www.chittorgarh.com/ipo/edserv_softsys...
# 1            607  https://www.chittorgarh.com/ipo/mahindra_holid...
# 2            504  https://www.chittorgarh.com/ipo/excel_infoways...
# 3             15  https://www.chittorgarh.com/ipo/raj_oil_mills_...
# 4            369  https://www.chittorgarh.com/ipo/adani_power_ip...
# ..           ...                                                ...
# 413          166  https://www.chittorgarh.com/ipo/happy-forgings...
# 414          214    https://www.chittorgarh.com/ipo/mufti-ipo/1595/
# 415          568  https://www.chittorgarh.com/ipo/rbz-jewellers-...
# 416          506  https://www.chittorgarh.com/ipo/azad-engineeri...
# 417          316  https://www.chittorgarh.com/ipo/innova-captab-...
#
#                                   Issuer Company  Exchange  \
# 0                 Edserv Softsystems Limited IPO  BSE, NSE
# 1    Mahindra Holidays and Resorts India Ltd IPO  BSE, NSE
# 2                     Excel Infoways Limited IPO  BSE, NSE
# 3                      Raj Oil Mills Limited IPO  BSE, NSE
# 4                        Adani Power Limited IPO  BSE, NSE
# ..                                           ...       ...
# 413                   Happy Forgings Limited IPO  BSE, NSE
# 414           Credo Brands Marketing Limited IPO  BSE, NSE
# 415                    RBZ Jewellers Limited IPO  BSE, NSE
# 416                 Azad Engineering Limited IPO  BSE, NSE
# 417                    Innova Captab Limited IPO  BSE, NSE
#
#                                      subscription_link  \
# 0    https://www.chittorgarh.com/ipo_subscription/e...
# 1    https://www.chittorgarh.com/ipo_subscription/m...
# 2    https://www.chittorgarh.com/ipo_subscription/e...
# 3    https://www.chittorgarh.com/ipo_subscription/r...
# 4    https://www.chittorgarh.com/ipo_subscription/a...
# ..                                                 ...
# 413  https://www.chittorgarh.com/ipo_subscription/h...
# 414  https://www.chittorgarh.com/ipo_subscription/m...
# 415  https://www.chittorgarh.com/ipo_subscription/r...
# 416  https://www.chittorgarh.com/ipo_subscription/a...
# 417  https://www.chittorgarh.com/ipo_subscription/i...
#
#                                     Subscription Dates  NSE_symbol  \
# 0    February 5, 2009;February 6, 2009;February 9, ...      EDSERV
# 1    June 23, 2009;June 24, 2009;June 25, 2009;June...       MHRIL
# 2    July 14, 2009;July 15, 2009;July 16, 2009;July...       EXCEL
# 3    July 20, 2009;July 21, 2009;July 22, 2009;July...      RAJOIL
# 4    July 28, 2009;July 29, 2009;July 30, 2009;July...  ADANIPOWER
# ..                                                 ...         ...
# 413  December 19, 2023;December 20, 2023;December 2...  HAPPYFORGE
# 414  December 19, 2023;December 20, 2023;December 2...       MUFTI
# 415  December 19, 2023;December 20, 2023;December 2...    RBZJEWEL
# 416  December 20, 2023;December 21, 2023;December 2...        AZAD
# 417  December 21, 2023;December 22, 2023;December 2...   INNOVACAP
#
#      Close Year  Close Year Previous 1 day before Close Day  ...  \
# 0          2009                 2008             2009-02-08  ...
# 1          2009                 2008             2009-06-25  ...
# 2          2009                 2008             2009-07-16  ...
# 3          2009                 2008             2009-07-22  ...
# 4          2009                 2008             2009-07-30  ...
# ..          ...                  ...                    ...  ...
# 413        2023                 2022             2023-12-20  ...
# 414        2023                 2022             2023-12-20  ...
# 415        2023                 2022             2023-12-20  ...
# 416        2023                 2022             2023-12-21  ...
# 417        2023                 2022             2023-12-25  ...
#
#                                  answer_of_question_16  \
# 0    The potential impact of market fluctuations on...
# 1    Based on the contents provided, the potential ...
# 2    Based on the content provided, it is stated th...
# 3    The Red Herring Prospectus (RHP) highlights th...
# 4    Based on the provided contents, the potential ...
# ..                                                 ...
# 413  Based on the provided Red Herring Prospectus (...
# 414  As per the content, the company's performance ...
# 415  Based on the content provided, the company's p...
# 416  The document indicates that the company's perf...
# 417  The potential impact of market fluctuations on...
#
#                                  answer_of_question_17  \
# 0    Based on the provided content, the valuations ...
# 1    Based on the information provided in the Red H...
# 2    Based on the data provided in the Red Herring ...
# 3    Based on the information provided in the Red H...
# 4    Based on the content provided, here is my anal...
# ..                                                 ...
# 413  Based on the contents provided, the basis for ...
# 414  The IPO price has been determined by the compa...
# 415  The IPO price is determined based on several q...
# 416  Based on the provided content, the basis for d...
# 417  The IPO price has been determined by the compa...
#
#                                  answer_of_question_18  \
# 0    Based on the provided content, the Red Herring...
# 1    Based on the information available in the Red ...
# 2    The determination of the Offer Price for the I...
# 3    The IPO grading rationale suggests that the co...
# 4    The RHP does not provide direct information ab...
# ..                                                 ...
# 413  Based on the provided content from the Red Her...
# 414  The Basis for Offer Price section of the Red H...
# 415  Based on the content provided, it can be infer...
# 416  Based on the provided contents, the IPO price ...
# 417  Based on the provided content, it appears that...
#
#                                  answer_of_question_19  \
# 0    Based on the content provided, it is difficult...
# 1    Based on the information provided in the Red H...
# 2    Based on the information provided in the Red H...
# 3    Based on the information provided, the company...
# 4    Based on the Red Herring Prospectus (RHP) of A...
# ..                                                 ...
# 413  Based on the provided contents, it is difficul...
# 414  The basis for determining the offer price is d...
# 415  Based on the content provided, it is difficult...
# 416  Based on the information provided in the Red H...
# 417  The IPO price has been determined based on an ...
#
#                                  answer_of_question_20  \
# 0    Based on the provided contents from the Red He...
# 1    The company's valuation seems to be justified ...
# 2    The company's valuation is based on several qu...
# 3    Based on the provided Red Herring Prospectus (...
# 4    Please note that the given content only includ...
# ..                                                 ...
# 413  The company's valuation cannot be considered r...
# 414  The company's valuation is based on the financ...
# 415  Based on the provided content, the company's v...
# 416     Based on the provided contents, we can analyze
# 417  Based on the information provided in the Red H...
#
#                                  answer_of_question_21  \
# 0    Based on the content provided, the company EdS...
# 1    Based on the Red Herring Prospectus (RHP), the...
# 2    Based on the contents, here is how the company...
# 3    Based on the content provided, the company fac...
# 4    The information provided in the Red Herring Pr...
# ..                                                 ...
# 413  Based on the provided Red Herring Prospectus (...
# 414  Based on the provided Red Herring Prospectus (...
# 415  Based on the provided contents, I can draw the...
# 416  Based on the content provided, the company has...
# 417  Based on the provided Red Herring Prospectus (...
#
#                                  answer_of_question_22  \
# 0    According to the content provided, the Declara...
# 1    Based on the provided contents, it can be infe...
# 2    The relevant content for this question can be ...
# 3    From the given content, it can be seen that th...
# 4    The company, Adani Power Limited, has complied...
# ..                                                 ...
# 413  The company has complied with all relevant reg...
# 414  Based on the content provided, the company has...
# 415  Based on the content provided, the company's D...
# 416  Based on the provided content, it appears that...
# 417  The Declaration section of the Red Herring Pro...
#
#                                  answer_of_question_23  \
# 0    The book running lead managers (BRLM) are Keyn...
# 1    According to the content, the lead managers an...
# 2    According to the Red Herring Prospectus, the B...
# 3    Based on the contents provided, the informatio...
# 4    According to the content provided, the Global ...
# ..                                                 ...
# 413  The relevant content for the question is not p...
# 414  The lead managers/underwriters mentioned in th...
# 415  Based on the provided contents from the Red He...
# 416  Based on the information provided in the Red H...
# 417  From the provided content, it appears that the...
#
#                                  answer_of_question_24  \
# 0    Based on the provided contents, the company's ...
# 1    The Red Herring Prospectus (RHP) does not expl...
# 2    Based on the provided Content-1 and Content-2,...
# 3    According to the Red Herring Prospectus (RHP) ...
# 4    Based on the provided information from the Red...
# ..                                                 ...
# 413  Based on the provided Red Herring Prospectus (...
# 414  Based on the given content, here is the answer...
# 415  Based on the provided contents from the Red He...
# 416  Based on the contents provided, here is a summ...
# 417  Based on the provided Red Herring Prospectus, ...
#
#                                  answer_of_question_25
# 0    The shareholding pattern of the company before...
# 1    Based on the content provided, the shareholdin...
# 2    Based on the provided content from the Red Her...
# 3    Based on the Red Herring Prospectus (RHP), the...
# 4    The shareholding pattern of Adani Power Limite...
# ..                                                 ...
# 413  Based on the information provided in the Red H...
# 414  According to the Red Herring Prospectus, the s...
# 415  Based on the provided content, the shareholdin...
# 416  Based on the Red Herring Prospectus (RHP), the...
# 417  Based on the Red Herring Prospectus (RHP) cont...
#
# [418 rows x 217 columns]

# %%
# !pip install h2o
# Out:
# Collecting h2o
#   Downloading h2o-3.46.0.5.tar.gz (265.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.6/265.6 MB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from h2o) (2.32.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from h2o) (0.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->h2o) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->h2o) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->h2o) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->h2o) (2024.8.30)
# Building wheels for collected packages: h2o
#   Building wheel for h2o (setup.py) ... done
#   Created wheel for h2o: filename=h2o-3.46.0.5-py2.py3-none-any.whl size=265646558 sha256=92f49052a9bc5a44db0263078dda4b4b8f5dde2e006e7fddbf4f428e3643d1a4
#   Stored in directory: /root/.cache/pip/wheels/1a/46/4f/9b366522399306d7849672d58aefb44c9b73378d710bde2853
# Successfully built h2o
# Installing collected packages: h2o
# Successfully installed h2o-3.46.0.5

# %%
import h2o
from h2o.automl import H2OAutoML

# Start the H2O cluster (locally)
h2o.init()

# Import a sample binary outcome train/test set into H2O
# train = h2o.import_file("https://s3.amazonaws.com/h2o-public-test-data/smalldata/higgs/higgs_train_10k.csv")
# test = h2o.import_file("https://s3.amazonaws.com/h2o-public-test-data/smalldata/higgs/higgs_test_5k.csv")

train = main[main['Close Year'] < 2023]
test =main[main['Close Year'] == 2023]
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.24" 2024-07-16; OpenJDK Runtime Environment (build 11.0.24+8-post-Ubuntu-1ubuntu322.04); OpenJDK 64-Bit Server VM (build 11.0.24+8-post-Ubuntu-1ubuntu322.04, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.10/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpkllou9lv
#   JVM stdout: /tmp/tmpkllou9lv/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmpkllou9lv/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------------------------------------------------------------------
# H2O_cluster_uptime:         07 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.5
# H2O_cluster_version_age:    21 days, 3 hours and 13 minutes
# H2O_cluster_name:           H2O_from_python_unknownUser_9jexir
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.170 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null, "colab_language_server": "/usr/colab/bin/language_service"}
# H2O_internal_security:      False
# Python_version:             3.10.12 final
# --------------------------  -----------------------------------------------------------------------------------------

# %%
numeric_features = ['Final_Issue_Price',
 'Issue Size (Rs Cr.)',
 'Lot Size',
 'GDP per capita growth (annual %)',
 'GDP growth (annual %)',
 'GDP (current US$)',
 'Unemployment, total (% of total labor force) (modeled ILO estimate)',
 'Stocks traded, total value (% of GDP)',
 'Personal remittances, received (% of GDP)',
 'Net trade in goods and services (BoP, current US$)',
 'GNI per capita growth (annual %)',
 'Inflation, consumer prices (annual %)',
 'GNI (current US$)',
 'Foreign direct investment, net inflows (BoP, current US$)',
 'Foreign direct investment, net (BoP, current US$)',
 'Price_nifty50_daily',
 'Open_nifty50_daily',
 'High_nifty50_daily',
 'Low_nifty50_daily',
 'Volume_nifty50_daily',
 'Chg%_nifty50_daily',
 'Price_nifty50_weekly',
 'Open_nifty50_weekly',
 'High_nifty50_weekly',
 'Low_nifty50_weekly',
 'Volume_nifty50_weekly',
 'Chg%_nifty50_weekly',
 'Price_nifty50_monthly',
 'Open_nifty50_monthly',
 'High_nifty50_monthly',
 'Low_nifty50_monthly',
 'Volume_nifty50_monthly',
 'Chg%_nifty50_monthly',
 'Price_vix_daily',
 'Open_vix_daily',
 'High_vix_daily',
 'Low_vix_daily',
 'Chg%_vix_daily',
 'Price_vix_weekly',
 'Open_vix_weekly',
 'High_vix_weekly',
 'Low_vix_weekly',
 'Chg%_vix_weekly',
 'Price_vix_monthly',
 'Open_vix_monthly',
 'High_vix_monthly',
 'Low_vix_monthly',
 'Chg%_vix_monthly',
 'previous_quarter_success_open',
 'previous_quarter_success_close',
 'previous_quarter_success_high',
 'dynamic_last_90Day_success_open',
 'dynamic_last_90Day_success_close',
 'dynamic_last_90Day_success_high',
 'day_1_qib',
 'day_1_nii',
 'day_1_retail',
 'day_1_total',
 'day_2_qib',
 'day_2_nii',
 'day_2_retail',
 'day_2_total',
 'day_3_qib',
 'day_3_nii',
 'day_3_retail',
 'day_3_total',
 'day_4_qib',
 'day_4_nii',
 'day_4_retail',
 'day_4_total',
 'day_5_qib',
 'day_5_nii',
 'day_5_retail',
 'day_5_total',
 'day_6_qib',
 'day_6_nii',
 'day_6_retail',
 'day_6_total',
 'Brokers_Subscribe',
 'Brokers_Neutral',
 'Brokers_Avoid',
 'Members_Subscribe',
 'Members_Neutral',
 'Members_Avoid',
 'Face Value per share',
 'Retail (Min)_Lots',
 'Retail (Min)_Shares',
 'Retail (Min)_Amount',
 'Retail (Max)_Lots',
 'Retail (Max)_Shares',
 'Retail (Max)_Amount',
 'S-HNI (Min)_Lots',
 'S-HNI (Min)_Shares',
 'S-HNI (Min)_Amount',
 'S-HNI (Max)_Lots',
 'S-HNI (Max)_Shares',
 'S-HNI (Max)_Amount',
 'B-HNI (Min)_Lots',
 'B-HNI (Min)_Shares',
 'B-HNI (Min)_Amount',
 'Share Holding Pre Issue',
 'Share Holding Post Issue',
 '0_assets',
 '0_revenue',
 '0_profit after tax',
 '0_net worth',
 '0_reserves and surplus',
 '0_total borrowing',
 '0_total income',
 '1_assets',
 '1_revenue',
 '1_profit after tax',
 '1_net worth',
 '1_reserves and surplus',
 '1_total borrowing',
 '1_total income',
 '2_assets',
 '2_revenue',
 '2_profit after tax',
 '2_net worth',
 '2_reserves and surplus',
 '2_total borrowing',
 '2_total income',
 '3_assets',
 '3_revenue',
 '3_profit after tax',
 '3_net worth',
 '3_reserves and surplus',
 '3_total borrowing',
 '3_total income',
 '4_assets',
 '4_revenue',
 '4_profit after tax',
 '4_net worth',
 '4_reserves and surplus',
 '4_total borrowing',
 '4_total income',
 '5_assets',
 '5_revenue',
 '5_profit after tax',
 '5_total income']

categorical_features = ['Sector',	'Industry',	'Total Issue Size',	'Issue Type',	'Fresh Issue',	'Offer for Sale',	'Price Band']

# %%
def clean_numbers(txt):
    num =  str(txt).replace(',','').replace(' ','')
    if len(num.split('.')) > 2:
        num = '.'.join(num.split('.')[0:2])
    if num == '':
        return np.nan
    if num == 'nan':
        return np.nan
    if num == '-':
        return np.nan
    if '%' in num:
        num = float(num.replace('%',''))/100
    elif 'Cr' in num:
        num = float(num.replace('Cr',''))*10000000
    elif 'B' in num:
        num = float(num.replace('B',''))*1000000000

    elif 'M' in num:
        num = float(num.replace('M',''))*1000000

    elif 'K' in num:
        num = float(num.replace('K',''))*1000
    else:
        num = float(num)

    return num

# %%
train_use_X = train[numeric_features + categorical_features]# + text_features]
test_use_X = test[numeric_features + categorical_features]# + text_features]
for i in numeric_features:
  if train_use_X[i].dtype != 'int64' and train_use_X[i].dtype !='float64':
    train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
    test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# Out:
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-9-cbaa4854669d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')

# %%
for col in  categorical_features:# + text_features:
  train_use_X[col] = train_use_X[col].str.replace('"', '', regex=False)  # Remove double quotes
  train_use_X[col] = train_use_X[col].str.replace('\n', ' ', regex=False)
  test_use_X[col] = test_use_X[col].str.replace('"', '', regex=False)  # Remove double quotes
  test_use_X[col] = test_use_X[col].str.replace('\n', ' ', regex=False)
# Out:
# <ipython-input-10-62d980eb7aa8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[col] = train_use_X[col].str.replace('"', '', regex=False)  # Remove double quotes
# <ipython-input-10-62d980eb7aa8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[col] = train_use_X[col].str.replace('\n', ' ', regex=False)
# <ipython-input-10-62d980eb7aa8>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[col] = test_use_X[col].str.replace('"', '', regex=False)  # Remove double quotes
# <ipython-input-10-62d980eb7aa8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[col] = test_use_X[col].str.replace('\n', ' ', regex=False)

# %%
h2o_train = h2o.H2OFrame(train_use_X)  # Convert train DataFrame to H2OFrame
h2o_test = h2o.H2OFrame(test_use_X)  # Convert test DataFrame to H2OFrame
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
if y == 'Success_Open':
  val = 'NSE_Open'
if y == 'Success_Close':
  val = 'NSE_Last_Trade'
if y == 'Success_High':
  val = 'NSE_High'
train['underpricing']= (train[val] - train['Final_Issue_Price'])/train['Final_Issue_Price']
# Out:
# <ipython-input-12-e348d5391cbf>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['underpricing']= (train[val] - train['Final_Issue_Price'])/train['Final_Issue_Price']

# %%
test['underpricing']= (test[val] - test['Final_Issue_Price'])/test['Final_Issue_Price']
# Out:
# <ipython-input-13-35217937bc5b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['underpricing']= (test[val] - test['Final_Issue_Price'])/test['Final_Issue_Price']

# %%
# Identify predictors and response
# x = train.columns
# y = "response"
# x.remove(y)

x= numeric_features + categorical_features


h2o_train[y] = h2o.H2OFrame(train['underpricing'].to_list()) #h2o.H2OFrame(train[y].to_list()).asfactor()  # Convert Pandas Series to H2OFrame before assigning
h2o_test[y] =  h2o.H2OFrame(test['underpricing'].to_list()) #h2o.H2OFrame(test[y].to_list()).asfactor()  # Convert Pandas Series to H2OFrame before assigning

# For binary classification, response should be a factor
# train[y] = train[y].asfactor()
# test[y] = test[y].asfactor()

# Run AutoML for 20 base models
aml = H2OAutoML(max_models=20, seed=1)
aml.train(x=x, y=y, training_frame=h2o_train)

# View the AutoML Leaderboard
lb = aml.leaderboard
lb.head(rows=lb.nrows)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 15:05:24.42: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ██
# 15:05:51.40: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ██
# 15:06:07.125: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
#
# 15:06:12.59: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:06:22.975: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ██
# 15:06:45.155: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:06:51.188: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:06:56.405: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:07:01.166: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:07:07.189: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ███
# 15:07:26.649: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
#
# 15:07:31.297: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ███████████████████████████████████████████████
# 15:20:32.83: _train param, Dropping unused columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
# 15:20:33.125: _train param, Dropping unused columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ██| (done) 100%
# model_id                                                     rmse        mse       mae       rmsle    mean_residual_deviance
# -------------------------------------------------------  --------  ---------  --------  ----------  ------------------------
# StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_150523  0.218581  0.0477775  0.134714    0.153078                 0.0477775
# DeepLearning_grid_3_AutoML_1_20240919_150523_model_1     0.219308  0.0480962  0.134276    0.154229                 0.0480962
# StackedEnsemble_AllModels_1_AutoML_1_20240919_150523     0.223068  0.0497594  0.13646     0.170783                 0.0497594
# DeepLearning_grid_2_AutoML_1_20240919_150523_model_1     0.229256  0.0525583  0.144156    0.181769                 0.0525583
# DeepLearning_grid_1_AutoML_1_20240919_150523_model_1     0.238152  0.0567162  0.148917  nan                        0.0567162
# XGBoost_grid_1_AutoML_1_20240919_150523_model_2          0.239538  0.0573783  0.151629    0.169597                 0.0573783
# XRT_1_AutoML_1_20240919_150523                           0.25017   0.0625852  0.152555    0.171179                 0.0625852
# XGBoost_2_AutoML_1_20240919_150523                       0.252794  0.0639049  0.160494    0.17938                  0.0639049
# XGBoost_grid_1_AutoML_1_20240919_150523_model_1          0.255857  0.0654626  0.160209    0.182128                 0.0654626
# DeepLearning_1_AutoML_1_20240919_150523                  0.259932  0.0675648  0.167709  nan                        0.0675648
# XGBoost_3_AutoML_1_20240919_150523                       0.261675  0.0684738  0.158053    0.184497                 0.0684738
# XGBoost_grid_1_AutoML_1_20240919_150523_model_3          0.264588  0.0700069  0.152499    0.182336                 0.0700069
# XGBoost_1_AutoML_1_20240919_150523                       0.265953  0.0707309  0.167882    0.189398                 0.0707309
# GBM_grid_1_AutoML_1_20240919_150523_model_1              0.291024  0.084695   0.161004    0.196272                 0.084695
# GBM_1_AutoML_1_20240919_150523                           0.304424  0.0926737  0.171354    0.209281                 0.0926737
# DRF_1_AutoML_1_20240919_150523                           0.308898  0.0954177  0.16924     0.212136                 0.0954177
# GBM_2_AutoML_1_20240919_150523                           0.310178  0.0962102  0.171953    0.213106                 0.0962102
# GLM_1_AutoML_1_20240919_150523                           0.310774  0.0965808  0.193349  nan                        0.0965808
# GBM_4_AutoML_1_20240919_150523                           0.313772  0.0984526  0.172598    0.215902                 0.0984526
# GBM_grid_1_AutoML_1_20240919_150523_model_2              0.323355  0.104559   0.178388    0.225408                 0.104559
# GBM_5_AutoML_1_20240919_150523                           0.323986  0.104967   0.178901    0.225704                 0.104967
# GBM_3_AutoML_1_20240919_150523                           0.324777  0.10548    0.179472    0.226556                 0.10548
# [22 rows x 6 columns]

# %%
lb
# Out:
# model_id                                                     rmse        mse       mae       rmsle    mean_residual_deviance
# -------------------------------------------------------  --------  ---------  --------  ----------  ------------------------
# StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_150523  0.218581  0.0477775  0.134714    0.153078                 0.0477775
# DeepLearning_grid_3_AutoML_1_20240919_150523_model_1     0.219308  0.0480962  0.134276    0.154229                 0.0480962
# StackedEnsemble_AllModels_1_AutoML_1_20240919_150523     0.223068  0.0497594  0.13646     0.170783                 0.0497594
# DeepLearning_grid_2_AutoML_1_20240919_150523_model_1     0.229256  0.0525583  0.144156    0.181769                 0.0525583
# DeepLearning_grid_1_AutoML_1_20240919_150523_model_1     0.238152  0.0567162  0.148917  nan                        0.0567162
# XGBoost_grid_1_AutoML_1_20240919_150523_model_2          0.239538  0.0573783  0.151629    0.169597                 0.0573783
# XRT_1_AutoML_1_20240919_150523                           0.25017   0.0625852  0.152555    0.171179                 0.0625852
# XGBoost_2_AutoML_1_20240919_150523                       0.252794  0.0639049  0.160494    0.17938                  0.0639049
# XGBoost_grid_1_AutoML_1_20240919_150523_model_1          0.255857  0.0654626  0.160209    0.182128                 0.0654626
# DeepLearning_1_AutoML_1_20240919_150523                  0.259932  0.0675648  0.167709  nan                        0.0675648
# XGBoost_3_AutoML_1_20240919_150523                       0.261675  0.0684738  0.158053    0.184497                 0.0684738
# XGBoost_grid_1_AutoML_1_20240919_150523_model_3          0.264588  0.0700069  0.152499    0.182336                 0.0700069
# XGBoost_1_AutoML_1_20240919_150523                       0.265953  0.0707309  0.167882    0.189398                 0.0707309
# GBM_grid_1_AutoML_1_20240919_150523_model_1              0.291024  0.084695   0.161004    0.196272                 0.084695
# GBM_1_AutoML_1_20240919_150523                           0.304424  0.0926737  0.171354    0.209281                 0.0926737
# DRF_1_AutoML_1_20240919_150523                           0.308898  0.0954177  0.16924     0.212136                 0.0954177
# GBM_2_AutoML_1_20240919_150523                           0.310178  0.0962102  0.171953    0.213106                 0.0962102
# GLM_1_AutoML_1_20240919_150523                           0.310774  0.0965808  0.193349  nan                        0.0965808
# GBM_4_AutoML_1_20240919_150523                           0.313772  0.0984526  0.172598    0.215902                 0.0984526
# GBM_grid_1_AutoML_1_20240919_150523_model_2              0.323355  0.104559   0.178388    0.225408                 0.104559
# GBM_5_AutoML_1_20240919_150523                           0.323986  0.104967   0.178901    0.225704                 0.104967
# GBM_3_AutoML_1_20240919_150523                           0.324777  0.10548    0.179472    0.226556                 0.10548
# [22 rows x 6 columns]

# %%
lb = h2o.automl.get_leaderboard(aml, extra_columns = "ALL")
lb
# Out:
# model_id                                                     rmse        mse       mae       rmsle    mean_residual_deviance    training_time_ms    predict_time_per_row_ms  algo
# -------------------------------------------------------  --------  ---------  --------  ----------  ------------------------  ------------------  -------------------------  ---------------
# StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_150523  0.218581  0.0477775  0.134714    0.153078                 0.0477775                 996                   0.383737  StackedEnsemble
# DeepLearning_grid_3_AutoML_1_20240919_150523_model_1     0.219308  0.0480962  0.134276    0.154229                 0.0480962               63302                   0.338143  DeepLearning
# StackedEnsemble_AllModels_1_AutoML_1_20240919_150523     0.223068  0.0497594  0.13646     0.170783                 0.0497594                1114                   0.897636  StackedEnsemble
# DeepLearning_grid_2_AutoML_1_20240919_150523_model_1     0.229256  0.0525583  0.144156    0.181769                 0.0525583               54048                   0.297271  DeepLearning
# DeepLearning_grid_1_AutoML_1_20240919_150523_model_1     0.238152  0.0567162  0.148917  nan                        0.0567162               24572                   0.29088   DeepLearning
# XGBoost_grid_1_AutoML_1_20240919_150523_model_2          0.239538  0.0573783  0.151629    0.169597                 0.0573783                 820                   0.057769  XGBoost
# XRT_1_AutoML_1_20240919_150523                           0.25017   0.0625852  0.152555    0.171179                 0.0625852                2689                   0.1066    DRF
# XGBoost_2_AutoML_1_20240919_150523                       0.252794  0.0639049  0.160494    0.17938                  0.0639049                1571                   0.022048  XGBoost
# XGBoost_grid_1_AutoML_1_20240919_150523_model_1          0.255857  0.0654626  0.160209    0.182128                 0.0654626                 861                   0.022703  XGBoost
# DeepLearning_1_AutoML_1_20240919_150523                  0.259932  0.0675648  0.167709  nan                        0.0675648                 824                   0.071821  DeepLearning
# [22 rows x 9 columns]

# %%
# Get the best model using the metric
m = aml.leader
print(m)
# Out:
# Model Details
# =============
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_150523
#
#
# Model Summary for Stacked Ensemble:
# key                                        value
# -----------------------------------------  ----------------
# Stacking strategy                          cross_validation
# Number of base models (used / total)       3/6
# # GBM base models (used / total)           1/1
# # XGBoost base models (used / total)       1/1
# # DeepLearning base models (used / total)  1/1
# # DRF base models (used / total)           0/2
# # GLM base models (used / total)           0/1
# Metalearner algorithm                      GLM
# Metalearner fold assignment scheme         Random
# Metalearner nfolds                         5
# Metalearner fold_column
# Custom metalearner hyperparameters         None
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.0038564116858484207
# RMSE: 0.0621000135736573
# MAE: 0.040516925734947556
# RMSLE: 0.0425916041445282
# Mean Residual Deviance: 0.0038564116858484207
# R^2: 0.9593213911157574
# Null degrees of freedom: 360
# Residual degrees of freedom: 357
# Null deviance: 34.22350608283844
# Residual deviance: 1.39216461859128
# AIC: -971.9709286241841
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.047777488850492614
# RMSE: 0.21858062322743207
# MAE: 0.1347138820541655
# RMSLE: 0.1530775298890127
# Mean Residual Deviance: 0.047777488850492614
# R^2: 0.4960284480123217
# Null degrees of freedom: 360
# Residual degrees of freedom: 356
# Null deviance: 34.56909087427962
# Residual deviance: 17.247673475027835
# AIC: -61.39982990834008
#
# Cross-Validation Metrics Summary:
#                         mean       sd         cv_1_valid    cv_2_valid    cv_3_valid    cv_4_valid    cv_5_valid
# ----------------------  ---------  ---------  ------------  ------------  ------------  ------------  ------------
# aic                     -13.8954   37.0627    46.5599       -24.0984      -8.41661      -50.4969      -33.0252
# loglikelihood           0          0          0             0             0             0             0
# mae                     0.134443   0.0198978  0.162988      0.132025      0.135484      0.106843      0.134877
# mean_residual_deviance  0.0471987  0.0280706  0.0952627     0.0397715     0.0448342     0.0231352     0.0329902
# mse                     0.0471987  0.0280706  0.0952627     0.0397715     0.0448342     0.0231352     0.0329902
# null_deviance           6.91382    3.02859    11.0207       5.29238       6.49765       3.15156       8.60682
# r2                      0.490439   0.138446   0.37293       0.359625      0.521833      0.495863      0.701943
# residual_deviance       3.418      2.0029     6.76365       3.30103       3.09356       1.45752       2.47426
# rmse                    0.21071    0.0591614  0.308646      0.199428      0.211741      0.152103      0.181632
# rmsle                   0.151227   0.0202461  0.17897       0.155698      0.157854      0.126717      0.136898

# %%
# this is equivalent to
m = aml.get_best_model()
print(m)
# Out:
# Model Details
# =============
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_150523
#
#
# Model Summary for Stacked Ensemble:
# key                                        value
# -----------------------------------------  ----------------
# Stacking strategy                          cross_validation
# Number of base models (used / total)       3/6
# # GBM base models (used / total)           1/1
# # XGBoost base models (used / total)       1/1
# # DeepLearning base models (used / total)  1/1
# # DRF base models (used / total)           0/2
# # GLM base models (used / total)           0/1
# Metalearner algorithm                      GLM
# Metalearner fold assignment scheme         Random
# Metalearner nfolds                         5
# Metalearner fold_column
# Custom metalearner hyperparameters         None
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.0038564116858484207
# RMSE: 0.0621000135736573
# MAE: 0.040516925734947556
# RMSLE: 0.0425916041445282
# Mean Residual Deviance: 0.0038564116858484207
# R^2: 0.9593213911157574
# Null degrees of freedom: 360
# Residual degrees of freedom: 357
# Null deviance: 34.22350608283844
# Residual deviance: 1.39216461859128
# AIC: -971.9709286241841
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.047777488850492614
# RMSE: 0.21858062322743207
# MAE: 0.1347138820541655
# RMSLE: 0.1530775298890127
# Mean Residual Deviance: 0.047777488850492614
# R^2: 0.4960284480123217
# Null degrees of freedom: 360
# Residual degrees of freedom: 356
# Null deviance: 34.56909087427962
# Residual deviance: 17.247673475027835
# AIC: -61.39982990834008
#
# Cross-Validation Metrics Summary:
#                         mean       sd         cv_1_valid    cv_2_valid    cv_3_valid    cv_4_valid    cv_5_valid
# ----------------------  ---------  ---------  ------------  ------------  ------------  ------------  ------------
# aic                     -13.8954   37.0627    46.5599       -24.0984      -8.41661      -50.4969      -33.0252
# loglikelihood           0          0          0             0             0             0             0
# mae                     0.134443   0.0198978  0.162988      0.132025      0.135484      0.106843      0.134877
# mean_residual_deviance  0.0471987  0.0280706  0.0952627     0.0397715     0.0448342     0.0231352     0.0329902
# mse                     0.0471987  0.0280706  0.0952627     0.0397715     0.0448342     0.0231352     0.0329902
# null_deviance           6.91382    3.02859    11.0207       5.29238       6.49765       3.15156       8.60682
# r2                      0.490439   0.138446   0.37293       0.359625      0.521833      0.495863      0.701943
# residual_deviance       3.418      2.0029     6.76365       3.30103       3.09356       1.45752       2.47426
# rmse                    0.21071    0.0591614  0.308646      0.199428      0.211741      0.152103      0.181632
# rmsle                   0.151227   0.0202461  0.17897       0.155698      0.157854      0.126717      0.136898

# %%
# Get the best model using a non-default metric
m = aml.get_best_model(criterion="RMSE")
print(m)
# Out:
# Model Details
# =============
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_150523
#
#
# Model Summary for Stacked Ensemble:
# key                                        value
# -----------------------------------------  ----------------
# Stacking strategy                          cross_validation
# Number of base models (used / total)       3/6
# # GBM base models (used / total)           1/1
# # XGBoost base models (used / total)       1/1
# # DeepLearning base models (used / total)  1/1
# # DRF base models (used / total)           0/2
# # GLM base models (used / total)           0/1
# Metalearner algorithm                      GLM
# Metalearner fold assignment scheme         Random
# Metalearner nfolds                         5
# Metalearner fold_column
# Custom metalearner hyperparameters         None
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.0038564116858484207
# RMSE: 0.0621000135736573
# MAE: 0.040516925734947556
# RMSLE: 0.0425916041445282
# Mean Residual Deviance: 0.0038564116858484207
# R^2: 0.9593213911157574
# Null degrees of freedom: 360
# Residual degrees of freedom: 357
# Null deviance: 34.22350608283844
# Residual deviance: 1.39216461859128
# AIC: -971.9709286241841
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.047777488850492614
# RMSE: 0.21858062322743207
# MAE: 0.1347138820541655
# RMSLE: 0.1530775298890127
# Mean Residual Deviance: 0.047777488850492614
# R^2: 0.4960284480123217
# Null degrees of freedom: 360
# Residual degrees of freedom: 356
# Null deviance: 34.56909087427962
# Residual deviance: 17.247673475027835
# AIC: -61.39982990834008
#
# Cross-Validation Metrics Summary:
#                         mean       sd         cv_1_valid    cv_2_valid    cv_3_valid    cv_4_valid    cv_5_valid
# ----------------------  ---------  ---------  ------------  ------------  ------------  ------------  ------------
# aic                     -13.8954   37.0627    46.5599       -24.0984      -8.41661      -50.4969      -33.0252
# loglikelihood           0          0          0             0             0             0             0
# mae                     0.134443   0.0198978  0.162988      0.132025      0.135484      0.106843      0.134877
# mean_residual_deviance  0.0471987  0.0280706  0.0952627     0.0397715     0.0448342     0.0231352     0.0329902
# mse                     0.0471987  0.0280706  0.0952627     0.0397715     0.0448342     0.0231352     0.0329902
# null_deviance           6.91382    3.02859    11.0207       5.29238       6.49765       3.15156       8.60682
# r2                      0.490439   0.138446   0.37293       0.359625      0.521833      0.495863      0.701943
# residual_deviance       3.418      2.0029     6.76365       3.30103       3.09356       1.45752       2.47426
# rmse                    0.21071    0.0591614  0.308646      0.199428      0.211741      0.152103      0.181632
# rmsle                   0.151227   0.0202461  0.17897       0.155698      0.157854      0.126717      0.136898

# %%
# Get AutoML event log
log = aml.event_log
print(log)
# Out:
# timestamp     level    stage       message                                                                                                                                                          name    value
# 15:05:23.734  INFO     Workflow    Project: AutoML_1_20240919_150523
# 15:05:23.737  INFO     Validation  5-fold cross-validation will be used.
# 15:05:23.738  INFO     Validation  Setting stopping tolerance adaptively based on the training frame: 0.05
# 15:05:23.738  INFO     Validation  Build control seed: 1
# 15:05:23.739  INFO     DataImport  training frame: Frame key: AutoML_1_20240919_150523_training_py_1_sid_baac    cols: 149    rows: 361  chunks: 1    size: 425185  checksum: -8570780476728420881
# 15:05:23.739  INFO     DataImport  validation frame: NULL
# 15:05:23.739  INFO     DataImport  leaderboard frame: NULL
# 15:05:23.739  INFO     DataImport  blending frame: NULL
# 15:05:23.739  INFO     DataImport  response column: Success_Open
# 15:05:23.739  INFO     DataImport  fold column: null
# [154 rows x 6 columns]

# %%
# Get training timing info
info = aml.training_info
print(info)
# Out:
# {'creation_epoch': '1726758324', 'start_epoch': '1726758324', 'start_XGBoost_def_2': '1726758324', 'start_GLM_def_1': '1726758351', 'start_GBM_def_5': '1726758367', 'start_XGBoost_def_1': '1726758372', 'start_DRF_def_1': '1726758383', 'start_GBM_def_2': '1726758405', 'start_GBM_def_3': '1726758411', 'start_GBM_def_4': '1726758416', 'start_XGBoost_def_3': '1726758421', 'start_DRF_XRT': '1726758427', 'start_GBM_def_1': '1726758447', 'start_DeepLearning_def_1': '1726758451', 'start_XGBoost_grid_1': '1726758461', 'start_GBM_grid_1': '1726758479', 'start_DeepLearning_grid_1': '1726758486', 'start_DeepLearning_grid_2': '1726758635', 'start_DeepLearning_grid_3': '1726758912', 'start_StackedEnsemble_best_of_family_xglm': '1726759232', 'start_StackedEnsemble_all_xglm': '1726759233', 'stop_epoch': '1726759234', 'duration_secs': '910'}

# %%
aml.leader.model_id
# Out:
# 'StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_150523'

# %%
# xgb = aml.get_best_model(algorithm="xgboost")
# xgb.varimp_plot()

# %%
h2o_test_new = h2o_test.drop(['4_reserves and surplus', 'Retail (Min)_Lots', '2_total borrowing', '2_reserves and surplus', '0_total borrowing', '1_reserves and surplus', '1_total borrowing', '3_reserves and surplus', '0_reserves and surplus', '3_total borrowing', '4_total borrowing'])

# %%
h2o_test_new['S-HNI (Min)_Lots'] = h2o_test_new['S-HNI (Min)_Lots'].asfactor()
h2o_test_new['S-HNI (Min)_Shares'] = h2o_test_new['S-HNI (Min)_Shares'].asfactor()

# %%
h2o_test_new['S-HNI (Max)_Shares'] = h2o_test_new['S-HNI (Max)_Shares'].asfactor()

# %%
h2o_test_new['S-HNI (Min)_Amount'] = h2o_test_new['S-HNI (Min)_Amount'].asfactor()

# %%
h2o_test_new['S-HNI (Max)_Lots' ] = h2o_test_new['S-HNI (Max)_Lots'].asfactor()

# %%
h2o_test_new['S-HNI (Max)_Amount'] = h2o_test_new['S-HNI (Max)_Amount'].asfactor()

# %%
h2o_test_new['B-HNI (Min)_Lots'] = h2o_test_new['B-HNI (Min)_Lots'].ascharacter().asfactor()

# %%
h2o_test_new['Share Holding Pre Issue'] = h2o_test_new['Share Holding Pre Issue'].ascharacter().asfactor()

# %%
cols = ['B-HNI (Min)_Lots', 'B-HNI (Min)_Shares', 'B-HNI (Min)_Amount' , 'Share Holding Post Issue', '0_net worth', '1_net worth', '2_net worth', '3_assets', '3_revenue', '3_net worth', 'S-HNI (Min)_Lots', 'S-HNI (Min)_Lots', 'S-HNI (Min)_Lots', '3_assets']
for col in cols:
  h2o_test_new[col] = h2o_test_new[col].ascharacter().asfactor()

# %%
h2o_test_new['3_assets'] = h2o.H2OFrame(test['3_assets'].to_list()).ascharacter().asfactor() #h2o_test_new['3_assets'].ascharacter().asfactor()
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
# print(h2o_test_new['3_assets'].type)
# print(h2o_train['3_assets'].type)

# %%
#preds = aml.predict(h2o_test)

# %%
test['3_assets'].value_counts()
# Out:
# 3_assets
# 19117.54    1
# 30293.39    1
# 256.05      1
# 123.74      1
# 416.99      1
# 876.38      1
# 792.00      1
# 275.42      1
# 687.20      1
# 457.52      1
# 2462.64     1
# 1097.70     1
# 3572.74     1
# 480.66      1
# 5466.31     1
# 948.25      1
# 426.02      1
# 12338.65    1
# 302.64      1
# 1146.51     1
# 338.11      1
# 9450.66     1
# 1077.86     1
# 5999.13     1
# 692.76      1
# 2633.62     1
# 638.72      1
# 213.98      1
# 6210.92     1
# 5746.44     1
# 369.62      1
# Name: count, dtype: int64

# %%
train['S-HNI (Min)_Lots'].value_counts()
# Out:
# S-HNI (Min)_Lots
# 14.0    20
# 15.0     1
# Name: count, dtype: int64

# %%
#preds

# %%
preds_leader = aml.leader.predict(h2o_test_new)
preds_leader
# Out:
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'day_3_qib' has levels not trained on: ["1.05", "1.28", "5.79", "64.1"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'day_3_nii' has levels not trained on: ["1.52", "1.92", "132.99", "6.49", "64.88", "9.01"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'day_3_retail' has levels not trained on: ["0.55", "16.53", "225.37", "3.14", "4.44", "64.84"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'day_3_total' has levels not trained on: ["0.98", "2.19", "5.35", "5.5", "50.38", "62.83"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'S-HNI (Min)_Lots' has levels not trained on: ["14", "15"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'S-HNI (Min)_Shares' has levels not trained on: ["195", "196", "238", "270", "280", "308", "322", "350", "392", "406", ...25 not listed..., "1950", "2100", "3220", "3500", "3640", "3750", "3878", "5992", "6440", "8400"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'S-HNI (Min)_Amount' has levels not trained on: ["202300", "202860", "203280", "204750", "204820", "205030", "205408", "205800", "206080", "206250", ...18 not listed..., "209160", "209244", "209300", "209412", "209608", "209720", "209916", "210000", "210600", "213300"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'S-HNI (Max)_Lots' has levels not trained on: ["66", "67", "68", "69", "70", "71", "72"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'S-HNI (Max)_Shares' has levels not trained on: ["923", "966", "1173", "1260", "1340", "1360", "1474", "1496", "1541", "1675", ...35 not listed..., "10050", "10200", "15180", "16500", "17420", "18000", "18282", "28248", "30820", "39600"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'S-HNI (Max)_Amount' has levels not trained on: ["986040", "986240", "986436", "986700", "987228", "987360", "988152", "988250", "988680", "988920", ...18 not listed..., "996826", "996840", "997050", "997696", "998032", "998233", "998568", "998970", "999600", "999810"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'B-HNI (Min)_Lots' has levels not trained on: ["67", "68", "69", "70", "71", "72", "73"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'B-HNI (Min)_Shares' has levels not trained on: ["10050", "10200", "10350", "1190", "1278", "1360", "1380", "1496", "1518", "15410", ...35 not listed..., "6120", "7140", "7169", "7200", "7245", "7973", "8442", "936", "9360", "980"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'B-HNI (Min)_Amount' has levels not trained on: ["1000960", "1000980", "1001382", "1001650", "1001880", "1002186", "1003000", "1003124", "1003660", "1003680", ...18 not listed..., "1011296", "1011432", "1011500", "1011704", "1012368", "1012928", "1013132", "1013472", "1013880", "1014300"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Share Holding Pre Issue' has levels not trained on: ["0.3337", "0.3741", "0.4408", "0.4665", "0.4979", "0.5675", "0.5791", "0.6642", "0.6666", "0.6679", ...21 not listed..., "0.918", "0.9284", "0.9523", "0.9642", "0.9749", "0.978", "0.9859", "0.993", "0.9935", "1"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Share Holding Post Issue' has levels not trained on: ["0.3019", "0.3534", "0.4091", "0.416", "0.4408", "0.4817", "0.5124", "0.5366", "0.5539", "0.5547", ...21 not listed..., "0.7494", "0.7495", "0.7497", "0.7545", "0.765", "0.7859", "0.792", "0.8561", "64.46", "78.06"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '0_net worth' has levels not trained on: ["-259.28", "-93.07", "1019.5", "104.57", "1103.33", "113.61", "1226.56", "123.49", "1374.97", "1414.9", ...23 not listed..., "56.58", "638.26", "6580.61", "725.68", "752.09", "810.79", "86.11", "875.07", "88.58", "999.37"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '1_net worth' has levels not trained on: ["-206.87", "-702.63", "100.93", "1033.38", "1103.22", "1240.53", "1336.58", "1355.68", "1368.35", "137.4", ...23 not listed..., "65.97", "665.73", "681.49", "71.39", "71.46", "75.2", "760.21", "92.47", "944.72", "988.31"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '2_net worth' has levels not trained on: ["-352.22", "-871.43", "100.49", "1026.78", "106.05", "107.25", "1076.13", "115.45", "1153.52", "1237.05", ...23 not listed..., "5268.11", "560.71", "631.91", "70.03", "705.62", "714", "72.46", "787.62", "86.22", "889.89"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '3_assets' has levels not trained on: ["1077.86", "1097.7", "1146.51", "123.74", "12338.65", "19117.54", "213.98", "2462.64", "256.05", "2633.62", ...11 not listed..., "5746.44", "5999.13", "6210.92", "638.72", "687.2", "692.76", "792", "876.38", "9450.66", "948.25"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '3_revenue' has levels not trained on: ["10311.01", "1059.58", "107.71", "1178.62", "125.03", "1567.77", "1585.88", "1768.42", "2031.3", "2069.58", ...11 not listed..., "402.59", "408.79", "412.03", "472.1", "543.28", "5633.64", "590.81", "608.99", "697.57", "740.36"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '3_net worth' has levels not trained on: ["-1765.14", "100.96", "114.09", "116.89", "117.6", "1352.06", "1390.47", "144.78", "1466.88", "192.33", ...10 not listed..., "375.76", "3934.64", "47.54", "487.83", "55.55", "622.23", "645.16", "723.55", "834.73", "937.27"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '4_assets' has levels not trained on: ["1082.82", "267.16", "485.97"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '4_revenue' has levels not trained on: ["166.13", "510.21", "523.1"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '4_profit after tax' has levels not trained on: ["19.24", "21.07", "65.77"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '4_net worth' has levels not trained on: ["182.96", "363.65", "74.74"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Industry' has levels not trained on: ["Computer Peripherals", "Integrated Oil", "Office Equipment/Supplies"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Fresh Issue' has levels not trained on: ["1,700,680 shares (aggregating up to 75.00 Cr)", "1,739,131 shares (aggregating up to 180.00 Cr)", "10,000,000 shares (aggregating up to 100.00 Cr)", "10,200,000 shares (aggregating up to 66.30 Cr)", "10,800,000 shares (aggregating up to 545.40 Cr)", "10,890,000 shares (aggregating up to 152.46 Cr)", "11,111,111 shares (aggregating up to 400.00 Cr)", "11,268,580 shares (aggregating up to 365.00 Cr)", "12,280,701 shares (aggregating up to 350.00 Cr)", "13,200,158 shares (aggregating up to 71.28 Cr)", ...27 not listed..., "6,930,806 shares (aggregating up to 146.24 Cr)", "65,116,667 shares (aggregating up to 390.70 Cr)", "7,142,857 shares (aggregating up to 320.00 Cr)", "7,339,450 shares (aggregating up to 320.00 Cr)", "7,374,163 shares (aggregating up to 542.00 Cr)", "8,517,350 shares (aggregating up to 270.00 Cr)", "8,520,000 shares (aggregating up to 119.28 Cr)", "9,605,263 shares (aggregating up to 292.00 Cr)", "9,767,442 shares (aggregating up to 210.00 Cr)", "95,238,095 shares (aggregating up to 1,200.00 Cr)"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Offer for Sale' has levels not trained on: ["10,449,816 shares of 1 (aggregating up to 171.38 Cr)", "10,759,493 shares of 10 (aggregating up to 850.00 Cr)", "11,756,910 shares of 2 (aggregating up to 198.69 Cr)", "12,050,000 shares of 10 (aggregating up to 72.30 Cr)", "12,183,099 shares of 1 (aggregating up to 173.00 Cr)", "12,500,000 shares of 2 (aggregating up to 545.00 Cr)", "13,500,000 shares of 1 (aggregating up to 170.10 Cr)", "14,213,198 shares of 1 (aggregating up to 280.00 Cr)", "17,236,808 shares of 5 (aggregating up to 1,784.01 Cr)", "17,500,000 shares of 2 (aggregating up to 189.00 Cr)", ...25 not listed..., "7,159,920 shares of 2 (aggregating up to 608.59 Cr)", "8,000,000 shares of 10 (aggregating up to 240.00 Cr)", "8,113,590 shares of 5 (aggregating up to 400.00 Cr)", "8,294,118 shares of 10 (aggregating up to 175.00 Cr)", "8,500,000 shares of 2 (aggregating up to 425.00 Cr)", "9,000,000 shares of 10 (aggregating up to 256.50 Cr)", "9,428,178 shares of 10 (aggregating up to 415.78 Cr)", "9,541,985 shares of 2 (aggregating up to 500.00 Cr)", "9,901,315 shares of 5 (aggregating up to 301.00 Cr)", "[.] shares of 10 (aggregating up to 425.00 Cr)"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Price Band' has levels not trained on: ["102 to 108 per share", "1026 to 1080 per share", "113 to 119 per share", "119 to 126 per share", "133 to 140 per share", "135 to 142 per share", "151 to 166 per share", "156 to 164 per share", "160 to 169 per share", "187 to 197 per share", ...30 not listed..., "617 to 648 per share", "627 to 660 per share", "638 to 672 per share", "695 to 735 per share", "705 to 741 per share", "750 to 790 per share", "808 to 850 per share", "93 to 98 per share", "95 to 100 per share", "983 to 1035 per share"]
#   warnings.warn(w)
#    predict
# ----------
# 0.103573
# 0.0184811
# 0.00517963
# 0.0848333
# 0.0390137
# 0.0742108
# 0.350102
# 0.0854038
# 0.489567
# 0.983638
# [57 rows x 1 column]

# %%
best_model = aml.get_best_model()
model_path = h2o.save_model(model=best_model, path="/content/drive/MyDrive/datasets/Indian_IPO_Prediction/h2o_best_stacked_model_" + save_path_name, force=True)
print(model_path)
# Out:
# /content/drive/MyDrive/datasets/Indian_IPO_Prediction/h2o_best_stacked_model__Undepricing_Success_Open_Numeric_Only/StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_150523

# %%
#loaded_model = h2o.load_model("path/to/save/model/model_filename")

# %%
performance = best_model.model_performance(test_data=h2o_test_new)

# %%
print("MAE:", performance.mae())
print("RMSE:", performance.rmse())
print("MSE:", performance.mse())
# Out:
# MAE: 0.17108379094908796
# RMSE: 0.23826889558495393
# MSE: 0.05677206660327368

# %%
for model_id in lb['model_id'].as_data_frame()['model_id']:
    model = h2o.get_model(model_id)
    performance = model.model_performance(test_data=h2o_test_new)
    print(f"Performance for model {model_id}:")
    print("MAE:", performance.mae())
    print(f"RMSE: {performance.rmse()}")
    print(f"MSE: {performance.mse()}")
    print("\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/h2o/frame.py:1981: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# Performance for model StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_150523:
# MAE: 0.17108379094908796
# RMSE: 0.23826889558495393
# MSE: 0.05677206660327368
#
#
# Performance for model DeepLearning_grid_3_AutoML_1_20240919_150523_model_1:
# MAE: 0.1845171636234547
# RMSE: 0.2566571018527629
# MSE: 0.06587286793145951
#
#
# Performance for model StackedEnsemble_AllModels_1_AutoML_1_20240919_150523:
# MAE: 0.1934542661848376
# RMSE: 0.2691118570767545
# MSE: 0.07242119161929955
#
#
# Performance for model DeepLearning_grid_2_AutoML_1_20240919_150523_model_1:
# MAE: 0.2272067729676541
# RMSE: 0.30754684564291834
# MSE: 0.09458506226490905
#
#
# Performance for model DeepLearning_grid_1_AutoML_1_20240919_150523_model_1:
# MAE: 0.2732224125758932
# RMSE: 0.41788461445060066
# MSE: 0.17462755099452715
#
#
# Performance for model XGBoost_grid_1_AutoML_1_20240919_150523_model_2:
# MAE: 0.23063100449610174
# RMSE: 0.28923526990292214
# MSE: 0.08365704135581623
#
#
# Performance for model XRT_1_AutoML_1_20240919_150523:
# MAE: 0.19158355091202234
# RMSE: 0.2544442600522022
# MSE: 0.0647418814735127
#
#
# Performance for model XGBoost_2_AutoML_1_20240919_150523:
# MAE: 0.40335026902979926
# RMSE: 0.5019836530123869
# MSE: 0.2519875878916604
#
#
# Performance for model XGBoost_grid_1_AutoML_1_20240919_150523_model_1:
# MAE: 0.3404502103007154
# RMSE: 0.4097958556970028
# MSE: 0.16793264334643873
#
#
# Performance for model DeepLearning_1_AutoML_1_20240919_150523:
# MAE: 0.27378560163019067
# RMSE: 0.3527034849688172
# MSE: 0.12439974830914866
#
#
# Performance for model XGBoost_3_AutoML_1_20240919_150523:
# MAE: 0.24722535210547217
# RMSE: 0.3231761606060182
# MSE: 0.10444283078404687
#
#
# Performance for model XGBoost_grid_1_AutoML_1_20240919_150523_model_3:
# MAE: 0.406368845322153
# RMSE: 0.5641168176835444
# MSE: 0.31822778399340923
#
#
# Performance for model XGBoost_1_AutoML_1_20240919_150523:
# MAE: 0.37720335523287457
# RMSE: 0.46457846825214066
# MSE: 0.21583315316350526
#
#
# Performance for model GBM_grid_1_AutoML_1_20240919_150523_model_1:
# MAE: 0.23061290013132119
# RMSE: 0.33964086645307295
# MSE: 0.11535591816499413
#
#
# Performance for model GBM_1_AutoML_1_20240919_150523:
# MAE: 0.222788976157128
# RMSE: 0.3163084139765634
# MSE: 0.10005101275236902
#
#
# Performance for model DRF_1_AutoML_1_20240919_150523:
# MAE: 0.24695712094836839
# RMSE: 0.3623805665754409
# MSE: 0.13131967503153752
#
#
# Performance for model GBM_2_AutoML_1_20240919_150523:
# MAE: 0.2503201250798047
# RMSE: 0.37292401386338364
# MSE: 0.13907232011597717
#
#
# Performance for model GLM_1_AutoML_1_20240919_150523:
# MAE: 0.2084513413223215
# RMSE: 0.28178213179290057
# MSE: 0.07940116979775158
#
#
# Performance for model GBM_4_AutoML_1_20240919_150523:
# MAE: 0.2532212788686957
# RMSE: 0.3770888236440837
# MSE: 0.14219598091727886
#
#
# Performance for model GBM_grid_1_AutoML_1_20240919_150523_model_2:
# MAE: 0.2780052220951066
# RMSE: 0.4001548918894118
# MSE: 0.16012393750302684
#
#
# Performance for model GBM_5_AutoML_1_20240919_150523:
# MAE: 0.2741365085194928
# RMSE: 0.3962510228247343
# MSE: 0.1570148730896481
#
#
# Performance for model GBM_3_AutoML_1_20240919_150523:
# MAE: 0.2726051656675563
# RMSE: 0.39721609947202147
# MSE: 0.15778062967976686

# %%
for model_id in lb['model_id'].as_data_frame()['model_id']:
    model = h2o.get_model(model_id)
    hyperparameters = model.get_params()
    print(f"Hyperparameters for model {model_id}:")
    print(hyperparameters)
    print("\n")
# Out:
# Hyperparameters for model StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_150523:
# {'model_id': None, 'training_frame': None, 'response_column': None, 'validation_frame': None, 'blending_frame': None, 'base_models': [], 'metalearner_algorithm': 'auto', 'metalearner_nfolds': 0, 'metalearner_fold_assignment': None, 'metalearner_fold_column': None, 'metalearner_params': None, 'metalearner_transform': 'none', 'max_runtime_secs': 0.0, 'weights_column': None, 'offset_column': None, 'custom_metric_func': None, 'seed': -1, 'score_training_samples': 10000, 'keep_levelone_frame': False, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'gainslift_bins': -1}
#
#
# Hyperparameters for model DeepLearning_grid_3_AutoML_1_20240919_150523_model_1:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'score_each_iteration': False, 'weights_column': None, 'offset_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'checkpoint': None, 'pretrained_autoencoder': None, 'overwrite_with_best_model': True, 'use_all_factor_levels': True, 'standardize': True, 'activation': 'rectifier', 'hidden': [200, 200], 'epochs': 10.0, 'train_samples_per_iteration': -2, 'target_ratio_comm_to_comp': 0.05, 'seed': -1, 'adaptive_rate': True, 'rho': 0.99, 'epsilon': 1e-08, 'rate': 0.005, 'rate_annealing': 1e-06, 'rate_decay': 1.0, 'momentum_start': 0.0, 'momentum_ramp': 1000000.0, 'momentum_stable': 0.0, 'nesterov_accelerated_gradient': True, 'input_dropout_ratio': 0.0, 'hidden_dropout_ratios': None, 'l1': 0.0, 'l2': 0.0, 'max_w2': 3.4028235e+38, 'initial_weight_distribution': 'uniform_adaptive', 'initial_weight_scale': 1.0, 'initial_weights': None, 'initial_biases': None, 'loss': 'automatic', 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'score_interval': 5.0, 'score_training_samples': 10000, 'score_validation_samples': 0, 'score_duty_cycle': 0.1, 'classification_stop': 0.0, 'regression_stop': 1e-06, 'stopping_rounds': 5, 'stopping_metric': 'auto', 'stopping_tolerance': 0.0, 'max_runtime_secs': 0.0, 'score_validation_sampling': 'uniform', 'diagnostics': True, 'fast_mode': True, 'force_load_balance': True, 'variable_importances': True, 'replicate_training_data': True, 'single_node_mode': False, 'shuffle_training_data': False, 'missing_values_handling': 'mean_imputation', 'quiet_mode': False, 'autoencoder': False, 'sparse': False, 'col_major': False, 'average_activation': 0.0, 'sparsity_beta': 0.0, 'max_categorical_features': 2147483647, 'reproducible': False, 'export_weights_and_biases': False, 'mini_batch_size': 1, 'categorical_encoding': 'auto', 'elastic_averaging': False, 'elastic_averaging_moving_rate': 0.9, 'elastic_averaging_regularization': 0.001, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'custom_metric_func': None, 'gainslift_bins': -1}
#
#
# Hyperparameters for model StackedEnsemble_AllModels_1_AutoML_1_20240919_150523:
# {'model_id': None, 'training_frame': None, 'response_column': None, 'validation_frame': None, 'blending_frame': None, 'base_models': [], 'metalearner_algorithm': 'auto', 'metalearner_nfolds': 0, 'metalearner_fold_assignment': None, 'metalearner_fold_column': None, 'metalearner_params': None, 'metalearner_transform': 'none', 'max_runtime_secs': 0.0, 'weights_column': None, 'offset_column': None, 'custom_metric_func': None, 'seed': -1, 'score_training_samples': 10000, 'keep_levelone_frame': False, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'gainslift_bins': -1}
# /usr/local/lib/python3.10/dist-packages/h2o/frame.py:1981: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# Hyperparameters for model DeepLearning_grid_2_AutoML_1_20240919_150523_model_1:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'score_each_iteration': False, 'weights_column': None, 'offset_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'checkpoint': None, 'pretrained_autoencoder': None, 'overwrite_with_best_model': True, 'use_all_factor_levels': True, 'standardize': True, 'activation': 'rectifier', 'hidden': [200, 200], 'epochs': 10.0, 'train_samples_per_iteration': -2, 'target_ratio_comm_to_comp': 0.05, 'seed': -1, 'adaptive_rate': True, 'rho': 0.99, 'epsilon': 1e-08, 'rate': 0.005, 'rate_annealing': 1e-06, 'rate_decay': 1.0, 'momentum_start': 0.0, 'momentum_ramp': 1000000.0, 'momentum_stable': 0.0, 'nesterov_accelerated_gradient': True, 'input_dropout_ratio': 0.0, 'hidden_dropout_ratios': None, 'l1': 0.0, 'l2': 0.0, 'max_w2': 3.4028235e+38, 'initial_weight_distribution': 'uniform_adaptive', 'initial_weight_scale': 1.0, 'initial_weights': None, 'initial_biases': None, 'loss': 'automatic', 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'score_interval': 5.0, 'score_training_samples': 10000, 'score_validation_samples': 0, 'score_duty_cycle': 0.1, 'classification_stop': 0.0, 'regression_stop': 1e-06, 'stopping_rounds': 5, 'stopping_metric': 'auto', 'stopping_tolerance': 0.0, 'max_runtime_secs': 0.0, 'score_validation_sampling': 'uniform', 'diagnostics': True, 'fast_mode': True, 'force_load_balance': True, 'variable_importances': True, 'replicate_training_data': True, 'single_node_mode': False, 'shuffle_training_data': False, 'missing_values_handling': 'mean_imputation', 'quiet_mode': False, 'autoencoder': False, 'sparse': False, 'col_major': False, 'average_activation': 0.0, 'sparsity_beta': 0.0, 'max_categorical_features': 2147483647, 'reproducible': False, 'export_weights_and_biases': False, 'mini_batch_size': 1, 'categorical_encoding': 'auto', 'elastic_averaging': False, 'elastic_averaging_moving_rate': 0.9, 'elastic_averaging_regularization': 0.001, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'custom_metric_func': None, 'gainslift_bins': -1}
#
#
# Hyperparameters for model DeepLearning_grid_1_AutoML_1_20240919_150523_model_1:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'score_each_iteration': False, 'weights_column': None, 'offset_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'checkpoint': None, 'pretrained_autoencoder': None, 'overwrite_with_best_model': True, 'use_all_factor_levels': True, 'standardize': True, 'activation': 'rectifier', 'hidden': [200, 200], 'epochs': 10.0, 'train_samples_per_iteration': -2, 'target_ratio_comm_to_comp': 0.05, 'seed': -1, 'adaptive_rate': True, 'rho': 0.99, 'epsilon': 1e-08, 'rate': 0.005, 'rate_annealing': 1e-06, 'rate_decay': 1.0, 'momentum_start': 0.0, 'momentum_ramp': 1000000.0, 'momentum_stable': 0.0, 'nesterov_accelerated_gradient': True, 'input_dropout_ratio': 0.0, 'hidden_dropout_ratios': None, 'l1': 0.0, 'l2': 0.0, 'max_w2': 3.4028235e+38, 'initial_weight_distribution': 'uniform_adaptive', 'initial_weight_scale': 1.0, 'initial_weights': None, 'initial_biases': None, 'loss': 'automatic', 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'score_interval': 5.0, 'score_training_samples': 10000, 'score_validation_samples': 0, 'score_duty_cycle': 0.1, 'classification_stop': 0.0, 'regression_stop': 1e-06, 'stopping_rounds': 5, 'stopping_metric': 'auto', 'stopping_tolerance': 0.0, 'max_runtime_secs': 0.0, 'score_validation_sampling': 'uniform', 'diagnostics': True, 'fast_mode': True, 'force_load_balance': True, 'variable_importances': True, 'replicate_training_data': True, 'single_node_mode': False, 'shuffle_training_data': False, 'missing_values_handling': 'mean_imputation', 'quiet_mode': False, 'autoencoder': False, 'sparse': False, 'col_major': False, 'average_activation': 0.0, 'sparsity_beta': 0.0, 'max_categorical_features': 2147483647, 'reproducible': False, 'export_weights_and_biases': False, 'mini_batch_size': 1, 'categorical_encoding': 'auto', 'elastic_averaging': False, 'elastic_averaging_moving_rate': 0.9, 'elastic_averaging_regularization': 0.001, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'custom_metric_func': None, 'gainslift_bins': -1}
#
#
# Hyperparameters for model XGBoost_grid_1_AutoML_1_20240919_150523_model_2:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'distribution': 'auto', 'tweedie_power': 1.5, 'categorical_encoding': 'auto', 'quiet_mode': True, 'checkpoint': None, 'export_checkpoints_dir': None, 'custom_metric_func': None, 'ntrees': 50, 'max_depth': 6, 'min_rows': 1.0, 'min_child_weight': 1.0, 'learn_rate': 0.3, 'eta': 0.3, 'sample_rate': 1.0, 'subsample': 1.0, 'col_sample_rate': 1.0, 'colsample_bylevel': 1.0, 'col_sample_rate_per_tree': 1.0, 'colsample_bytree': 1.0, 'colsample_bynode': 1.0, 'max_abs_leafnode_pred': 0.0, 'max_delta_step': 0.0, 'monotone_constraints': None, 'interaction_constraints': None, 'score_tree_interval': 0, 'min_split_improvement': 0.0, 'gamma': 0.0, 'nthread': -1, 'save_matrix_directory': None, 'build_tree_one_node': False, 'parallelize_cross_validation': True, 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'max_bins': 256, 'max_leaves': 0, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.0, 'one_drop': False, 'skip_drop': 0.0, 'tree_method': 'auto', 'grow_policy': 'depthwise', 'booster': 'gbtree', 'reg_lambda': 1.0, 'reg_alpha': 0.0, 'dmatrix_type': 'auto', 'backend': 'auto', 'gpu_id': None, 'gainslift_bins': -1, 'auc_type': 'auto', 'scale_pos_weight': 1.0, 'eval_metric': None, 'score_eval_metric_only': False}
#
#
# Hyperparameters for model XRT_1_AutoML_1_20240919_150523:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 20, 'min_rows': 1.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'mtries': -1, 'sample_rate': 0.632, 'sample_rate_per_class': None, 'binomial_double_trees': False, 'checkpoint': None, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'distribution': 'auto', 'custom_metric_func': None, 'export_checkpoints_dir': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto'}
#
#
# Hyperparameters for model XGBoost_2_AutoML_1_20240919_150523:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'distribution': 'auto', 'tweedie_power': 1.5, 'categorical_encoding': 'auto', 'quiet_mode': True, 'checkpoint': None, 'export_checkpoints_dir': None, 'custom_metric_func': None, 'ntrees': 50, 'max_depth': 6, 'min_rows': 1.0, 'min_child_weight': 1.0, 'learn_rate': 0.3, 'eta': 0.3, 'sample_rate': 1.0, 'subsample': 1.0, 'col_sample_rate': 1.0, 'colsample_bylevel': 1.0, 'col_sample_rate_per_tree': 1.0, 'colsample_bytree': 1.0, 'colsample_bynode': 1.0, 'max_abs_leafnode_pred': 0.0, 'max_delta_step': 0.0, 'monotone_constraints': None, 'interaction_constraints': None, 'score_tree_interval': 0, 'min_split_improvement': 0.0, 'gamma': 0.0, 'nthread': -1, 'save_matrix_directory': None, 'build_tree_one_node': False, 'parallelize_cross_validation': True, 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'max_bins': 256, 'max_leaves': 0, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.0, 'one_drop': False, 'skip_drop': 0.0, 'tree_method': 'auto', 'grow_policy': 'depthwise', 'booster': 'gbtree', 'reg_lambda': 1.0, 'reg_alpha': 0.0, 'dmatrix_type': 'auto', 'backend': 'auto', 'gpu_id': None, 'gainslift_bins': -1, 'auc_type': 'auto', 'scale_pos_weight': 1.0, 'eval_metric': None, 'score_eval_metric_only': False}
#
#
# Hyperparameters for model XGBoost_grid_1_AutoML_1_20240919_150523_model_1:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'distribution': 'auto', 'tweedie_power': 1.5, 'categorical_encoding': 'auto', 'quiet_mode': True, 'checkpoint': None, 'export_checkpoints_dir': None, 'custom_metric_func': None, 'ntrees': 50, 'max_depth': 6, 'min_rows': 1.0, 'min_child_weight': 1.0, 'learn_rate': 0.3, 'eta': 0.3, 'sample_rate': 1.0, 'subsample': 1.0, 'col_sample_rate': 1.0, 'colsample_bylevel': 1.0, 'col_sample_rate_per_tree': 1.0, 'colsample_bytree': 1.0, 'colsample_bynode': 1.0, 'max_abs_leafnode_pred': 0.0, 'max_delta_step': 0.0, 'monotone_constraints': None, 'interaction_constraints': None, 'score_tree_interval': 0, 'min_split_improvement': 0.0, 'gamma': 0.0, 'nthread': -1, 'save_matrix_directory': None, 'build_tree_one_node': False, 'parallelize_cross_validation': True, 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'max_bins': 256, 'max_leaves': 0, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.0, 'one_drop': False, 'skip_drop': 0.0, 'tree_method': 'auto', 'grow_policy': 'depthwise', 'booster': 'gbtree', 'reg_lambda': 1.0, 'reg_alpha': 0.0, 'dmatrix_type': 'auto', 'backend': 'auto', 'gpu_id': None, 'gainslift_bins': -1, 'auc_type': 'auto', 'scale_pos_weight': 1.0, 'eval_metric': None, 'score_eval_metric_only': False}
#
#
# Hyperparameters for model DeepLearning_1_AutoML_1_20240919_150523:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'score_each_iteration': False, 'weights_column': None, 'offset_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'checkpoint': None, 'pretrained_autoencoder': None, 'overwrite_with_best_model': True, 'use_all_factor_levels': True, 'standardize': True, 'activation': 'rectifier', 'hidden': [200, 200], 'epochs': 10.0, 'train_samples_per_iteration': -2, 'target_ratio_comm_to_comp': 0.05, 'seed': -1, 'adaptive_rate': True, 'rho': 0.99, 'epsilon': 1e-08, 'rate': 0.005, 'rate_annealing': 1e-06, 'rate_decay': 1.0, 'momentum_start': 0.0, 'momentum_ramp': 1000000.0, 'momentum_stable': 0.0, 'nesterov_accelerated_gradient': True, 'input_dropout_ratio': 0.0, 'hidden_dropout_ratios': None, 'l1': 0.0, 'l2': 0.0, 'max_w2': 3.4028235e+38, 'initial_weight_distribution': 'uniform_adaptive', 'initial_weight_scale': 1.0, 'initial_weights': None, 'initial_biases': None, 'loss': 'automatic', 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'score_interval': 5.0, 'score_training_samples': 10000, 'score_validation_samples': 0, 'score_duty_cycle': 0.1, 'classification_stop': 0.0, 'regression_stop': 1e-06, 'stopping_rounds': 5, 'stopping_metric': 'auto', 'stopping_tolerance': 0.0, 'max_runtime_secs': 0.0, 'score_validation_sampling': 'uniform', 'diagnostics': True, 'fast_mode': True, 'force_load_balance': True, 'variable_importances': True, 'replicate_training_data': True, 'single_node_mode': False, 'shuffle_training_data': False, 'missing_values_handling': 'mean_imputation', 'quiet_mode': False, 'autoencoder': False, 'sparse': False, 'col_major': False, 'average_activation': 0.0, 'sparsity_beta': 0.0, 'max_categorical_features': 2147483647, 'reproducible': False, 'export_weights_and_biases': False, 'mini_batch_size': 1, 'categorical_encoding': 'auto', 'elastic_averaging': False, 'elastic_averaging_moving_rate': 0.9, 'elastic_averaging_regularization': 0.001, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'custom_metric_func': None, 'gainslift_bins': -1}
#
#
# Hyperparameters for model XGBoost_3_AutoML_1_20240919_150523:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'distribution': 'auto', 'tweedie_power': 1.5, 'categorical_encoding': 'auto', 'quiet_mode': True, 'checkpoint': None, 'export_checkpoints_dir': None, 'custom_metric_func': None, 'ntrees': 50, 'max_depth': 6, 'min_rows': 1.0, 'min_child_weight': 1.0, 'learn_rate': 0.3, 'eta': 0.3, 'sample_rate': 1.0, 'subsample': 1.0, 'col_sample_rate': 1.0, 'colsample_bylevel': 1.0, 'col_sample_rate_per_tree': 1.0, 'colsample_bytree': 1.0, 'colsample_bynode': 1.0, 'max_abs_leafnode_pred': 0.0, 'max_delta_step': 0.0, 'monotone_constraints': None, 'interaction_constraints': None, 'score_tree_interval': 0, 'min_split_improvement': 0.0, 'gamma': 0.0, 'nthread': -1, 'save_matrix_directory': None, 'build_tree_one_node': False, 'parallelize_cross_validation': True, 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'max_bins': 256, 'max_leaves': 0, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.0, 'one_drop': False, 'skip_drop': 0.0, 'tree_method': 'auto', 'grow_policy': 'depthwise', 'booster': 'gbtree', 'reg_lambda': 1.0, 'reg_alpha': 0.0, 'dmatrix_type': 'auto', 'backend': 'auto', 'gpu_id': None, 'gainslift_bins': -1, 'auc_type': 'auto', 'scale_pos_weight': 1.0, 'eval_metric': None, 'score_eval_metric_only': False}
#
#
# Hyperparameters for model XGBoost_grid_1_AutoML_1_20240919_150523_model_3:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'distribution': 'auto', 'tweedie_power': 1.5, 'categorical_encoding': 'auto', 'quiet_mode': True, 'checkpoint': None, 'export_checkpoints_dir': None, 'custom_metric_func': None, 'ntrees': 50, 'max_depth': 6, 'min_rows': 1.0, 'min_child_weight': 1.0, 'learn_rate': 0.3, 'eta': 0.3, 'sample_rate': 1.0, 'subsample': 1.0, 'col_sample_rate': 1.0, 'colsample_bylevel': 1.0, 'col_sample_rate_per_tree': 1.0, 'colsample_bytree': 1.0, 'colsample_bynode': 1.0, 'max_abs_leafnode_pred': 0.0, 'max_delta_step': 0.0, 'monotone_constraints': None, 'interaction_constraints': None, 'score_tree_interval': 0, 'min_split_improvement': 0.0, 'gamma': 0.0, 'nthread': -1, 'save_matrix_directory': None, 'build_tree_one_node': False, 'parallelize_cross_validation': True, 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'max_bins': 256, 'max_leaves': 0, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.0, 'one_drop': False, 'skip_drop': 0.0, 'tree_method': 'auto', 'grow_policy': 'depthwise', 'booster': 'gbtree', 'reg_lambda': 1.0, 'reg_alpha': 0.0, 'dmatrix_type': 'auto', 'backend': 'auto', 'gpu_id': None, 'gainslift_bins': -1, 'auc_type': 'auto', 'scale_pos_weight': 1.0, 'eval_metric': None, 'score_eval_metric_only': False}
#
#
# Hyperparameters for model XGBoost_1_AutoML_1_20240919_150523:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'distribution': 'auto', 'tweedie_power': 1.5, 'categorical_encoding': 'auto', 'quiet_mode': True, 'checkpoint': None, 'export_checkpoints_dir': None, 'custom_metric_func': None, 'ntrees': 50, 'max_depth': 6, 'min_rows': 1.0, 'min_child_weight': 1.0, 'learn_rate': 0.3, 'eta': 0.3, 'sample_rate': 1.0, 'subsample': 1.0, 'col_sample_rate': 1.0, 'colsample_bylevel': 1.0, 'col_sample_rate_per_tree': 1.0, 'colsample_bytree': 1.0, 'colsample_bynode': 1.0, 'max_abs_leafnode_pred': 0.0, 'max_delta_step': 0.0, 'monotone_constraints': None, 'interaction_constraints': None, 'score_tree_interval': 0, 'min_split_improvement': 0.0, 'gamma': 0.0, 'nthread': -1, 'save_matrix_directory': None, 'build_tree_one_node': False, 'parallelize_cross_validation': True, 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'max_bins': 256, 'max_leaves': 0, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.0, 'one_drop': False, 'skip_drop': 0.0, 'tree_method': 'auto', 'grow_policy': 'depthwise', 'booster': 'gbtree', 'reg_lambda': 1.0, 'reg_alpha': 0.0, 'dmatrix_type': 'auto', 'backend': 'auto', 'gpu_id': None, 'gainslift_bins': -1, 'auc_type': 'auto', 'scale_pos_weight': 1.0, 'eval_metric': None, 'score_eval_metric_only': False}
#
#
# Hyperparameters for model GBM_grid_1_AutoML_1_20240919_150523_model_1:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}
#
#
# Hyperparameters for model GBM_1_AutoML_1_20240919_150523:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}
#
#
# Hyperparameters for model DRF_1_AutoML_1_20240919_150523:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 20, 'min_rows': 1.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'mtries': -1, 'sample_rate': 0.632, 'sample_rate_per_class': None, 'binomial_double_trees': False, 'checkpoint': None, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'distribution': 'auto', 'custom_metric_func': None, 'export_checkpoints_dir': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto'}
#
#
# Hyperparameters for model GBM_2_AutoML_1_20240919_150523:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}
#
#
# Hyperparameters for model GLM_1_AutoML_1_20240919_150523:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'checkpoint': None, 'export_checkpoints_dir': None, 'seed': -1, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'random_columns': None, 'ignore_const_cols': True, 'score_each_iteration': False, 'score_iteration_interval': -1, 'offset_column': None, 'weights_column': None, 'family': 'auto', 'rand_family': None, 'tweedie_variance_power': 0.0, 'tweedie_link_power': 1.0, 'theta': 1e-10, 'solver': 'auto', 'alpha': None, 'lambda': None, 'lambda_search': False, 'early_stopping': True, 'nlambdas': -1, 'standardize': True, 'missing_values_handling': 'mean_imputation', 'plug_values': None, 'compute_p_values': False, 'dispersion_parameter_method': 'pearson', 'init_dispersion_parameter': 1.0, 'remove_collinear_columns': False, 'intercept': True, 'non_negative': False, 'max_iterations': -1, 'objective_epsilon': -1.0, 'beta_epsilon': 0.0001, 'gradient_epsilon': -1.0, 'link': 'family_default', 'rand_link': None, 'startval': None, 'calc_like': False, 'HGLM': False, 'prior': -1.0, 'cold_start': False, 'lambda_min_ratio': -1.0, 'max_active_predictors': -1, 'interactions': None, 'interaction_pairs': None, 'obj_reg': -1.0, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'max_runtime_secs': 0.0, 'custom_metric_func': None, 'generate_scoring_history': False, 'auc_type': 'auto', 'dispersion_epsilon': 0.0001, 'tweedie_epsilon': 8e-17, 'max_iterations_dispersion': 3000, 'build_null_model': False, 'fix_dispersion_parameter': False, 'generate_variable_inflation_factors': False, 'fix_tweedie_variance_power': True, 'dispersion_learning_rate': 0.5, 'influence': None, 'gainslift_bins': -1, 'linear_constraints': None, 'init_optimal_glm': False, 'separate_linear_beta': False, 'constraint_eta0': 0.1258925, 'constraint_tau': 10.0, 'constraint_alpha': 0.1, 'constraint_beta': 0.9, 'constraint_c0': 10.0}
#
#
# Hyperparameters for model GBM_4_AutoML_1_20240919_150523:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}
#
#
# Hyperparameters for model GBM_grid_1_AutoML_1_20240919_150523_model_2:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}
#
#
# Hyperparameters for model GBM_5_AutoML_1_20240919_150523:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}
#
#
# Hyperparameters for model GBM_3_AutoML_1_20240919_150523:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}

# %%
model = aml.get_best_model()
hyperparameters = model.get_params()
print("Hyperparameters for the best model:")
print(hyperparameters)
print("\n")
# Out:
# Hyperparameters for the best model:
# {'model_id': None, 'training_frame': None, 'response_column': None, 'validation_frame': None, 'blending_frame': None, 'base_models': [], 'metalearner_algorithm': 'auto', 'metalearner_nfolds': 0, 'metalearner_fold_assignment': None, 'metalearner_fold_column': None, 'metalearner_params': None, 'metalearner_transform': 'none', 'max_runtime_secs': 0.0, 'weights_column': None, 'offset_column': None, 'custom_metric_func': None, 'seed': -1, 'score_training_samples': 10000, 'keep_levelone_frame': False, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'gainslift_bins': -1}

# %%
# import h2o
# h2o.init()

# %%
# best_model_loaded = h2o.load_model("/content/drive/MyDrive/datasets/Indian_IPO_Prediction/h2o_best_stacked_model__Undepricing_Success_Open_Numeric_Only/DeepLearning_grid_1_AutoML_2_20240913_23840_model_1")
# hyperparameters = best_model_loaded.get_params()
# print("Hyperparameters for the best model:")
# print(hyperparameters)
# print("\n")
