# %%
import pandas as pd

# %%
data = pd.read_excel('main_data_with_indics_nifty50daily_weekly_monthly_vix_daily_weekly_monthly.xlsx')
data.shape

# %%
data.head()
# Out:
#    mapping_key                                                url  \
# 0            0  https://www.chittorgarh.com/ipo/infibeam_ipo/532/
# 1            1  https://www.chittorgarh.com/ipo/route-mobile-i...
# 2            2  https://www.chittorgarh.com/ipo/valiant-labora...
# 3            3  https://www.chittorgarh.com/ipo/irm-energy-ipo...
# 4            4  https://www.chittorgarh.com/ipo/bse-limited-ip...
#
#                      Issuer Company     Open Date    Close Date  Listing Date  \
# 0    Infibeam Incorporation Ltd IPO  Mar 21, 2016  Mar 23, 2016           NaN
# 1              Route Mobile Ltd IPO  Sep 09, 2020  Sep 11, 2020  Sep 21, 2020
# 2  Valiant Laboratories Limited IPO  Sep 27, 2023  Oct 03, 2023  Oct 06, 2023
# 3            IRM Energy Limited IPO  Oct 18, 2023  Oct 20, 2023  Oct 26, 2023
# 4                   BSE Limited IPO  Jan 23, 2017  Jan 25, 2017  Feb 03, 2017
#
#   Issue Price (Rs) Issue Size (Rs Cr.) Lot Size  Exchange  ...  \
# ...

# %%
data.columns
# Out:
# Index(['mapping_key', 'url', 'Issuer Company', 'Open Date', 'Close Date',
#        'Listing Date', 'Issue Price (Rs)', 'Issue Size (Rs Cr.)', 'Lot Size',
#        'Exchange',
#        ...
#        'Chg%_vix_weekly', 'week', 'Price_vix_monthly', 'Open_vix_monthly',
#        'High_vix_monthly', 'Low_vix_monthly', 'Volume_vix_monthly',
#        'Chg%_vix_monthly', 'month', 'year'],
#       dtype='object', length=102)

# %%
data['year'].value_counts()
# Out:
# year
# 2010.0    63
# 2023.0    62
# 2021.0    60
# 2017.0    40
# 2022.0    39
# 2011.0    38
# 2016.0    27
# 2009.0    27
# 2018.0    23
# 2015.0    22
# 2020.0    20
# 2008.0    19
# 2024.0    19
# 2019.0    15
# 2012.0    13
# 2014.0     7
# 2013.0     5
# Name: count, dtype: int64

# %%
data['year'].min()
# Out:
# 2008.0

# %%
pd.isnull(data['year']).value_counts()
# Out:
# year
# False    499
# True     199
# Name: count, dtype: int64

# %%
data[pd.isnull(data['year'])]
# Out:
#      mapping_key                                                url  \
# 10            10  https://www.chittorgarh.com/ipo/insecticides_i...
# 13            13  https://www.chittorgarh.com/ipo/simplex_projec...
# 14            14  https://www.chittorgarh.com/ipo/sita_shree_ipo...
# 16            16  https://www.chittorgarh.com/ipo/powergrid-invi...
# 21            21      https://www.chittorgarh.com/ipo/minar_ipo/12/
# ..           ...                                                ...
# 681          681  https://www.chittorgarh.com/ipo/asahi_songwon_...
# 685          685    https://www.chittorgarh.com/ipo/cinemax_ipo/42/
# 690          690  https://www.chittorgarh.com/ipo/nissan_copper_...
# 694          694  https://www.chittorgarh.com/ipo/abhishek_mills...
# 696          696  https://www.chittorgarh.com/ipo/amd_metplast_i...
#
#                        Issuer Company     Open Date    Close Date  \
# 10         Insecticides India Ltd IPO  May 07, 2007  May 11, 2007
# ...

# %%
# Remove 2024 data as world bank economic indicators we have till 2022. Considering 2022 as the previous year, we can consider ipo data till 2023
# Remove years before 2009 i.e. till 2008, as vix data is not present
# Remove the ones with FPO


# No value for creating y-vaiable
# Coluumns with all zero or constant values


# For the folowing data was not crawled from chittorgarh. Thus, removing these
# https://www.chittorgarh.com/ipo/powergrid-invit-ipo-april-2021/1110/
# https://www.chittorgarh.com/ipo/brookfield-india-reit/1082/
# https://www.chittorgarh.com/ipo/mindspace-business-reit/1051/
# https://www.chittorgarh.com/ipo/embassy-office-parks/971/
# https://www.chittorgarh.com/ipo/nexus-select-trust-reit/1417/

# %%
data[data['year'].isin(list(range(2009,2024,1)))].shape
# Out:
# (461, 102)

# %%
data_use = data[data['year'].isin(list(range(2009,2024,1)))]
data_use
# Out:
#      mapping_key                                                url  \
# 0              0  https://www.chittorgarh.com/ipo/infibeam_ipo/532/
# 1              1  https://www.chittorgarh.com/ipo/route-mobile-i...
# 2              2  https://www.chittorgarh.com/ipo/valiant-labora...
# 3              3  https://www.chittorgarh.com/ipo/irm-energy-ipo...
# 4              4  https://www.chittorgarh.com/ipo/bse-limited-ip...
# ..           ...                                                ...
# 691          691  https://www.chittorgarh.com/ipo/rites-limited-...
# 692          692  https://www.chittorgarh.com/ipo/indian-energy-...
# 693          693   https://www.chittorgarh.com/ipo/muthoot_ipo/300/
# 695          695  https://www.chittorgarh.com/ipo/greensignal-bi...
# 697          697  https://www.chittorgarh.com/ipo/c_mahendra_ipo...
#
#                        Issuer Company     Open Date    Close Date  \
# 0      Infibeam Incorporation Ltd IPO  Mar 21, 2016  Mar 23, 2016
# ...

# %%
data_use.shape
# Out:
# (461, 102)

# %%
data_use[data_use['url'].apply(lambda x : 'fpo' in str(x))]
# Out:
# Empty DataFrame
# ...

# %%
data_use[data_use['url'].apply(lambda x : 'ipo' in str(x))].shape
# Out:
# (461, 102)

# %%
'BSE_Open' in data_use.columns
# Out:
# True

# %%
for col in ['price_info', 'BSE_Open', 'NSE_Open', 'BSE_Low', 'NSE_Low', 'BSE_High', 'NSE_High']:
  print(col, pd.isnull(data_use[col]).value_counts())
# Out:
# price_info price_info
# False    461
# Name: count, dtype: int64
# BSE_Open BSE_Open
# False    439
# True      22
# Name: count, dtype: int64
# NSE_Open NSE_Open
# False    426
# True      35
# Name: count, dtype: int64
# BSE_Low BSE_Low
# False    439
# True      22
# Name: count, dtype: int64
# NSE_Low NSE_Low
# False    426
# True      35
# Name: count, dtype: int64
# BSE_High BSE_High
# False    439
# True      22
# Name: count, dtype: int64
# NSE_High NSE_High
# False    426
# True      35
# Name: count, dtype: int64

# %%
for col in ['price_info',  'NSE_Open', 'NSE_Low',  'NSE_High']:
  print(col, pd.isnull(data_use[col]).value_counts())
# Out:
# price_info price_info
# False    461
# Name: count, dtype: int64
# NSE_Open NSE_Open
# False    426
# True      35
# Name: count, dtype: int64
# NSE_Low NSE_Low
# False    426
# True      35
# Name: count, dtype: int64
# NSE_High NSE_High
# False    426
# True      35
# Name: count, dtype: int64

# %%
data_use_filter = data_use[(~pd.isnull(data_use['NSE_Open'])) & (data_use['Exchange']!='BSE') & (~pd.isnull(data_use['subscription_info'])) & (data_use['Close Year']<2024)]
data_use_filter.shape
# Out:
# (418, 102)

# %%
for col in ['price_info',  'NSE_Open', 'NSE_Low',  'NSE_High']:
  print(col, pd.isnull(data_use_filter[col]).value_counts())
# Out:
# price_info price_info
# False    418
# Name: count, dtype: int64
# NSE_Open NSE_Open
# False    418
# Name: count, dtype: int64
# NSE_Low NSE_Low
# False    418
# Name: count, dtype: int64
# NSE_High NSE_High
# False    418
# Name: count, dtype: int64

# %%
data_use_filter
# Out:
#      mapping_key                                                url  \
# 0              0  https://www.chittorgarh.com/ipo/infibeam_ipo/532/
# 1              1  https://www.chittorgarh.com/ipo/route-mobile-i...
# 2              2  https://www.chittorgarh.com/ipo/valiant-labora...
# 3              3  https://www.chittorgarh.com/ipo/irm-energy-ipo...
# 4              4  https://www.chittorgarh.com/ipo/bse-limited-ip...
# ..           ...                                                ...
# 689          689  https://www.chittorgarh.com/ipo/heranba-indust...
# 691          691  https://www.chittorgarh.com/ipo/rites-limited-...
# 692          692  https://www.chittorgarh.com/ipo/indian-energy-...
# 693          693   https://www.chittorgarh.com/ipo/muthoot_ipo/300/
# 697          697  https://www.chittorgarh.com/ipo/c_mahendra_ipo...
#
#                        Issuer Company     Open Date    Close Date  \
# 0      Infibeam Incorporation Ltd IPO  Mar 21, 2016  Mar 23, 2016
# ...

# %%
data_use_filter['lot_size_headers']
# Out:
# 0      ['Application', 'Lots', 'Shares', 'Amount']
# 1      ['Application', 'Lots', 'Shares', 'Amount']
# 2      ['Application', 'Lots', 'Shares', 'Amount']
# 3      ['Application', 'Lots', 'Shares', 'Amount']
# 4      ['Application', 'Lots', 'Shares', 'Amount']
#                           ...
# 689    ['Application', 'Lots', 'Shares', 'Amount']
# 691    ['Application', 'Lots', 'Shares', 'Amount']
# 692    ['Application', 'Lots', 'Shares', 'Amount']
# 693    ['Application', 'Lots', 'Shares', 'Amount']
# 697    ['Application', 'Lots', 'Shares', 'Amount']
# Name: lot_size_headers, Length: 418, dtype: object

# %%
for col in data_use_filter.columns:
  if data_use_filter[col].nunique()<2:
    print(col)
# Out:
# Others
# Policyholder
# lot_size_headers
# Volume_vix_daily
# Volume_vix_weekly
# Volume_vix_monthly

# %%
cols_to_remove = ['Others',
'Policyholder',
'lot_size_headers',
'Volume_vix_daily',
'Volume_vix_weekly',
'Volume_vix_monthly', 'year_x', 'year_y']

# %%
list(data_use_filter.columns)
# Out:
# ['mapping_key',
#  'url',
#  'Issuer Company',
#  'Open Date',
#  'Close Date',
#  'Listing Date',
#  'Issue Price (Rs)',
#  'Issue Size (Rs Cr.)',
#  'Lot Size',
#  'Exchange',
#  'subscription_link',
#  'subscription_info',
#  'price_info',
#  'Date',
#  'QIB',
#  'NII',
#  'Retail',
#  'Total',
#  'EMP',
#  'bNII (bids above ₹10L)',
#  'sNII (bids below ₹10L)',
#  'RII',
#  'Others',
#  'Other',
#  'Policyholder',
#  'NSE_symbol',
#  'BSE_Final_Issue_Price',
#  'NSE_Final_Issue_Price',
#  'BSE_Open',
#  'NSE_Open',
#  'BSE_Low',
#  'NSE_Low',
#  'BSE_High',
#  'NSE_High',
#  'BSE_Last_Trade',
#  'NSE_Last_Trade',
#  'Total_subscriptions',
#  'elasticity',
#  'lot_size_headers',
#  'lot_size_rows',
#  'full_text_content',
#  'Close Year',
#  'Close Year Previous',
#  'year_x',
#  'GDP per capita growth (annual %)',
#  'GDP growth (annual %)',
#  'GDP (current US$)',
#  'Unemployment, total (% of total labor force) (modeled ILO estimate)',
# ...

# %%
cols_use = [i for i in data_use_filter.columns if i not in cols_to_remove]

# %%
data_use_filter[cols_use]
# Out:
#      mapping_key                                                url  \
# 0              0  https://www.chittorgarh.com/ipo/infibeam_ipo/532/
# 1              1  https://www.chittorgarh.com/ipo/route-mobile-i...
# 2              2  https://www.chittorgarh.com/ipo/valiant-labora...
# 3              3  https://www.chittorgarh.com/ipo/irm-energy-ipo...
# 4              4  https://www.chittorgarh.com/ipo/bse-limited-ip...
# ..           ...                                                ...
# 689          689  https://www.chittorgarh.com/ipo/heranba-indust...
# 691          691  https://www.chittorgarh.com/ipo/rites-limited-...
# 692          692  https://www.chittorgarh.com/ipo/indian-energy-...
# 693          693   https://www.chittorgarh.com/ipo/muthoot_ipo/300/
# 697          697  https://www.chittorgarh.com/ipo/c_mahendra_ipo...
#
#                        Issuer Company     Open Date    Close Date  \
# 0      Infibeam Incorporation Ltd IPO  Mar 21, 2016  Mar 23, 2016
# ...

# %%
data_use_filter[cols_use].to_excel('main_data_with_indics_nifty50daily_weekly_monthly_vix_daily_weekly_monthly_FITERED_CLEANED.xlsx', index = False)

# %%
# Missing Value of 'lot_size_rows' populate by visiting website for the
# https://www.chittorgarh.com/ipo/indigrid-invit-fund/661/
# https://www.chittorgarh.com/ipo/prataap-snacks/707/


# Missing Value of 'Listing Date' populate by visisting website
# 'Listing Date'

# %%
import requests
from bs4 import BeautifulSoup

# %%
lili=[]
for link in ['https://www.chittorgarh.com/ipo/raj_oil_mills_ipo/198/','https://www.chittorgarh.com/ipo/tecpro_ipo/269/','https://www.chittorgarh.com/ipo/indigrid-invit-fund/661/','https://www.chittorgarh.com/ipo/mep_infrastructure_ipo/467/','https://www.chittorgarh.com/ipo/aqua_logistics_ipo/216/','https://www.chittorgarh.com/ipo/syngene_international_ipo/481/','https://www.chittorgarh.com/ipo/srs_ipo/320/','https://www.chittorgarh.com/ipo/ufo_moviez_ipo/468/','https://www.chittorgarh.com/ipo/quess_corp_ipo/552/','https://www.chittorgarh.com/ipo/pnc_infratech_ipo/469/','https://www.chittorgarh.com/ipo/equitas_holdings_ipo/536/','https://www.chittorgarh.com/ipo/jindal_cotex_ipo/202/','https://www.chittorgarh.com/ipo/bharatiya
arh.com/ipo/shilpi_cables_ipo/299/','https://www.chittorgarh.com/ipo/inox_wind_ipo/438/','https://www.chittorgarh.com/ipo/flexituff_ipo/329/','https://www.chittorgarh.com/ipo/sharda_cropchem_ipo/430/','https://www.chittorgarh.com/ipo/nhpc_ipo/200/','https://www.chittorgarh.com/ipo/indosolar_ipo/260/','https://www.chittorgarh.com/ipo/rites-limited-ipo/886/','https://www.chittorgarh.com/ipo/indian-energy-exchange-iex-ipo/746/','https://www.chittorgarh.com/ipo/muthoot_ipo/300/','https://www.chittorgarh.com/ipo/c_mahendra_ipo/290/']:
  reqs = requests.get(link)
  soup = BeautifulSoup(reqs.text, 'html.parser')
  table = soup.find('table', attrs={'class':'table table-bordered table-striped table-hover w-auto'})
  table_body = table.find('tbody')

  rows = table_body.find_all('td')
  for i in range(len(rows)):
    if rows[i].text == 'Listing Date':
      lili.append([link,rows[i+1].text])
      break

# %%
link = 'https://www.chittorgarh.com/ipo/raj_oil_mills_ipo/198/'
reqs = requests.get(link)
soup = BeautifulSoup(reqs.text, 'html.parser')

# %%
table
# Out:
# <table class="table table-bordered table-striped table-hover w-auto">
# <tbody>
# <tr>
# <td>IPO Date</td>
# <td>July 20, 2009 to July 23, 2009</td>
# </tr>
# <tr>
# <td>Listing Date</td>
# <td>August 12, 2009</td>
# </tr>
# <tr>
# <td>Face Value</td>
# <td>₹10 per share</td>
# </tr>
# <tr>
# <td>Price Band</td>
# <td>₹100 to ₹120 per share</td>
# </tr>
# <tr>
# <td>Lot Size</td>
# <td>50 Shares</td>
# </tr>
# <tr><td>Total Issue Size</td><td>9,500,000 shares <br/>(aggregating up to ₹114.00 Cr)</td></tr>
# <tr>
# <td>Issue Type</td>
# <td>Book Built Issue IPO</td>
# </tr>
# <tr>
# <td>Listing At</td>
# <td>BSE, NSE</td>
# </tr>
# </tbody>
# </table>

# %%
table_body = table.find('tbody')

rows = table_body.find_all('td')
for i in range(len(rows)):
  if rows[i].text == 'Listing Date':
    print(rows[i+1].text)
    break
# Out:
# August 12, 2009

# %%
pd.DataFrame(lili, columns = ['links', 'listing_date'])
# Out:
#                                                  links        listing_date
# 0    https://www.chittorgarh.com/ipo/raj_oil_mills_...     August 12, 2009
# 1      https://www.chittorgarh.com/ipo/tecpro_ipo/269/    October 12, 2010
# 2    https://www.chittorgarh.com/ipo/indigrid-invit...        June 6, 2017
# 3    https://www.chittorgarh.com/ipo/mep_infrastruc...         May 6, 2015
# 4    https://www.chittorgarh.com/ipo/aqua_logistics...   February 23, 2010
# ..                                                 ...                 ...
# 161  https://www.chittorgarh.com/ipo/indosolar_ipo/...  September 29, 2010
# 162  https://www.chittorgarh.com/ipo/rites-limited-...        July 2, 2018
# 163  https://www.chittorgarh.com/ipo/indian-energy-...    October 23, 2017
# 164   https://www.chittorgarh.com/ipo/muthoot_ipo/300/         May 6, 2011
# 165  https://www.chittorgarh.com/ipo/c_mahendra_ipo...    January 20, 2011
#
# [166 rows x 2 columns]

# %%
pd.DataFrame(lili, columns = ['links', 'listing_date']).to_csv('missing_listing_date.csv', index = False)

# %%
final_data = pd.read_excel('main_data_with_indics_nifty50daily_weekly_monthly_vix_daily_weekly_monthly_FITERED_CLEANED_v2.xlsx')
final_data

# %%
final_data['Listing Date'] = final_data['Listing Date'].apply(lambda x : str(x).split()[0][:3]+ ' ' + ' '.join(str(x).split()[1:]) if len(str(x).split()[0])>3 else str(x))

# %%
final_data.to_excel('main_data_with_indics_nifty50daily_weekly_monthly_vix_daily_weekly_monthly_FITERED_CLEANED_v3.xlsx', index = False)

# %%
final_data = pd.read_excel('main_data_with_indics_nifty50daily_weekly_monthly_vix_daily_weekly_monthly_FITERED_CLEANED_v3.xlsx')
final_data.shape
# Out:
# (418, 94)

# %%
final_data.columns
# Out:
# Index(['mapping_key', 'url', 'Issuer Company', 'Open Date', 'Close Date',
#        'Listing Date', 'Issue Price (Rs)', 'Issue Size (Rs Cr.)', 'Lot Size',
#        'Exchange', 'subscription_link', 'subscription_info', 'price_info',
#        'Date', 'QIB', 'NII', 'Retail', 'Total', 'EMP',
#        'bNII (bids above ₹10L)', 'sNII (bids below ₹10L)', 'RII', 'Other',
#        'NSE_symbol', 'BSE_Final_Issue_Price', 'NSE_Final_Issue_Price',
#        'BSE_Open', 'NSE_Open', 'BSE_Low', 'NSE_Low', 'BSE_High', 'NSE_High',
#        'BSE_Last_Trade', 'NSE_Last_Trade', 'Total_subscriptions', 'elasticity',
#        'lot_size_rows', 'full_text_content', 'Close Year',
#        'Close Year Previous', 'GDP per capita growth (annual %)',
#        'GDP growth (annual %)', 'GDP (current US$)',
#        'Unemployment, total (% of total labor force) (modeled ILO estimate)',
#        'Stocks traded, total value (% of GDP)',
#        'Personal remittances, received (% of GDP)',
# ...

# %%
lili=[]
for link in final_data['url'].to_list():
  reqs = requests.get(link)
  soup = BeautifulSoup(reqs.text, 'html.parser')

# %%
link = final_data['url'].to_list()[0]
reqs = requests.get(link)
soup = BeautifulSoup(reqs.text, 'html.parser')

# %%
link
# Out:
# 'https://www.chittorgarh.com/ipo/infibeam_ipo/532/'

# %%
final_data['url'].to_list()[90]
# Out:
# 'https://www.chittorgarh.com/ipo/tree_house_ipo/321/'

# %%
final_data
# Out:
#      mapping_key                                                url  \
# 0              0  https://www.chittorgarh.com/ipo/infibeam_ipo/532/
# 1              1  https://www.chittorgarh.com/ipo/route-mobile-i...
# 2              2  https://www.chittorgarh.com/ipo/valiant-labora...
# 3              3  https://www.chittorgarh.com/ipo/irm-energy-ipo...
# 4              4  https://www.chittorgarh.com/ipo/bse-limited-ip...
# ..           ...                                                ...
# 413          689  https://www.chittorgarh.com/ipo/heranba-indust...
# 414          691  https://www.chittorgarh.com/ipo/rites-limited-...
# 415          692  https://www.chittorgarh.com/ipo/indian-energy-...
# 416          693   https://www.chittorgarh.com/ipo/muthoot_ipo/300/
# 417          697  https://www.chittorgarh.com/ipo/c_mahendra_ipo...
#
#                        Issuer Company     Open Date    Close Date  \
# 0      Infibeam Incorporation Ltd IPO  Mar 21, 2016  Mar 23, 2016
# ...

# %%
final_data['url'].nunique()
# Out:
# 418

# %%
final_data['Issuer Company'].nunique()
# Out:
# 418

# %%
final_data['Issuer Company'].apply(lambda x : str(x).replace(' IPO', '').lower().strip()).nunique()
# Out:
# 418

# %% [markdown]
# # For SME

# %%
import pandas as pd

final_data = pd.read_excel('sme_data_with_indics_nifty50daily_weekly_monthly_vix_daily_weekly_monthly_filter_out_2024_picked_price_removed_currency_symbol_recent_performance_flattened_tables.xlsx').head(690)
final_data
# Out:
#      Unnamed: 0  Unnamed: 0.2  Unnamed: 0.1  mapping_key  \
# 0             0         619.0         721.0          906
# 1             1         127.0         144.0          190
# 2             2         534.0         624.0          793
# 3             3          77.0          89.0          124
# 4             4         507.0         592.0          750
# ..          ...           ...           ...          ...
# 685         685         302.0         355.0          451
# 686         686         239.0         277.0          351
# 687         687         438.0         519.0          659
# 688         688         683.0         794.0          993
# 689         689          49.0          57.0           75
#
#                                                  links  \
# 0    https://www.chittorgarh.com/ipo/nitiraj-engine...
# 1    https://www.chittorgarh.com/ipo/sanginita-chem...
# 2    https://www.chittorgarh.com/ipo/rmc-switchgear...
# ...

# %%
industry_info = pd.read_csv('India_PLC_Sector_Industry_2024_MAY.csv')
industry_info['Description'] = industry_info['Description'].apply(lambda x : str(x).lower().strip())
industry_info
# Out:
#                          Description               Sector  \
# 0                digicontent limited  Commercial Services
# 1     prismx global ventures limited  Commercial Services
# 2     integrated capital services lt  Commercial Services
# 3     dj mediaprint & logistics limi  Commercial Services
# 4     humming bird education limited  Commercial Services
# ...                              ...                  ...
# 6485               utiamc - nifitetf                  NaN
# 6486          aurum proptech limited                  NaN
# 6487              piramal enterprise                  NaN
# 6488              indiabulls housing                  NaN
# 6489        nippon india mutual fund                  NaN
#
#                                Industry Exchange
# 0             Commercial Printing/Forms      BSE
# 1     Miscellaneous Commercial Services      BSE
# 2     Miscellaneous Commercial Services      BSE
# 3             Commercial Printing/Forms      BSE
# ...

# %%
from difflib import get_close_matches
get_close_matches('appel', ['ape', 'apple', 'peach', 'puppy'], n = 1)
# Out:
# ['apple']

# %%
company_industry_list = industry_info['Description'].to_list()

# %%
final_data['Issuer Company'] = final_data['subscription_link'].apply(lambda x : str(x).split('/')[-3].lower().replace('ipo', '').replace('-', ' ').strip())

# %%
matching_company = []
for company in final_data['Issuer Company']:
  company = company.replace(' IPO', '').lower().strip()
  try:
    match = get_close_matches(company, company_industry_list, n = 1)[0]
  except:
    match = ''
  matching_company.append(match)

# %%
df = pd.DataFrame({'Issuer Company' : final_data['Issuer Company'], 'Description' : matching_company})
df_industry = df.merge(industry_info, on = 'Description')
df_industry
# Out:
#                         Issuer Company                     Description  \
# 0                    nitiraj engineers           nitiraj engineers ltd
# 1                  sanginita chemicals         sanginita chemicals ltd
# 2                      rmc switchgears         rmc switchgears limited
# 3                 shri ram switchgears         rmc switchgears limited
# 4                 akash infra projects        akash infra-projects ltd
# ..                                 ...                             ...
# 638             aik pipes and polymers  aik pipes and polymers limited
# 639                      manoj ceramic           manoj ceramic limited
# 640                  hrh next services               hrh next services
# 641  akanksha power and infrastructure  tinna rubber and infrastructur
# 642            balaji valve components  shri balaji valve components l
#
#                      Sector                          Industry Exchange
# ...

# %%
df_industry.to_csv('industry_match_automatic_SME.csv', index = False)

# %%
df_industry_manual = pd.read_csv('SME_industry_match_manually_verified.csv')

# %%
df_industry_manual
# Out:
#                         Issuer Company                  Sector  \
# 0                    nitiraj engineers   Electronic Technology
# 1                  sanginita chemicals      Process Industries
# 2                      rmc switchgears  Producer Manufacturing
# 3                 shri ram switchgears  Producer Manufacturing
# 4                 akash infra projects     Industrial Services
# ..                                 ...                     ...
# 630             aik pipes and polymers  Producer Manufacturing
# 631                      manoj ceramic            Retail Trade
# 632                  hrh next services       Consumer Services
# 633  akanksha power and infrastructure      Process Industries
# 634            balaji valve components  Producer Manufacturing
#
#                              Industry
# 0    Electronic Equipment/Instruments
# 1                Chemicals: Specialty
# 2                 Electrical Products
# 3                 Electrical Products
# ...

# %%
final_data_with_industry = final_data.merge(df_industry_manual, on = 'Issuer Company', how = 'left').rename(columns = {'Description':'Company Name'})

# %%
final_data_with_industry
# Out:
#      Unnamed: 0  Unnamed: 0.2  Unnamed: 0.1  mapping_key  \
# 0             0         619.0         721.0          906
# 1             1         127.0         144.0          190
# 2             2         534.0         624.0          793
# 3             3          77.0          89.0          124
# 4             4         507.0         592.0          750
# ..          ...           ...           ...          ...
# 699         685         302.0         355.0          451
# 700         686         239.0         277.0          351
# 701         687         438.0         519.0          659
# 702         688         683.0         794.0          993
# 703         689          49.0          57.0           75
#
#                                                  links  \
# 0    https://www.chittorgarh.com/ipo/nitiraj-engine...
# 1    https://www.chittorgarh.com/ipo/sanginita-chem...
# 2    https://www.chittorgarh.com/ipo/rmc-switchgear...
# ...

# %%
del final_data_with_industry['Unnamed: 0']
del final_data_with_industry['Unnamed: 0.1']
del final_data_with_industry['Unnamed: 0.2']

# %%
final_data_with_industry
# Out:
#      mapping_key                                              links  \
# 0            906  https://www.chittorgarh.com/ipo/nitiraj-engine...
# 1            190  https://www.chittorgarh.com/ipo/sanginita-chem...
# 2            793  https://www.chittorgarh.com/ipo/rmc-switchgear...
# 3            124  https://www.chittorgarh.com/ipo/akash-infra-pr...
# 4            750  https://www.chittorgarh.com/ipo/ifl-enterprise...
# ..           ...                                                ...
# 699          451  https://www.chittorgarh.com/ipo/aik-pipes-and-...
# 700          351  https://www.chittorgarh.com/ipo/manoj-ceramic-...
# 701          659  https://www.chittorgarh.com/ipo/hrh-next-servi...
# 702          993  https://www.chittorgarh.com/ipo/akanksha-power...
# 703           75  https://www.chittorgarh.com/ipo/balaji-valve-c...
#
#                                      subscription_link  \
# 0    https://www.chittorgarh.com/ipo_subscription/n...
# ...

# %%
final_data_with_industry.to_excel('SME_data_final_v3.xlsx', index = False)
