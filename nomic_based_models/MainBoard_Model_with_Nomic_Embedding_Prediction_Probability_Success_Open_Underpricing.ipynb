# %%
import pandas as pd
import numpy as np
import pickle

# %%
text_features = ['full_text_content', 'full_text_context_with_news', 'answer_of_question_1',	'answer_of_question_2',	'answer_of_question_3','answer_of_question_4','answer_of_question_5','answer_of_question_6','answer_of_question_7','answer_of_question_8','answer_of_question_9','answer_of_question_10','answer_of_question_11','answer_of_question_12','answer_of_question_13','answer_of_question_14','answer_of_question_15','answer_of_question_16','answer_of_question_17','answer_of_question_18','answer_of_question_19','answer_of_question_20','answer_of_question_21','answer_of_question_22','answer_of_question_23','answer_of_question_24','answer_of_question_25']

# %%
# !pip install -q h2o
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.6/265.6 MB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for h2o (setup.py) ... done

# %%
import h2o
from h2o.automl import H2OAutoML

# Start the H2O cluster (locally)
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.24" 2024-07-16; OpenJDK Runtime Environment (build 11.0.24+8-post-Ubuntu-1ubuntu322.04); OpenJDK 64-Bit Server VM (build 11.0.24+8-post-Ubuntu-1ubuntu322.04, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.10/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmph__0dn5b
#   JVM stdout: /tmp/tmph__0dn5b/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmph__0dn5b/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------------------------------------------------------------------
# H2O_cluster_uptime:         07 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.5
# H2O_cluster_version_age:    21 days, 3 hours and 24 minutes
# H2O_cluster_name:           H2O_from_python_unknownUser_oisy44
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.170 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null, "colab_language_server": "/usr/colab/bin/language_service"}
# H2O_internal_security:      False
# Python_version:             3.10.12 final
# --------------------------  -----------------------------------------------------------------------------------------

# %%
numeric_features = ['Final_Issue_Price',
 'Issue Size (Rs Cr.)',
 'Lot Size',
 'GDP per capita growth (annual %)',
 'GDP growth (annual %)',
 'GDP (current US$)',
 'Unemployment, total (% of total labor force) (modeled ILO estimate)',
 'Stocks traded, total value (% of GDP)',
 'Personal remittances, received (% of GDP)',
 'Net trade in goods and services (BoP, current US$)',
 'GNI per capita growth (annual %)',
 'Inflation, consumer prices (annual %)',
 'GNI (current US$)',
 'Foreign direct investment, net inflows (BoP, current US$)',
 'Foreign direct investment, net (BoP, current US$)',
 'Price_nifty50_daily',
 'Open_nifty50_daily',
 'High_nifty50_daily',
 'Low_nifty50_daily',
 'Volume_nifty50_daily',
 'Chg%_nifty50_daily',
 'Price_nifty50_weekly',
 'Open_nifty50_weekly',
 'High_nifty50_weekly',
 'Low_nifty50_weekly',
 'Volume_nifty50_weekly',
 'Chg%_nifty50_weekly',
 'Price_nifty50_monthly',
 'Open_nifty50_monthly',
 'High_nifty50_monthly',
 'Low_nifty50_monthly',
 'Volume_nifty50_monthly',
 'Chg%_nifty50_monthly',
 'Price_vix_daily',
 'Open_vix_daily',
 'High_vix_daily',
 'Low_vix_daily',
 'Chg%_vix_daily',
 'Price_vix_weekly',
 'Open_vix_weekly',
 'High_vix_weekly',
 'Low_vix_weekly',
 'Chg%_vix_weekly',
 'Price_vix_monthly',
 'Open_vix_monthly',
 'High_vix_monthly',
 'Low_vix_monthly',
 'Chg%_vix_monthly',
 'previous_quarter_success_open',
 'previous_quarter_success_close',
 'previous_quarter_success_high',
 'dynamic_last_90Day_success_open',
 'dynamic_last_90Day_success_close',
 'dynamic_last_90Day_success_high',
 'day_1_qib',
 'day_1_nii',
 'day_1_retail',
 'day_1_total',
 'day_2_qib',
 'day_2_nii',
 'day_2_retail',
 'day_2_total',
 'day_3_qib',
 'day_3_nii',
 'day_3_retail',
 'day_3_total',
 'day_4_qib',
 'day_4_nii',
 'day_4_retail',
 'day_4_total',
 'day_5_qib',
 'day_5_nii',
 'day_5_retail',
 'day_5_total',
 'day_6_qib',
 'day_6_nii',
 'day_6_retail',
 'day_6_total',
 'Brokers_Subscribe',
 'Brokers_Neutral',
 'Brokers_Avoid',
 'Members_Subscribe',
 'Members_Neutral',
 'Members_Avoid',
 'Face Value per share',
 'Retail (Min)_Lots',
 'Retail (Min)_Shares',
 'Retail (Min)_Amount',
 'Retail (Max)_Lots',
 'Retail (Max)_Shares',
 'Retail (Max)_Amount',
 'S-HNI (Min)_Lots',
 'S-HNI (Min)_Shares',
 'S-HNI (Min)_Amount',
 'S-HNI (Max)_Lots',
 'S-HNI (Max)_Shares',
 'S-HNI (Max)_Amount',
 'B-HNI (Min)_Lots',
 'B-HNI (Min)_Shares',
 'B-HNI (Min)_Amount',
 'Share Holding Pre Issue',
 'Share Holding Post Issue',
 '0_assets',
 '0_revenue',
 '0_profit after tax',
 '0_net worth',
 '0_reserves and surplus',
 '0_total borrowing',
 '0_total income',
 '1_assets',
 '1_revenue',
 '1_profit after tax',
 '1_net worth',
 '1_reserves and surplus',
 '1_total borrowing',
 '1_total income',
 '2_assets',
 '2_revenue',
 '2_profit after tax',
 '2_net worth',
 '2_reserves and surplus',
 '2_total borrowing',
 '2_total income',
 '3_assets',
 '3_revenue',
 '3_profit after tax',
 '3_net worth',
 '3_reserves and surplus',
 '3_total borrowing',
 '3_total income',
 '4_assets',
 '4_revenue',
 '4_profit after tax',
 '4_net worth',
 '4_reserves and surplus',
 '4_total borrowing',
 '4_total income',
 '5_assets',
 '5_revenue',
 '5_profit after tax',
 '5_total income']

categorical_features = ['Sector',	'Industry',	'Total Issue Size',	'Issue Type',	'Fresh Issue',	'Offer for Sale',	'Price Band']

# %%
def clean_numbers(txt):
    num =  str(txt).replace(',','').replace(' ','')
    if len(num.split('.')) > 2:
        num = '.'.join(num.split('.')[0:2])
    if num == '':
        return np.nan
    if num == 'nan':
        return np.nan
    if num == '-':
        return np.nan
    if '%' in num:
        num = float(num.replace('%',''))/100
    elif 'Cr' in num:
        num = float(num.replace('Cr',''))*10000000
    elif 'B' in num:
        num = float(num.replace('B',''))*1000000000

    elif 'M' in num:
        num = float(num.replace('M',''))*1000000

    elif 'K' in num:
        num = float(num.replace('K',''))*1000
    else:
        num = float(num)

    return num

# %% [markdown]
# # Main Board

# %%
main = pd.read_excel("/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/ipo_mainline_final_data_v18.xlsx")
main.shape
# Out:
# (418, 217)

# %%
train = main[main['Close Year'] < 2023]
test = main[main['Close Year'] == 2023]

# %%
y = 'Success_Open'
for txt_feat in text_features:
  train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
  test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# Out:
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[txt_feat + '_probab'] = pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_train_predictions_{txt_feat}.csv")['p1'].to_list()
# <ipython-input-9-2e5af5cb18ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[txt_feat + '_probab']  =  pd.read_csv( f"/content/drive/MyDrive/datasets/Indian_IPO_Prediction/final_data/mainboard_text_feature_predictions/{y}mainboard_test_predictions_{txt_feat}.csv")['p1'].to_list()

# %% [markdown]
# ## Without News

# %%
text_features_probab = [i + '_probab' for i in text_features]
text_features_probab.remove('full_text_context_with_news_probab')

# %%
train_use_X = train[numeric_features + categorical_features + text_features_probab]
test_use_X = test[numeric_features + categorical_features + text_features_probab]
for i in numeric_features:
  if train_use_X[i].dtype != 'int64' and train_use_X[i].dtype !='float64':
    train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
    test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')

for col in  categorical_features:
  train_use_X[col] = train_use_X[col].str.replace('"', '', regex=False)  # Remove double quotes
  train_use_X[col] = train_use_X[col].str.replace('\n', ' ', regex=False)
  test_use_X[col] = test_use_X[col].str.replace('"', '', regex=False)  # Remove double quotes
  test_use_X[col] = test_use_X[col].str.replace('\n', ' ', regex=False)
# Out:
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-11-25082cdf839e>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[col] = train_use_X[col].str.replace('"', '', regex=False)  # Remove double quotes
# <ipython-input-11-25082cdf839e>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[col] = train_use_X[col].str.replace('\n', ' ', regex=False)
# <ipython-input-11-25082cdf839e>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[col] = test_use_X[col].str.replace('"', '', regex=False)  # Remove double quotes
# <ipython-input-11-25082cdf839e>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[col] = test_use_X[col].str.replace('\n', ' ', regex=False)

# %%
h2o_train = h2o.H2OFrame(train_use_X)  # Convert train DataFrame to H2OFrame
h2o_test = h2o.H2OFrame(test_use_X)  # Convert test DataFrame to H2OFrame

# train['underpricing']= (train[y] - train['Final_Issue_Price'])/train['Final_Issue_Price']
# test['underpricing']= (test[y] - test['Final_Issue_Price'])/test['Final_Issue_Price']
if y == 'Success_Open':
  val = 'NSE_Open'
if y == 'Success_Close':
  val = 'NSE_Last_Trade'
if y == 'Success_High':
  val = 'NSE_High'
train['underpricing']= (train[val] - train['Final_Issue_Price'])/train['Final_Issue_Price']
test['underpricing']= (test[val] - test['Final_Issue_Price'])/test['Final_Issue_Price']
# Identify predictors and response
# x = train.columns
# y = "response"
# x.remove(y)

x= numeric_features + categorical_features + text_features_probab #+ text_features


# h2o_train[y] = h2o.H2OFrame(train[y].to_list()).asfactor()  # Convert Pandas Series to H2OFrame before assigning
# h2o_test[y] = h2o.H2OFrame(test[y].to_list()).asfactor()  # Convert Pandas Series to H2OFrame before assigning
h2o_train[y] = h2o.H2OFrame(train['underpricing'].to_list()) #h2o.H2OFrame(train[y].to_list()).asfactor()  # Convert Pandas Series to H2OFrame before assigning
h2o_test[y] =  h2o.H2OFrame(test['underpricing'].to_list()) #h2o.H2OFrame(test[y].to_list()).asfactor()  # Convert Pandas Series to H2OFrame before assigning

# For binary classification, response should be a factor
# train[y] = train[y].asfactor()
# test[y] = test[y].asfactor()

# Run AutoML for 20 base models
aml = H2OAutoML(max_models=20, seed=1)
aml.train(x=x, y=y, training_frame=h2o_train)

# View the AutoML Leaderboard
lb = aml.leaderboard
lb.head(rows=lb.nrows)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# <ipython-input-12-3dacf8f0bfc9>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['underpricing']= (train[val] - train['Final_Issue_Price'])/train['Final_Issue_Price']
# <ipython-input-12-3dacf8f0bfc9>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['underpricing']= (test[val] - test['Final_Issue_Price'])/test['Final_Issue_Price']
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 15:17:05.37: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ██
# 15:17:16.319: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:17:29.873: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:17:35.978: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:17:45.66: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ██
# 15:18:06.708: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:18:13.583: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:18:19.122: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:18:23.841: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:18:30.261: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ███
# 15:18:51.962: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:18:59.637: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ██████████████████████████████████████████████
# 15:30:44.582: _train param, Dropping unused columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
# 15:30:45.468: _train param, Dropping unused columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ██| (done) 100%
# model_id                                                     rmse        mse       mae       rmsle    mean_residual_deviance
# -------------------------------------------------------  --------  ---------  --------  ----------  ------------------------
# StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_151704  0.201793  0.0407202  0.116437    0.134446                 0.0407202
# DeepLearning_grid_3_AutoML_1_20240919_151704_model_1     0.203786  0.0415289  0.116419    0.137359                 0.0415289
# StackedEnsemble_AllModels_1_AutoML_1_20240919_151704     0.204783  0.0419362  0.115227    0.135508                 0.0419362
# DeepLearning_grid_2_AutoML_1_20240919_151704_model_1     0.208141  0.0433226  0.122918    0.141743                 0.0433226
# DeepLearning_grid_1_AutoML_1_20240919_151704_model_1     0.209849  0.0440365  0.124919    0.14143                  0.0440365
# DeepLearning_1_AutoML_1_20240919_151704                  0.226265  0.051196   0.133212    0.154078                 0.051196
# XGBoost_2_AutoML_1_20240919_151704                       0.228385  0.0521597  0.140481    0.155625                 0.0521597
# XGBoost_grid_1_AutoML_1_20240919_151704_model_2          0.230232  0.0530069  0.134414    0.153663                 0.0530069
# XGBoost_3_AutoML_1_20240919_151704                       0.230528  0.053143   0.133021    0.153989                 0.053143
# XRT_1_AutoML_1_20240919_151704                           0.232594  0.0541002  0.134227    0.151547                 0.0541002
# XGBoost_grid_1_AutoML_1_20240919_151704_model_1          0.237788  0.0565432  0.141887    0.162095                 0.0565432
# XGBoost_1_AutoML_1_20240919_151704                       0.253635  0.0643306  0.156238    0.175058                 0.0643306
# XGBoost_grid_1_AutoML_1_20240919_151704_model_3          0.25589   0.0654798  0.137458    0.165994                 0.0654798
# GLM_1_AutoML_1_20240919_151704                           0.271329  0.0736192  0.141625  nan                        0.0736192
# GBM_grid_1_AutoML_1_20240919_151704_model_1              0.289334  0.0837144  0.1464      0.191012                 0.0837144
# GBM_1_AutoML_1_20240919_151704                           0.305004  0.0930275  0.161983    0.207136                 0.0930275
# DRF_1_AutoML_1_20240919_151704                           0.30864   0.0952589  0.155607    0.208725                 0.0952589
# GBM_2_AutoML_1_20240919_151704                           0.312451  0.0976254  0.164212    0.21345                  0.0976254
# GBM_grid_1_AutoML_1_20240919_151704_model_2              0.313704  0.09841    0.163303    0.214355                 0.09841
# GBM_3_AutoML_1_20240919_151704                           0.314187  0.0987137  0.163847    0.214815                 0.0987137
# GBM_5_AutoML_1_20240919_151704                           0.315661  0.0996418  0.165906    0.216274                 0.0996418
# GBM_4_AutoML_1_20240919_151704                           0.316257  0.100019   0.165753    0.21695                  0.100019
# [22 rows x 6 columns]

# %%
lb
# Out:
# model_id                                                     rmse        mse       mae       rmsle    mean_residual_deviance
# -------------------------------------------------------  --------  ---------  --------  ----------  ------------------------
# StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_151704  0.201793  0.0407202  0.116437    0.134446                 0.0407202
# DeepLearning_grid_3_AutoML_1_20240919_151704_model_1     0.203786  0.0415289  0.116419    0.137359                 0.0415289
# StackedEnsemble_AllModels_1_AutoML_1_20240919_151704     0.204783  0.0419362  0.115227    0.135508                 0.0419362
# DeepLearning_grid_2_AutoML_1_20240919_151704_model_1     0.208141  0.0433226  0.122918    0.141743                 0.0433226
# DeepLearning_grid_1_AutoML_1_20240919_151704_model_1     0.209849  0.0440365  0.124919    0.14143                  0.0440365
# DeepLearning_1_AutoML_1_20240919_151704                  0.226265  0.051196   0.133212    0.154078                 0.051196
# XGBoost_2_AutoML_1_20240919_151704                       0.228385  0.0521597  0.140481    0.155625                 0.0521597
# XGBoost_grid_1_AutoML_1_20240919_151704_model_2          0.230232  0.0530069  0.134414    0.153663                 0.0530069
# XGBoost_3_AutoML_1_20240919_151704                       0.230528  0.053143   0.133021    0.153989                 0.053143
# XRT_1_AutoML_1_20240919_151704                           0.232594  0.0541002  0.134227    0.151547                 0.0541002
# XGBoost_grid_1_AutoML_1_20240919_151704_model_1          0.237788  0.0565432  0.141887    0.162095                 0.0565432
# XGBoost_1_AutoML_1_20240919_151704                       0.253635  0.0643306  0.156238    0.175058                 0.0643306
# XGBoost_grid_1_AutoML_1_20240919_151704_model_3          0.25589   0.0654798  0.137458    0.165994                 0.0654798
# GLM_1_AutoML_1_20240919_151704                           0.271329  0.0736192  0.141625  nan                        0.0736192
# GBM_grid_1_AutoML_1_20240919_151704_model_1              0.289334  0.0837144  0.1464      0.191012                 0.0837144
# GBM_1_AutoML_1_20240919_151704                           0.305004  0.0930275  0.161983    0.207136                 0.0930275
# DRF_1_AutoML_1_20240919_151704                           0.30864   0.0952589  0.155607    0.208725                 0.0952589
# GBM_2_AutoML_1_20240919_151704                           0.312451  0.0976254  0.164212    0.21345                  0.0976254
# GBM_grid_1_AutoML_1_20240919_151704_model_2              0.313704  0.09841    0.163303    0.214355                 0.09841
# GBM_3_AutoML_1_20240919_151704                           0.314187  0.0987137  0.163847    0.214815                 0.0987137
# GBM_5_AutoML_1_20240919_151704                           0.315661  0.0996418  0.165906    0.216274                 0.0996418
# GBM_4_AutoML_1_20240919_151704                           0.316257  0.100019   0.165753    0.21695                  0.100019
# [22 rows x 6 columns]

# %%
lb = h2o.automl.get_leaderboard(aml, extra_columns = "ALL")
lb
# Out:
# model_id                                                     rmse        mse       mae     rmsle    mean_residual_deviance    training_time_ms    predict_time_per_row_ms  algo
# -------------------------------------------------------  --------  ---------  --------  --------  ------------------------  ------------------  -------------------------  ---------------
# StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_151704  0.201793  0.0407202  0.116437  0.134446                 0.0407202                 838                   0.485169  StackedEnsemble
# DeepLearning_grid_3_AutoML_1_20240919_151704_model_1     0.203786  0.0415289  0.116419  0.137359                 0.0415289               46749                   0.461804  DeepLearning
# StackedEnsemble_AllModels_1_AutoML_1_20240919_151704     0.204783  0.0419362  0.115227  0.135508                 0.0419362                1044                   0.979102  StackedEnsemble
# DeepLearning_grid_2_AutoML_1_20240919_151704_model_1     0.208141  0.0433226  0.122918  0.141743                 0.0433226               48648                   0.305839  DeepLearning
# DeepLearning_grid_1_AutoML_1_20240919_151704_model_1     0.209849  0.0440365  0.124919  0.14143                  0.0440365               33170                   0.408584  DeepLearning
# DeepLearning_1_AutoML_1_20240919_151704                  0.226265  0.051196   0.133212  0.154078                 0.051196                  629                   0.057915  DeepLearning
# XGBoost_2_AutoML_1_20240919_151704                       0.228385  0.0521597  0.140481  0.155625                 0.0521597                1222                   0.024667  XGBoost
# XGBoost_grid_1_AutoML_1_20240919_151704_model_2          0.230232  0.0530069  0.134414  0.153663                 0.0530069                 950                   0.019894  XGBoost
# XGBoost_3_AutoML_1_20240919_151704                       0.230528  0.053143   0.133021  0.153989                 0.053143                  721                   0.016537  XGBoost
# XRT_1_AutoML_1_20240919_151704                           0.232594  0.0541002  0.134227  0.151547                 0.0541002                3055                   0.052134  DRF
# [22 rows x 9 columns]

# %%
# Get the best model using the metric
m = aml.leader
print(m)
# Out:
# Model Details
# =============
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_151704
#
#
# Model Summary for Stacked Ensemble:
# key                                        value
# -----------------------------------------  ----------------
# Stacking strategy                          cross_validation
# Number of base models (used / total)       3/6
# # GBM base models (used / total)           0/1
# # XGBoost base models (used / total)       1/1
# # DeepLearning base models (used / total)  1/1
# # DRF base models (used / total)           0/2
# # GLM base models (used / total)           1/1
# Metalearner algorithm                      GLM
# Metalearner fold assignment scheme         Random
# Metalearner nfolds                         5
# Metalearner fold_column
# Custom metalearner hyperparameters         None
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.0031009515047063915
# RMSE: 0.05568618773723329
# MAE: 0.03887823870278598
# RMSLE: 0.041614459625576264
# Mean Residual Deviance: 0.0031009515047063915
# R^2: 0.9672902159559754
# Null degrees of freedom: 360
# Residual degrees of freedom: 357
# Null deviance: 34.22350608283844
# Residual deviance: 1.1194434931990074
# AIC: -1050.6790852342306
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.04072021739707058
# RMSE: 0.2017925107556536
# MAE: 0.11643663106672114
# RMSLE: 0.1344461643983951
# Mean Residual Deviance: 0.04072021739707058
# R^2: 0.5704707038267516
# Null degrees of freedom: 360
# Residual degrees of freedom: 356
# Null deviance: 34.56909087427962
# Residual deviance: 14.69999848034248
# AIC: -119.09841404760559
#
# Cross-Validation Metrics Summary:
#                         mean       sd         cv_1_valid    cv_2_valid    cv_3_valid    cv_4_valid    cv_5_valid
# ----------------------  ---------  ---------  ------------  ------------  ------------  ------------  ------------
# aic                     -25.8292   40.1142    35.1071       -43.4034      -10.4695      -70.264       -40.1163
# loglikelihood           0          0          0             0             0             0             0
# mae                     0.11584    0.0237502  0.147128      0.108502      0.127683      0.0830658     0.112821
# mean_residual_deviance  0.0403499  0.0247066  0.0810715     0.0307676     0.0435199     0.0163765     0.0300139
# mse                     0.0403499  0.0247066  0.0810715     0.0307676     0.0435199     0.0163765     0.0300139
# null_deviance           6.91382    3.02859    11.0207       5.29238       6.49765       3.15156       8.60682
# r2                      0.575754   0.107935   0.466344      0.5046        0.53585       0.643142      0.728833
# residual_deviance       2.91908    1.74624    5.75607       2.55371       3.00288       1.03172       2.25104
# rmse                    0.193994   0.0582708  0.28473       0.175407      0.208614      0.127971      0.173245
# rmsle                   0.132122   0.0222236  0.157155      0.130792      0.149253      0.101219      0.12219

# %%
# this is equivalent to
m = aml.get_best_model()
print(m)
# Out:
# Model Details
# =============
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_151704
#
#
# Model Summary for Stacked Ensemble:
# key                                        value
# -----------------------------------------  ----------------
# Stacking strategy                          cross_validation
# Number of base models (used / total)       3/6
# # GBM base models (used / total)           0/1
# # XGBoost base models (used / total)       1/1
# # DeepLearning base models (used / total)  1/1
# # DRF base models (used / total)           0/2
# # GLM base models (used / total)           1/1
# Metalearner algorithm                      GLM
# Metalearner fold assignment scheme         Random
# Metalearner nfolds                         5
# Metalearner fold_column
# Custom metalearner hyperparameters         None
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.0031009515047063915
# RMSE: 0.05568618773723329
# MAE: 0.03887823870278598
# RMSLE: 0.041614459625576264
# Mean Residual Deviance: 0.0031009515047063915
# R^2: 0.9672902159559754
# Null degrees of freedom: 360
# Residual degrees of freedom: 357
# Null deviance: 34.22350608283844
# Residual deviance: 1.1194434931990074
# AIC: -1050.6790852342306
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.04072021739707058
# RMSE: 0.2017925107556536
# MAE: 0.11643663106672114
# RMSLE: 0.1344461643983951
# Mean Residual Deviance: 0.04072021739707058
# R^2: 0.5704707038267516
# Null degrees of freedom: 360
# Residual degrees of freedom: 356
# Null deviance: 34.56909087427962
# Residual deviance: 14.69999848034248
# AIC: -119.09841404760559
#
# Cross-Validation Metrics Summary:
#                         mean       sd         cv_1_valid    cv_2_valid    cv_3_valid    cv_4_valid    cv_5_valid
# ----------------------  ---------  ---------  ------------  ------------  ------------  ------------  ------------
# aic                     -25.8292   40.1142    35.1071       -43.4034      -10.4695      -70.264       -40.1163
# loglikelihood           0          0          0             0             0             0             0
# mae                     0.11584    0.0237502  0.147128      0.108502      0.127683      0.0830658     0.112821
# mean_residual_deviance  0.0403499  0.0247066  0.0810715     0.0307676     0.0435199     0.0163765     0.0300139
# mse                     0.0403499  0.0247066  0.0810715     0.0307676     0.0435199     0.0163765     0.0300139
# null_deviance           6.91382    3.02859    11.0207       5.29238       6.49765       3.15156       8.60682
# r2                      0.575754   0.107935   0.466344      0.5046        0.53585       0.643142      0.728833
# residual_deviance       2.91908    1.74624    5.75607       2.55371       3.00288       1.03172       2.25104
# rmse                    0.193994   0.0582708  0.28473       0.175407      0.208614      0.127971      0.173245
# rmsle                   0.132122   0.0222236  0.157155      0.130792      0.149253      0.101219      0.12219

# %%
# Get the best model using a non-default metric
# m = aml.get_best_model(criterion="logloss")
# print(m)

# %%
# Get AutoML event log
log = aml.event_log
print(log)
# Out:
# timestamp     level    stage       message                                                                                                                                                          name    value
# 15:17:04.869  INFO     Workflow    Project: AutoML_1_20240919_151704
# 15:17:04.872  INFO     Validation  5-fold cross-validation will be used.
# 15:17:04.873  INFO     Validation  Setting stopping tolerance adaptively based on the training frame: 0.05
# 15:17:04.873  INFO     Validation  Build control seed: 1
# 15:17:04.875  INFO     DataImport  training frame: Frame key: AutoML_1_20240919_151704_training_py_1_sid_a926    cols: 175    rows: 361  chunks: 1    size: 496103  checksum: -4427595717191003112
# 15:17:04.875  INFO     DataImport  validation frame: NULL
# 15:17:04.875  INFO     DataImport  leaderboard frame: NULL
# 15:17:04.875  INFO     DataImport  blending frame: NULL
# 15:17:04.876  INFO     DataImport  response column: Success_Open
# 15:17:04.876  INFO     DataImport  fold column: null
# [153 rows x 6 columns]

# %%
# Get training timing info
info = aml.training_info
print(info)
# Out:
# {'creation_epoch': '1726759025', 'start_epoch': '1726759025', 'start_XGBoost_def_2': '1726759025', 'start_GLM_def_1': '1726759036', 'start_GBM_def_5': '1726759050', 'start_XGBoost_def_1': '1726759056', 'start_DRF_def_1': '1726759065', 'start_GBM_def_2': '1726759087', 'start_GBM_def_3': '1726759094', 'start_GBM_def_4': '1726759099', 'start_XGBoost_def_3': '1726759104', 'start_DRF_XRT': '1726759110', 'start_GBM_def_1': '1726759132', 'start_DeepLearning_def_1': '1726759140', 'start_XGBoost_grid_1': '1726759146', 'start_GBM_grid_1': '1726759163', 'start_DeepLearning_grid_1': '1726759171', 'start_DeepLearning_grid_2': '1726759352', 'start_DeepLearning_grid_3': '1726759609', 'start_StackedEnsemble_best_of_family_xglm': '1726759845', 'start_StackedEnsemble_all_xglm': '1726759845', 'stop_epoch': '1726759847', 'duration_secs': '822'}

# %%
aml.leader.model_id
# Out:
# 'StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_151704'

# %%
# aml.leader.confusion_matrix()

# %%
cols = ['3_assets',  '3_revenue', 'Share Holding Post Issue', 'Share Holding Pre Issue', 'S-HNI (Max)_Shares',  'B-HNI (Min)_Shares', 'S-HNI (Min)_Amount', 'B-HNI (Min)_Amount', 'S-HNI (Min)_Shares', 'S-HNI (Max)_Amount', 'B-HNI (Min)_Lots', 'S-HNI (Max)_Lots', 'S-HNI (Min)_Lots', '0_net worth',  '3_net worth', '1_net worth', '2_net worth']
for col in cols:
  h2o_test[col] = h2o_test[col].ascharacter().asfactor()

# %%
preds_leader = aml.leader.predict(h2o_test)
preds_leader
# Out:
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'day_3_qib' has levels not trained on: ["1.05", "1.28", "5.79", "64.1"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'day_3_nii' has levels not trained on: ["1.52", "1.92", "132.99", "6.49", "64.88", "9.01"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'day_3_retail' has levels not trained on: ["0.55", "16.53", "225.37", "3.14", "4.44", "64.84"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'day_3_total' has levels not trained on: ["0.98", "2.19", "5.35", "5.5", "50.38", "62.83"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'S-HNI (Min)_Lots' has levels not trained on: ["14", "15"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'S-HNI (Min)_Shares' has levels not trained on: ["1064", "1232", "1260", "1470", "1498", "1500", "1666", "1764", "195", "1950", ...25 not listed..., "686", "700", "714", "728", "742", "784", "8400", "938", "966", "980"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'S-HNI (Min)_Amount' has levels not trained on: ["202300", "202860", "203280", "204750", "204820", "205030", "205408", "205800", "206080", "206250", ...18 not listed..., "209160", "209244", "209300", "209412", "209608", "209720", "209916", "210000", "210600", "213300"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'S-HNI (Max)_Lots' has levels not trained on: ["66", "67", "68", "69", "70", "71", "72"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'S-HNI (Max)_Shares' has levels not trained on: ["10050", "10200", "1173", "1260", "1340", "1360", "1474", "1496", "15180", "1541", ...35 not listed..., "7035", "7062", "7100", "7140", "7854", "8316", "923", "9230", "966", "9900"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'S-HNI (Max)_Amount' has levels not trained on: ["986040", "986240", "986436", "986700", "987228", "987360", "988152", "988250", "988680", "988920", ...18 not listed..., "996826", "996840", "997050", "997696", "998032", "998233", "998568", "998970", "999600", "999810"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'B-HNI (Min)_Lots' has levels not trained on: ["67", "68", "69", "70", "71", "72", "73"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'B-HNI (Min)_Shares' has levels not trained on: ["10050", "10200", "10350", "1190", "1278", "1360", "1380", "1496", "1518", "15410", ...35 not listed..., "6120", "7140", "7169", "7200", "7245", "7973", "8442", "936", "9360", "980"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'B-HNI (Min)_Amount' has levels not trained on: ["1000960", "1000980", "1001382", "1001650", "1001880", "1002186", "1003000", "1003124", "1003660", "1003680", ...18 not listed..., "1011296", "1011432", "1011500", "1011704", "1012368", "1012928", "1013132", "1013472", "1013880", "1014300"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Share Holding Pre Issue' has levels not trained on: ["0.3337", "0.3741", "0.4408", "0.4665", "0.4979", "0.5675", "0.5791", "0.6642", "0.6666", "0.6679", ...21 not listed..., "0.918", "0.9284", "0.9523", "0.9642", "0.9749", "0.978", "0.9859", "0.993", "0.9935", "1"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Share Holding Post Issue' has levels not trained on: ["0.3019", "0.3534", "0.4091", "0.416", "0.4408", "0.4817", "0.5124", "0.5366", "0.5539", "0.5547", ...21 not listed..., "0.7494", "0.7495", "0.7497", "0.7545", "0.765", "0.7859", "0.792", "0.8561", "64.46", "78.06"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '0_net worth' has levels not trained on: ["-259.28", "-93.07", "1019.5", "104.57", "1103.33", "113.61", "1226.56", "123.49", "1374.97", "1414.9", ...23 not listed..., "56.58", "638.26", "6580.61", "725.68", "752.09", "810.79", "86.11", "875.07", "88.58", "999.37"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '1_net worth' has levels not trained on: ["-206.87", "-702.63", "100.93", "1033.38", "1103.22", "1240.53", "1336.58", "1355.68", "1368.35", "137.4", ...23 not listed..., "65.97", "665.73", "681.49", "71.39", "71.46", "75.2", "760.21", "92.47", "944.72", "988.31"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '2_net worth' has levels not trained on: ["-352.22", "-871.43", "100.49", "1026.78", "106.05", "107.25", "1076.13", "115.45", "1153.52", "1237.05", ...23 not listed..., "5268.11", "560.71", "631.91", "70.03", "705.62", "714", "72.46", "787.62", "86.22", "889.89"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '3_assets' has levels not trained on: ["1077.86", "1097.7", "1146.51", "123.74", "12338.65", "19117.54", "213.98", "2462.64", "256.05", "2633.62", ...11 not listed..., "5746.44", "5999.13", "6210.92", "638.72", "687.2", "692.76", "792", "876.38", "9450.66", "948.25"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '3_revenue' has levels not trained on: ["10311.01", "1059.58", "107.71", "1178.62", "125.03", "1567.77", "1585.88", "1768.42", "2031.3", "2069.58", ...11 not listed..., "402.59", "408.79", "412.03", "472.1", "543.28", "5633.64", "590.81", "608.99", "697.57", "740.36"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '3_net worth' has levels not trained on: ["-1765.14", "100.96", "114.09", "116.89", "117.6", "1352.06", "1390.47", "144.78", "1466.88", "192.33", ...10 not listed..., "375.76", "3934.64", "47.54", "487.83", "55.55", "622.23", "645.16", "723.55", "834.73", "937.27"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '4_assets' has levels not trained on: ["1082.82", "267.16", "485.97"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '4_revenue' has levels not trained on: ["166.13", "510.21", "523.1"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '4_profit after tax' has levels not trained on: ["19.24", "21.07", "65.77"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '4_net worth' has levels not trained on: ["182.96", "363.65", "74.74"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Industry' has levels not trained on: ["Computer Peripherals", "Integrated Oil", "Office Equipment/Supplies"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Fresh Issue' has levels not trained on: ["1,700,680 shares (aggregating up to 75.00 Cr)", "1,739,131 shares (aggregating up to 180.00 Cr)", "10,000,000 shares (aggregating up to 100.00 Cr)", "10,200,000 shares (aggregating up to 66.30 Cr)", "10,800,000 shares (aggregating up to 545.40 Cr)", "10,890,000 shares (aggregating up to 152.46 Cr)", "11,111,111 shares (aggregating up to 400.00 Cr)", "11,268,580 shares (aggregating up to 365.00 Cr)", "12,280,701 shares (aggregating up to 350.00 Cr)", "13,200,158 shares (aggregating up to 71.28 Cr)", ...27 not listed..., "6,930,806 shares (aggregating up to 146.24 Cr)", "65,116,667 shares (aggregating up to 390.70 Cr)", "7,142,857 shares (aggregating up to 320.00 Cr)", "7,339,450 shares (aggregating up to 320.00 Cr)", "7,374,163 shares (aggregating up to 542.00 Cr)", "8,517,350 shares (aggregating up to 270.00 Cr)", "8,520,000 shares (aggregating up to 119.28 Cr)", "9,605,263 shares (aggregating up to 292.00 Cr)", "9,767,442 shares (aggregating up to 210.00 Cr)", "95,238,095 shares (aggregating up to 1,200.00 Cr)"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Offer for Sale' has levels not trained on: ["10,449,816 shares of 1 (aggregating up to 171.38 Cr)", "10,759,493 shares of 10 (aggregating up to 850.00 Cr)", "11,756,910 shares of 2 (aggregating up to 198.69 Cr)", "12,050,000 shares of 10 (aggregating up to 72.30 Cr)", "12,183,099 shares of 1 (aggregating up to 173.00 Cr)", "12,500,000 shares of 2 (aggregating up to 545.00 Cr)", "13,500,000 shares of 1 (aggregating up to 170.10 Cr)", "14,213,198 shares of 1 (aggregating up to 280.00 Cr)", "17,236,808 shares of 5 (aggregating up to 1,784.01 Cr)", "17,500,000 shares of 2 (aggregating up to 189.00 Cr)", ...25 not listed..., "7,159,920 shares of 2 (aggregating up to 608.59 Cr)", "8,000,000 shares of 10 (aggregating up to 240.00 Cr)", "8,113,590 shares of 5 (aggregating up to 400.00 Cr)", "8,294,118 shares of 10 (aggregating up to 175.00 Cr)", "8,500,000 shares of 2 (aggregating up to 425.00 Cr)", "9,000,000 shares of 10 (aggregating up to 256.50 Cr)", "9,428,178 shares of 10 (aggregating up to 415.78 Cr)", "9,541,985 shares of 2 (aggregating up to 500.00 Cr)", "9,901,315 shares of 5 (aggregating up to 301.00 Cr)", "[.] shares of 10 (aggregating up to 425.00 Cr)"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Price Band' has levels not trained on: ["102 to 108 per share", "1026 to 1080 per share", "113 to 119 per share", "119 to 126 per share", "133 to 140 per share", "135 to 142 per share", "151 to 166 per share", "156 to 164 per share", "160 to 169 per share", "187 to 197 per share", ...30 not listed..., "617 to 648 per share", "627 to 660 per share", "638 to 672 per share", "695 to 735 per share", "705 to 741 per share", "750 to 790 per share", "808 to 850 per share", "93 to 98 per share", "95 to 100 per share", "983 to 1035 per share"]
#   warnings.warn(w)
#    predict
# ----------
#  0.0715941
# -0.0112416
# -0.0235639
#  0.0819073
#  0.0520688
#  0.0431171
#  0.233587
#  0.0218176
#  0.269122
#  0.833228
# [57 rows x 1 column]

# %%
best_model = aml.get_best_model()
model_path = h2o.save_model(model=best_model, path="/content/drive/MyDrive/datasets/Indian_IPO_Prediction/mainboard_h2o_best_stacked_model_" + y + "_ALL_features_with_text_emb_predprobab_underpricing/", force=True)
print(model_path)
# Out:
# /content/drive/MyDrive/datasets/Indian_IPO_Prediction/mainboard_h2o_best_stacked_model_Success_Open_ALL_features_with_text_emb_predprobab_underpricing/StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_151704

# %%
performance = best_model.model_performance(test_data=h2o_test)
print("MAE:", performance.mae())
print(f"RMSE: {performance.rmse()}")
print(f"MSE: {performance.mse()}")
print("\n")
# Out:
# MAE: 0.17614758527210134
# RMSE: 0.2454424470198195
# MSE: 0.060241994799076895

# %%
for model_id in lb['model_id'].as_data_frame()['model_id']:
    model = h2o.get_model(model_id)
    performance = model.model_performance(test_data=h2o_test)
    print(f"Performance for model {model_id}:")
    #print(f"AUC: {performance.auc()}")
    #print(f"Log Loss: {performance.logloss()}")
    #print(f"Mean Per Class Error: {performance.mean_per_class_error()}")
    print("MAE:", performance.mae())
    print(f"RMSE: {performance.rmse()}")
    print(f"MSE: {performance.mse()}")
    print("\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/h2o/frame.py:1981: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# Performance for model StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_151704:
# MAE: 0.17614758527210134
# RMSE: 0.2454424470198195
# MSE: 0.060241994799076895
#
#
# Performance for model DeepLearning_grid_3_AutoML_1_20240919_151704_model_1:
# MAE: 0.1811344939257064
# RMSE: 0.2613632073447356
# MSE: 0.06831072615352726
#
#
# Performance for model StackedEnsemble_AllModels_1_AutoML_1_20240919_151704:
# MAE: 0.17868537165045603
# RMSE: 0.24694424295020892
# MSE: 0.0609814591262518
#
#
# Performance for model DeepLearning_grid_2_AutoML_1_20240919_151704_model_1:
# MAE: 0.2046605795642024
# RMSE: 0.28597314281510205
# MSE: 0.08178063841154676
#
#
# Performance for model DeepLearning_grid_1_AutoML_1_20240919_151704_model_1:
# MAE: 0.21093791388693184
# RMSE: 0.3004752724450088
# MSE: 0.09028538935090227
#
#
# Performance for model DeepLearning_1_AutoML_1_20240919_151704:
# MAE: 0.18418371250269716
# RMSE: 0.2500976852138068
# MSE: 0.06254885214930442
#
#
# Performance for model XGBoost_2_AutoML_1_20240919_151704:
# MAE: 0.2565748305427597
# RMSE: 0.32746444960228543
# MSE: 0.10723296575332775
#
#
# Performance for model XGBoost_grid_1_AutoML_1_20240919_151704_model_2:
# MAE: 0.17235265400979602
# RMSE: 0.234664740378404
# MSE: 0.05506754037686376
#
#
# Performance for model XGBoost_3_AutoML_1_20240919_151704:
# MAE: 0.23703976258586504
# RMSE: 0.3382895892451446
# MSE: 0.11443984619164863
#
#
# Performance for model XRT_1_AutoML_1_20240919_151704:
# MAE: 0.17090607758696297
# RMSE: 0.23550904320617208
# MSE: 0.05546450943188663
#
#
# Performance for model XGBoost_grid_1_AutoML_1_20240919_151704_model_1:
# MAE: 0.28562381817027926
# RMSE: 0.36512904861131557
# MSE: 0.13331922213980443
#
#
# Performance for model XGBoost_1_AutoML_1_20240919_151704:
# MAE: 0.21609788634732627
# RMSE: 0.30087002503839544
# MSE: 0.0905227719666047
#
#
# Performance for model XGBoost_grid_1_AutoML_1_20240919_151704_model_3:
# MAE: 0.3099055832227398
# RMSE: 0.42863692788365726
# MSE: 0.18372961594553958
#
#
# Performance for model GLM_1_AutoML_1_20240919_151704:
# MAE: 0.20202438860597055
# RMSE: 0.2878304271230934
# MSE: 0.08284635477786238
#
#
# Performance for model GBM_grid_1_AutoML_1_20240919_151704_model_1:
# MAE: 0.24934027077395604
# RMSE: 0.36621059878411055
# MSE: 0.1341102026618168
#
#
# Performance for model GBM_1_AutoML_1_20240919_151704:
# MAE: 0.24783357885310112
# RMSE: 0.3514853672655842
# MSE: 0.12354196340182262
#
#
# Performance for model DRF_1_AutoML_1_20240919_151704:
# MAE: 0.2658048452423067
# RMSE: 0.3770372781931009
# MSE: 0.14215710914726176
#
#
# Performance for model GBM_2_AutoML_1_20240919_151704:
# MAE: 0.26184713085784456
# RMSE: 0.380601644574856
# MSE: 0.14485761185308502
#
#
# Performance for model GBM_grid_1_AutoML_1_20240919_151704_model_2:
# MAE: 0.2818332836688837
# RMSE: 0.40524719588768626
# MSE: 0.16422528977483275
#
#
# Performance for model GBM_3_AutoML_1_20240919_151704:
# MAE: 0.2716015481976521
# RMSE: 0.3954918229031641
# MSE: 0.15641378198326772
#
#
# Performance for model GBM_5_AutoML_1_20240919_151704:
# MAE: 0.27962619301630126
# RMSE: 0.4033809220575497
# MSE: 0.16271616827999902
#
#
# Performance for model GBM_4_AutoML_1_20240919_151704:
# MAE: 0.27897649031169164
# RMSE: 0.40388132312057906
# MSE: 0.1631201231656296

# %%
for model_id in lb['model_id'].as_data_frame()['model_id']:
    model = h2o.get_model(model_id)
    hyperparameters = model.get_params()
    print(f"Hyperparameters for model {model_id}:")
    print(hyperparameters)
    print("\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/h2o/frame.py:1981: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# Hyperparameters for model StackedEnsemble_BestOfFamily_1_AutoML_1_20240919_151704:
# {'model_id': None, 'training_frame': None, 'response_column': None, 'validation_frame': None, 'blending_frame': None, 'base_models': [], 'metalearner_algorithm': 'auto', 'metalearner_nfolds': 0, 'metalearner_fold_assignment': None, 'metalearner_fold_column': None, 'metalearner_params': None, 'metalearner_transform': 'none', 'max_runtime_secs': 0.0, 'weights_column': None, 'offset_column': None, 'custom_metric_func': None, 'seed': -1, 'score_training_samples': 10000, 'keep_levelone_frame': False, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'gainslift_bins': -1}
#
#
# Hyperparameters for model DeepLearning_grid_3_AutoML_1_20240919_151704_model_1:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'score_each_iteration': False, 'weights_column': None, 'offset_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'checkpoint': None, 'pretrained_autoencoder': None, 'overwrite_with_best_model': True, 'use_all_factor_levels': True, 'standardize': True, 'activation': 'rectifier', 'hidden': [200, 200], 'epochs': 10.0, 'train_samples_per_iteration': -2, 'target_ratio_comm_to_comp': 0.05, 'seed': -1, 'adaptive_rate': True, 'rho': 0.99, 'epsilon': 1e-08, 'rate': 0.005, 'rate_annealing': 1e-06, 'rate_decay': 1.0, 'momentum_start': 0.0, 'momentum_ramp': 1000000.0, 'momentum_stable': 0.0, 'nesterov_accelerated_gradient': True, 'input_dropout_ratio': 0.0, 'hidden_dropout_ratios': None, 'l1': 0.0, 'l2': 0.0, 'max_w2': 3.4028235e+38, 'initial_weight_distribution': 'uniform_adaptive', 'initial_weight_scale': 1.0, 'initial_weights': None, 'initial_biases': None, 'loss': 'automatic', 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'score_interval': 5.0, 'score_training_samples': 10000, 'score_validation_samples': 0, 'score_duty_cycle': 0.1, 'classification_stop': 0.0, 'regression_stop': 1e-06, 'stopping_rounds': 5, 'stopping_metric': 'auto', 'stopping_tolerance': 0.0, 'max_runtime_secs': 0.0, 'score_validation_sampling': 'uniform', 'diagnostics': True, 'fast_mode': True, 'force_load_balance': True, 'variable_importances': True, 'replicate_training_data': True, 'single_node_mode': False, 'shuffle_training_data': False, 'missing_values_handling': 'mean_imputation', 'quiet_mode': False, 'autoencoder': False, 'sparse': False, 'col_major': False, 'average_activation': 0.0, 'sparsity_beta': 0.0, 'max_categorical_features': 2147483647, 'reproducible': False, 'export_weights_and_biases': False, 'mini_batch_size': 1, 'categorical_encoding': 'auto', 'elastic_averaging': False, 'elastic_averaging_moving_rate': 0.9, 'elastic_averaging_regularization': 0.001, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'custom_metric_func': None, 'gainslift_bins': -1}
#
#
# Hyperparameters for model StackedEnsemble_AllModels_1_AutoML_1_20240919_151704:
# {'model_id': None, 'training_frame': None, 'response_column': None, 'validation_frame': None, 'blending_frame': None, 'base_models': [], 'metalearner_algorithm': 'auto', 'metalearner_nfolds': 0, 'metalearner_fold_assignment': None, 'metalearner_fold_column': None, 'metalearner_params': None, 'metalearner_transform': 'none', 'max_runtime_secs': 0.0, 'weights_column': None, 'offset_column': None, 'custom_metric_func': None, 'seed': -1, 'score_training_samples': 10000, 'keep_levelone_frame': False, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'gainslift_bins': -1}
#
#
# Hyperparameters for model DeepLearning_grid_2_AutoML_1_20240919_151704_model_1:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'score_each_iteration': False, 'weights_column': None, 'offset_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'checkpoint': None, 'pretrained_autoencoder': None, 'overwrite_with_best_model': True, 'use_all_factor_levels': True, 'standardize': True, 'activation': 'rectifier', 'hidden': [200, 200], 'epochs': 10.0, 'train_samples_per_iteration': -2, 'target_ratio_comm_to_comp': 0.05, 'seed': -1, 'adaptive_rate': True, 'rho': 0.99, 'epsilon': 1e-08, 'rate': 0.005, 'rate_annealing': 1e-06, 'rate_decay': 1.0, 'momentum_start': 0.0, 'momentum_ramp': 1000000.0, 'momentum_stable': 0.0, 'nesterov_accelerated_gradient': True, 'input_dropout_ratio': 0.0, 'hidden_dropout_ratios': None, 'l1': 0.0, 'l2': 0.0, 'max_w2': 3.4028235e+38, 'initial_weight_distribution': 'uniform_adaptive', 'initial_weight_scale': 1.0, 'initial_weights': None, 'initial_biases': None, 'loss': 'automatic', 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'score_interval': 5.0, 'score_training_samples': 10000, 'score_validation_samples': 0, 'score_duty_cycle': 0.1, 'classification_stop': 0.0, 'regression_stop': 1e-06, 'stopping_rounds': 5, 'stopping_metric': 'auto', 'stopping_tolerance': 0.0, 'max_runtime_secs': 0.0, 'score_validation_sampling': 'uniform', 'diagnostics': True, 'fast_mode': True, 'force_load_balance': True, 'variable_importances': True, 'replicate_training_data': True, 'single_node_mode': False, 'shuffle_training_data': False, 'missing_values_handling': 'mean_imputation', 'quiet_mode': False, 'autoencoder': False, 'sparse': False, 'col_major': False, 'average_activation': 0.0, 'sparsity_beta': 0.0, 'max_categorical_features': 2147483647, 'reproducible': False, 'export_weights_and_biases': False, 'mini_batch_size': 1, 'categorical_encoding': 'auto', 'elastic_averaging': False, 'elastic_averaging_moving_rate': 0.9, 'elastic_averaging_regularization': 0.001, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'custom_metric_func': None, 'gainslift_bins': -1}
#
#
# Hyperparameters for model DeepLearning_grid_1_AutoML_1_20240919_151704_model_1:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'score_each_iteration': False, 'weights_column': None, 'offset_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'checkpoint': None, 'pretrained_autoencoder': None, 'overwrite_with_best_model': True, 'use_all_factor_levels': True, 'standardize': True, 'activation': 'rectifier', 'hidden': [200, 200], 'epochs': 10.0, 'train_samples_per_iteration': -2, 'target_ratio_comm_to_comp': 0.05, 'seed': -1, 'adaptive_rate': True, 'rho': 0.99, 'epsilon': 1e-08, 'rate': 0.005, 'rate_annealing': 1e-06, 'rate_decay': 1.0, 'momentum_start': 0.0, 'momentum_ramp': 1000000.0, 'momentum_stable': 0.0, 'nesterov_accelerated_gradient': True, 'input_dropout_ratio': 0.0, 'hidden_dropout_ratios': None, 'l1': 0.0, 'l2': 0.0, 'max_w2': 3.4028235e+38, 'initial_weight_distribution': 'uniform_adaptive', 'initial_weight_scale': 1.0, 'initial_weights': None, 'initial_biases': None, 'loss': 'automatic', 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'score_interval': 5.0, 'score_training_samples': 10000, 'score_validation_samples': 0, 'score_duty_cycle': 0.1, 'classification_stop': 0.0, 'regression_stop': 1e-06, 'stopping_rounds': 5, 'stopping_metric': 'auto', 'stopping_tolerance': 0.0, 'max_runtime_secs': 0.0, 'score_validation_sampling': 'uniform', 'diagnostics': True, 'fast_mode': True, 'force_load_balance': True, 'variable_importances': True, 'replicate_training_data': True, 'single_node_mode': False, 'shuffle_training_data': False, 'missing_values_handling': 'mean_imputation', 'quiet_mode': False, 'autoencoder': False, 'sparse': False, 'col_major': False, 'average_activation': 0.0, 'sparsity_beta': 0.0, 'max_categorical_features': 2147483647, 'reproducible': False, 'export_weights_and_biases': False, 'mini_batch_size': 1, 'categorical_encoding': 'auto', 'elastic_averaging': False, 'elastic_averaging_moving_rate': 0.9, 'elastic_averaging_regularization': 0.001, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'custom_metric_func': None, 'gainslift_bins': -1}
#
#
# Hyperparameters for model DeepLearning_1_AutoML_1_20240919_151704:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'score_each_iteration': False, 'weights_column': None, 'offset_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'checkpoint': None, 'pretrained_autoencoder': None, 'overwrite_with_best_model': True, 'use_all_factor_levels': True, 'standardize': True, 'activation': 'rectifier', 'hidden': [200, 200], 'epochs': 10.0, 'train_samples_per_iteration': -2, 'target_ratio_comm_to_comp': 0.05, 'seed': -1, 'adaptive_rate': True, 'rho': 0.99, 'epsilon': 1e-08, 'rate': 0.005, 'rate_annealing': 1e-06, 'rate_decay': 1.0, 'momentum_start': 0.0, 'momentum_ramp': 1000000.0, 'momentum_stable': 0.0, 'nesterov_accelerated_gradient': True, 'input_dropout_ratio': 0.0, 'hidden_dropout_ratios': None, 'l1': 0.0, 'l2': 0.0, 'max_w2': 3.4028235e+38, 'initial_weight_distribution': 'uniform_adaptive', 'initial_weight_scale': 1.0, 'initial_weights': None, 'initial_biases': None, 'loss': 'automatic', 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'score_interval': 5.0, 'score_training_samples': 10000, 'score_validation_samples': 0, 'score_duty_cycle': 0.1, 'classification_stop': 0.0, 'regression_stop': 1e-06, 'stopping_rounds': 5, 'stopping_metric': 'auto', 'stopping_tolerance': 0.0, 'max_runtime_secs': 0.0, 'score_validation_sampling': 'uniform', 'diagnostics': True, 'fast_mode': True, 'force_load_balance': True, 'variable_importances': True, 'replicate_training_data': True, 'single_node_mode': False, 'shuffle_training_data': False, 'missing_values_handling': 'mean_imputation', 'quiet_mode': False, 'autoencoder': False, 'sparse': False, 'col_major': False, 'average_activation': 0.0, 'sparsity_beta': 0.0, 'max_categorical_features': 2147483647, 'reproducible': False, 'export_weights_and_biases': False, 'mini_batch_size': 1, 'categorical_encoding': 'auto', 'elastic_averaging': False, 'elastic_averaging_moving_rate': 0.9, 'elastic_averaging_regularization': 0.001, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'custom_metric_func': None, 'gainslift_bins': -1}
#
#
# Hyperparameters for model XGBoost_2_AutoML_1_20240919_151704:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'distribution': 'auto', 'tweedie_power': 1.5, 'categorical_encoding': 'auto', 'quiet_mode': True, 'checkpoint': None, 'export_checkpoints_dir': None, 'custom_metric_func': None, 'ntrees': 50, 'max_depth': 6, 'min_rows': 1.0, 'min_child_weight': 1.0, 'learn_rate': 0.3, 'eta': 0.3, 'sample_rate': 1.0, 'subsample': 1.0, 'col_sample_rate': 1.0, 'colsample_bylevel': 1.0, 'col_sample_rate_per_tree': 1.0, 'colsample_bytree': 1.0, 'colsample_bynode': 1.0, 'max_abs_leafnode_pred': 0.0, 'max_delta_step': 0.0, 'monotone_constraints': None, 'interaction_constraints': None, 'score_tree_interval': 0, 'min_split_improvement': 0.0, 'gamma': 0.0, 'nthread': -1, 'save_matrix_directory': None, 'build_tree_one_node': False, 'parallelize_cross_validation': True, 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'max_bins': 256, 'max_leaves': 0, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.0, 'one_drop': False, 'skip_drop': 0.0, 'tree_method': 'auto', 'grow_policy': 'depthwise', 'booster': 'gbtree', 'reg_lambda': 1.0, 'reg_alpha': 0.0, 'dmatrix_type': 'auto', 'backend': 'auto', 'gpu_id': None, 'gainslift_bins': -1, 'auc_type': 'auto', 'scale_pos_weight': 1.0, 'eval_metric': None, 'score_eval_metric_only': False}
#
#
# Hyperparameters for model XGBoost_grid_1_AutoML_1_20240919_151704_model_2:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'distribution': 'auto', 'tweedie_power': 1.5, 'categorical_encoding': 'auto', 'quiet_mode': True, 'checkpoint': None, 'export_checkpoints_dir': None, 'custom_metric_func': None, 'ntrees': 50, 'max_depth': 6, 'min_rows': 1.0, 'min_child_weight': 1.0, 'learn_rate': 0.3, 'eta': 0.3, 'sample_rate': 1.0, 'subsample': 1.0, 'col_sample_rate': 1.0, 'colsample_bylevel': 1.0, 'col_sample_rate_per_tree': 1.0, 'colsample_bytree': 1.0, 'colsample_bynode': 1.0, 'max_abs_leafnode_pred': 0.0, 'max_delta_step': 0.0, 'monotone_constraints': None, 'interaction_constraints': None, 'score_tree_interval': 0, 'min_split_improvement': 0.0, 'gamma': 0.0, 'nthread': -1, 'save_matrix_directory': None, 'build_tree_one_node': False, 'parallelize_cross_validation': True, 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'max_bins': 256, 'max_leaves': 0, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.0, 'one_drop': False, 'skip_drop': 0.0, 'tree_method': 'auto', 'grow_policy': 'depthwise', 'booster': 'gbtree', 'reg_lambda': 1.0, 'reg_alpha': 0.0, 'dmatrix_type': 'auto', 'backend': 'auto', 'gpu_id': None, 'gainslift_bins': -1, 'auc_type': 'auto', 'scale_pos_weight': 1.0, 'eval_metric': None, 'score_eval_metric_only': False}
#
#
# Hyperparameters for model XGBoost_3_AutoML_1_20240919_151704:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'distribution': 'auto', 'tweedie_power': 1.5, 'categorical_encoding': 'auto', 'quiet_mode': True, 'checkpoint': None, 'export_checkpoints_dir': None, 'custom_metric_func': None, 'ntrees': 50, 'max_depth': 6, 'min_rows': 1.0, 'min_child_weight': 1.0, 'learn_rate': 0.3, 'eta': 0.3, 'sample_rate': 1.0, 'subsample': 1.0, 'col_sample_rate': 1.0, 'colsample_bylevel': 1.0, 'col_sample_rate_per_tree': 1.0, 'colsample_bytree': 1.0, 'colsample_bynode': 1.0, 'max_abs_leafnode_pred': 0.0, 'max_delta_step': 0.0, 'monotone_constraints': None, 'interaction_constraints': None, 'score_tree_interval': 0, 'min_split_improvement': 0.0, 'gamma': 0.0, 'nthread': -1, 'save_matrix_directory': None, 'build_tree_one_node': False, 'parallelize_cross_validation': True, 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'max_bins': 256, 'max_leaves': 0, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.0, 'one_drop': False, 'skip_drop': 0.0, 'tree_method': 'auto', 'grow_policy': 'depthwise', 'booster': 'gbtree', 'reg_lambda': 1.0, 'reg_alpha': 0.0, 'dmatrix_type': 'auto', 'backend': 'auto', 'gpu_id': None, 'gainslift_bins': -1, 'auc_type': 'auto', 'scale_pos_weight': 1.0, 'eval_metric': None, 'score_eval_metric_only': False}
#
#
# Hyperparameters for model XRT_1_AutoML_1_20240919_151704:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 20, 'min_rows': 1.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'mtries': -1, 'sample_rate': 0.632, 'sample_rate_per_class': None, 'binomial_double_trees': False, 'checkpoint': None, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'distribution': 'auto', 'custom_metric_func': None, 'export_checkpoints_dir': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto'}
#
#
# Hyperparameters for model XGBoost_grid_1_AutoML_1_20240919_151704_model_1:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'distribution': 'auto', 'tweedie_power': 1.5, 'categorical_encoding': 'auto', 'quiet_mode': True, 'checkpoint': None, 'export_checkpoints_dir': None, 'custom_metric_func': None, 'ntrees': 50, 'max_depth': 6, 'min_rows': 1.0, 'min_child_weight': 1.0, 'learn_rate': 0.3, 'eta': 0.3, 'sample_rate': 1.0, 'subsample': 1.0, 'col_sample_rate': 1.0, 'colsample_bylevel': 1.0, 'col_sample_rate_per_tree': 1.0, 'colsample_bytree': 1.0, 'colsample_bynode': 1.0, 'max_abs_leafnode_pred': 0.0, 'max_delta_step': 0.0, 'monotone_constraints': None, 'interaction_constraints': None, 'score_tree_interval': 0, 'min_split_improvement': 0.0, 'gamma': 0.0, 'nthread': -1, 'save_matrix_directory': None, 'build_tree_one_node': False, 'parallelize_cross_validation': True, 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'max_bins': 256, 'max_leaves': 0, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.0, 'one_drop': False, 'skip_drop': 0.0, 'tree_method': 'auto', 'grow_policy': 'depthwise', 'booster': 'gbtree', 'reg_lambda': 1.0, 'reg_alpha': 0.0, 'dmatrix_type': 'auto', 'backend': 'auto', 'gpu_id': None, 'gainslift_bins': -1, 'auc_type': 'auto', 'scale_pos_weight': 1.0, 'eval_metric': None, 'score_eval_metric_only': False}
#
#
# Hyperparameters for model XGBoost_1_AutoML_1_20240919_151704:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'distribution': 'auto', 'tweedie_power': 1.5, 'categorical_encoding': 'auto', 'quiet_mode': True, 'checkpoint': None, 'export_checkpoints_dir': None, 'custom_metric_func': None, 'ntrees': 50, 'max_depth': 6, 'min_rows': 1.0, 'min_child_weight': 1.0, 'learn_rate': 0.3, 'eta': 0.3, 'sample_rate': 1.0, 'subsample': 1.0, 'col_sample_rate': 1.0, 'colsample_bylevel': 1.0, 'col_sample_rate_per_tree': 1.0, 'colsample_bytree': 1.0, 'colsample_bynode': 1.0, 'max_abs_leafnode_pred': 0.0, 'max_delta_step': 0.0, 'monotone_constraints': None, 'interaction_constraints': None, 'score_tree_interval': 0, 'min_split_improvement': 0.0, 'gamma': 0.0, 'nthread': -1, 'save_matrix_directory': None, 'build_tree_one_node': False, 'parallelize_cross_validation': True, 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'max_bins': 256, 'max_leaves': 0, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.0, 'one_drop': False, 'skip_drop': 0.0, 'tree_method': 'auto', 'grow_policy': 'depthwise', 'booster': 'gbtree', 'reg_lambda': 1.0, 'reg_alpha': 0.0, 'dmatrix_type': 'auto', 'backend': 'auto', 'gpu_id': None, 'gainslift_bins': -1, 'auc_type': 'auto', 'scale_pos_weight': 1.0, 'eval_metric': None, 'score_eval_metric_only': False}
#
#
# Hyperparameters for model XGBoost_grid_1_AutoML_1_20240919_151704_model_3:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'distribution': 'auto', 'tweedie_power': 1.5, 'categorical_encoding': 'auto', 'quiet_mode': True, 'checkpoint': None, 'export_checkpoints_dir': None, 'custom_metric_func': None, 'ntrees': 50, 'max_depth': 6, 'min_rows': 1.0, 'min_child_weight': 1.0, 'learn_rate': 0.3, 'eta': 0.3, 'sample_rate': 1.0, 'subsample': 1.0, 'col_sample_rate': 1.0, 'colsample_bylevel': 1.0, 'col_sample_rate_per_tree': 1.0, 'colsample_bytree': 1.0, 'colsample_bynode': 1.0, 'max_abs_leafnode_pred': 0.0, 'max_delta_step': 0.0, 'monotone_constraints': None, 'interaction_constraints': None, 'score_tree_interval': 0, 'min_split_improvement': 0.0, 'gamma': 0.0, 'nthread': -1, 'save_matrix_directory': None, 'build_tree_one_node': False, 'parallelize_cross_validation': True, 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'max_bins': 256, 'max_leaves': 0, 'sample_type': 'uniform', 'normalize_type': 'tree', 'rate_drop': 0.0, 'one_drop': False, 'skip_drop': 0.0, 'tree_method': 'auto', 'grow_policy': 'depthwise', 'booster': 'gbtree', 'reg_lambda': 1.0, 'reg_alpha': 0.0, 'dmatrix_type': 'auto', 'backend': 'auto', 'gpu_id': None, 'gainslift_bins': -1, 'auc_type': 'auto', 'scale_pos_weight': 1.0, 'eval_metric': None, 'score_eval_metric_only': False}
#
#
# Hyperparameters for model GLM_1_AutoML_1_20240919_151704:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'checkpoint': None, 'export_checkpoints_dir': None, 'seed': -1, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'random_columns': None, 'ignore_const_cols': True, 'score_each_iteration': False, 'score_iteration_interval': -1, 'offset_column': None, 'weights_column': None, 'family': 'auto', 'rand_family': None, 'tweedie_variance_power': 0.0, 'tweedie_link_power': 1.0, 'theta': 1e-10, 'solver': 'auto', 'alpha': None, 'lambda': None, 'lambda_search': False, 'early_stopping': True, 'nlambdas': -1, 'standardize': True, 'missing_values_handling': 'mean_imputation', 'plug_values': None, 'compute_p_values': False, 'dispersion_parameter_method': 'pearson', 'init_dispersion_parameter': 1.0, 'remove_collinear_columns': False, 'intercept': True, 'non_negative': False, 'max_iterations': -1, 'objective_epsilon': -1.0, 'beta_epsilon': 0.0001, 'gradient_epsilon': -1.0, 'link': 'family_default', 'rand_link': None, 'startval': None, 'calc_like': False, 'HGLM': False, 'prior': -1.0, 'cold_start': False, 'lambda_min_ratio': -1.0, 'max_active_predictors': -1, 'interactions': None, 'interaction_pairs': None, 'obj_reg': -1.0, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'max_runtime_secs': 0.0, 'custom_metric_func': None, 'generate_scoring_history': False, 'auc_type': 'auto', 'dispersion_epsilon': 0.0001, 'tweedie_epsilon': 8e-17, 'max_iterations_dispersion': 3000, 'build_null_model': False, 'fix_dispersion_parameter': False, 'generate_variable_inflation_factors': False, 'fix_tweedie_variance_power': True, 'dispersion_learning_rate': 0.5, 'influence': None, 'gainslift_bins': -1, 'linear_constraints': None, 'init_optimal_glm': False, 'separate_linear_beta': False, 'constraint_eta0': 0.1258925, 'constraint_tau': 10.0, 'constraint_alpha': 0.1, 'constraint_beta': 0.9, 'constraint_c0': 10.0}
#
#
# Hyperparameters for model GBM_grid_1_AutoML_1_20240919_151704_model_1:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}
#
#
# Hyperparameters for model GBM_1_AutoML_1_20240919_151704:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}
#
#
# Hyperparameters for model DRF_1_AutoML_1_20240919_151704:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 20, 'min_rows': 1.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'mtries': -1, 'sample_rate': 0.632, 'sample_rate_per_class': None, 'binomial_double_trees': False, 'checkpoint': None, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'distribution': 'auto', 'custom_metric_func': None, 'export_checkpoints_dir': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto'}
#
#
# Hyperparameters for model GBM_2_AutoML_1_20240919_151704:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}
#
#
# Hyperparameters for model GBM_grid_1_AutoML_1_20240919_151704_model_2:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}
#
#
# Hyperparameters for model GBM_3_AutoML_1_20240919_151704:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}
#
#
# Hyperparameters for model GBM_5_AutoML_1_20240919_151704:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}
#
#
# Hyperparameters for model GBM_4_AutoML_1_20240919_151704:
# {'model_id': None, 'training_frame': None, 'validation_frame': None, 'nfolds': 0, 'keep_cross_validation_models': True, 'keep_cross_validation_predictions': False, 'keep_cross_validation_fold_assignment': False, 'score_each_iteration': False, 'score_tree_interval': 0, 'fold_assignment': 'auto', 'fold_column': None, 'response_column': None, 'ignored_columns': None, 'ignore_const_cols': True, 'offset_column': None, 'weights_column': None, 'balance_classes': False, 'class_sampling_factors': None, 'max_after_balance_size': 5.0, 'max_confusion_matrix_size': 20, 'ntrees': 50, 'max_depth': 5, 'min_rows': 10.0, 'nbins': 20, 'nbins_top_level': 1024, 'nbins_cats': 1024, 'r2_stopping': None, 'stopping_rounds': 0, 'stopping_metric': 'auto', 'stopping_tolerance': 0.001, 'max_runtime_secs': 0.0, 'seed': -1, 'build_tree_one_node': False, 'learn_rate': 0.1, 'learn_rate_annealing': 1.0, 'distribution': 'auto', 'quantile_alpha': 0.5, 'tweedie_power': 1.5, 'huber_alpha': 0.9, 'checkpoint': None, 'sample_rate': 1.0, 'sample_rate_per_class': None, 'col_sample_rate': 1.0, 'col_sample_rate_change_per_level': 1.0, 'col_sample_rate_per_tree': 1.0, 'min_split_improvement': 1e-05, 'histogram_type': 'auto', 'max_abs_leafnode_pred': None, 'pred_noise_bandwidth': 0.0, 'categorical_encoding': 'auto', 'calibrate_model': False, 'calibration_frame': None, 'calibration_method': 'auto', 'custom_metric_func': None, 'custom_distribution_func': None, 'export_checkpoints_dir': None, 'in_training_checkpoints_dir': None, 'in_training_checkpoints_tree_interval': 1, 'monotone_constraints': None, 'check_constant_response': True, 'gainslift_bins': -1, 'auc_type': 'auto', 'interaction_constraints': None, 'auto_rebalance': True}

# %%
model = aml.get_best_model()
hyperparameters = model.get_params()
print(f"Hyperparameters for model {model_id}:")
print(hyperparameters)
print("\n")
# Out:
# Hyperparameters for model GBM_4_AutoML_1_20240919_151704:
# {'model_id': None, 'training_frame': None, 'response_column': None, 'validation_frame': None, 'blending_frame': None, 'base_models': [], 'metalearner_algorithm': 'auto', 'metalearner_nfolds': 0, 'metalearner_fold_assignment': None, 'metalearner_fold_column': None, 'metalearner_params': None, 'metalearner_transform': 'none', 'max_runtime_secs': 0.0, 'weights_column': None, 'offset_column': None, 'custom_metric_func': None, 'seed': -1, 'score_training_samples': 10000, 'keep_levelone_frame': False, 'export_checkpoints_dir': None, 'auc_type': 'auto', 'gainslift_bins': -1}

# %% [markdown]
# ## With News

# %%
text_features_probab = [i + '_probab' for i in text_features]
text_features_probab.remove('full_text_content_probab')
train_use_X = train[numeric_features + categorical_features + text_features_probab]
test_use_X = test[numeric_features + categorical_features + text_features_probab]
for i in numeric_features:
  if train_use_X[i].dtype != 'int64' and train_use_X[i].dtype !='float64':
    train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
    test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')

for col in  categorical_features:
  train_use_X[col] = train_use_X[col].str.replace('"', '', regex=False)  # Remove double quotes
  train_use_X[col] = train_use_X[col].str.replace('\n', ' ', regex=False)
  test_use_X[col] = test_use_X[col].str.replace('"', '', regex=False)  # Remove double quotes
  test_use_X[col] = test_use_X[col].str.replace('\n', ' ', regex=False)

h2o_train = h2o.H2OFrame(train_use_X)  # Convert train DataFrame to H2OFrame
h2o_test = h2o.H2OFrame(test_use_X)  # Convert test DataFrame to H2OFrame

# Identify predictors and response
# x = train.columns
# y = "response"
# x.remove(y)

x= numeric_features + categorical_features + text_features_probab #+ text_features


# h2o_train[y] = h2o.H2OFrame(train[y].to_list()).asfactor()  # Convert Pandas Series to H2OFrame before assigning
# h2o_test[y] = h2o.H2OFrame(test[y].to_list()).asfactor()  # Convert Pandas Series to H2OFrame before assigning
h2o_train[y] = h2o.H2OFrame(train['underpricing'].to_list()) #h2o.H2OFrame(train[y].to_list()).asfactor()  # Convert Pandas Series to H2OFrame before assigning
h2o_test[y] =  h2o.H2OFrame(test['underpricing'].to_list()) #h2o.H2OFrame(test[y].to_list()).asfactor()  # Convert Pandas Series to H2OFrame before assigning

# For binary classification, response should be a factor
# train[y] = train[y].asfactor()
# test[y] = test[y].asfactor()

# Run AutoML for 20 base models
aml = H2OAutoML(max_models=20, seed=1)
aml.train(x=x, y=y, training_frame=h2o_train)

# View the AutoML Leaderboard
lb = aml.leaderboard
lb.head(rows=lb.nrows)
# Out:
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[i] = train_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[i] = test_use_X[i].apply(lambda x : clean_numbers(str(x))).astype('float64')
# <ipython-input-29-54aad56d052b>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[col] = train_use_X[col].str.replace('"', '', regex=False)  # Remove double quotes
# <ipython-input-29-54aad56d052b>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_use_X[col] = train_use_X[col].str.replace('\n', ' ', regex=False)
# <ipython-input-29-54aad56d052b>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[col] = test_use_X[col].str.replace('"', '', regex=False)  # Remove double quotes
# <ipython-input-29-54aad56d052b>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_use_X[col] = test_use_X[col].str.replace('\n', ' ', regex=False)
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# AutoML progress: |
# 15:30:59.258: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:31:07.133: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ██
# 15:31:16.813: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:31:19.92: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:31:23.27: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ███
# 15:31:36.707: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
# 15:31:40.486: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:31:46.958: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:31:51.217: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:31:54.974: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ███
# 15:32:14.684: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █
# 15:32:20.949: _train param, Dropping bad and constant columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# █████████████████████████████████████████████
# 15:42:41.117: _train param, Dropping unused columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
# 15:42:41.708: _train param, Dropping unused columns: [4_reserves and surplus, Retail (Min)_Lots, 2_total borrowing, 2_reserves and surplus, 0_total borrowing, 1_reserves and surplus, 1_total borrowing, 3_reserves and surplus, 0_reserves and surplus, 3_total borrowing, Total Issue Size, 4_total borrowing]
#
# ███| (done) 100%
# model_id                                                     rmse        mse       mae       rmsle    mean_residual_deviance
# -------------------------------------------------------  --------  ---------  --------  ----------  ------------------------
# StackedEnsemble_BestOfFamily_1_AutoML_2_20240919_153059  0.200601  0.0402407  0.116869    0.132378                 0.0402407
# DeepLearning_grid_3_AutoML_2_20240919_153059_model_1     0.201104  0.0404427  0.116424    0.134147                 0.0404427
# DeepLearning_grid_2_AutoML_2_20240919_153059_model_1     0.206905  0.0428097  0.118279    0.141467                 0.0428097
# StackedEnsemble_AllModels_1_AutoML_2_20240919_153059     0.207517  0.0430631  0.116398    0.13661                  0.0430631
# DeepLearning_grid_1_AutoML_2_20240919_153059_model_1     0.216816  0.0470094  0.128037    0.145016                 0.0470094
# XRT_1_AutoML_2_20240919_153059                           0.229925  0.0528655  0.133518    0.149807                 0.0528655
# XGBoost_2_AutoML_2_20240919_153059                       0.230018  0.0529082  0.141173    0.157696                 0.0529082
# DeepLearning_1_AutoML_2_20240919_153059                  0.230595  0.0531739  0.141048    0.156579                 0.0531739
# XGBoost_grid_1_AutoML_2_20240919_153059_model_2          0.23124   0.0534719  0.135693    0.155729                 0.0534719
# XGBoost_3_AutoML_2_20240919_153059                       0.235916  0.0556561  0.13353     0.157817                 0.0556561
# XGBoost_grid_1_AutoML_2_20240919_153059_model_1          0.237633  0.0564696  0.145903    0.163119                 0.0564696
# XGBoost_1_AutoML_2_20240919_153059                       0.244578  0.0598182  0.145177    0.165446                 0.0598182
# XGBoost_grid_1_AutoML_2_20240919_153059_model_3          0.260257  0.0677339  0.142087    0.169496                 0.0677339
# GLM_1_AutoML_2_20240919_153059                           0.270634  0.0732425  0.141453  nan                        0.0732425
# GBM_grid_1_AutoML_2_20240919_153059_model_1              0.290169  0.0841978  0.14731     0.191782                 0.0841978
# GBM_1_AutoML_2_20240919_153059                           0.305027  0.0930417  0.161859    0.207147                 0.0930417
# DRF_1_AutoML_2_20240919_153059                           0.308829  0.0953751  0.155575    0.208967                 0.0953751
# GBM_2_AutoML_2_20240919_153059                           0.312288  0.0975236  0.163726    0.213266                 0.0975236
# GBM_3_AutoML_2_20240919_153059                           0.313025  0.0979844  0.163677    0.213886                 0.0979844
# GBM_grid_1_AutoML_2_20240919_153059_model_2              0.313623  0.0983593  0.162805    0.21425                  0.0983593
# GBM_4_AutoML_2_20240919_153059                           0.315809  0.0997351  0.165582    0.216545                 0.0997351
# GBM_5_AutoML_2_20240919_153059                           0.316796  0.100359   0.166035    0.217391                 0.100359
# [22 rows x 6 columns]

# %%
lb
# Out:
# model_id                                                     rmse        mse       mae       rmsle    mean_residual_deviance
# -------------------------------------------------------  --------  ---------  --------  ----------  ------------------------
# StackedEnsemble_BestOfFamily_1_AutoML_2_20240919_153059  0.200601  0.0402407  0.116869    0.132378                 0.0402407
# DeepLearning_grid_3_AutoML_2_20240919_153059_model_1     0.201104  0.0404427  0.116424    0.134147                 0.0404427
# DeepLearning_grid_2_AutoML_2_20240919_153059_model_1     0.206905  0.0428097  0.118279    0.141467                 0.0428097
# StackedEnsemble_AllModels_1_AutoML_2_20240919_153059     0.207517  0.0430631  0.116398    0.13661                  0.0430631
# DeepLearning_grid_1_AutoML_2_20240919_153059_model_1     0.216816  0.0470094  0.128037    0.145016                 0.0470094
# XRT_1_AutoML_2_20240919_153059                           0.229925  0.0528655  0.133518    0.149807                 0.0528655
# XGBoost_2_AutoML_2_20240919_153059                       0.230018  0.0529082  0.141173    0.157696                 0.0529082
# DeepLearning_1_AutoML_2_20240919_153059                  0.230595  0.0531739  0.141048    0.156579                 0.0531739
# XGBoost_grid_1_AutoML_2_20240919_153059_model_2          0.23124   0.0534719  0.135693    0.155729                 0.0534719
# XGBoost_3_AutoML_2_20240919_153059                       0.235916  0.0556561  0.13353     0.157817                 0.0556561
# XGBoost_grid_1_AutoML_2_20240919_153059_model_1          0.237633  0.0564696  0.145903    0.163119                 0.0564696
# XGBoost_1_AutoML_2_20240919_153059                       0.244578  0.0598182  0.145177    0.165446                 0.0598182
# XGBoost_grid_1_AutoML_2_20240919_153059_model_3          0.260257  0.0677339  0.142087    0.169496                 0.0677339
# GLM_1_AutoML_2_20240919_153059                           0.270634  0.0732425  0.141453  nan                        0.0732425
# GBM_grid_1_AutoML_2_20240919_153059_model_1              0.290169  0.0841978  0.14731     0.191782                 0.0841978
# GBM_1_AutoML_2_20240919_153059                           0.305027  0.0930417  0.161859    0.207147                 0.0930417
# DRF_1_AutoML_2_20240919_153059                           0.308829  0.0953751  0.155575    0.208967                 0.0953751
# GBM_2_AutoML_2_20240919_153059                           0.312288  0.0975236  0.163726    0.213266                 0.0975236
# GBM_3_AutoML_2_20240919_153059                           0.313025  0.0979844  0.163677    0.213886                 0.0979844
# GBM_grid_1_AutoML_2_20240919_153059_model_2              0.313623  0.0983593  0.162805    0.21425                  0.0983593
# GBM_4_AutoML_2_20240919_153059                           0.315809  0.0997351  0.165582    0.216545                 0.0997351
# GBM_5_AutoML_2_20240919_153059                           0.316796  0.100359   0.166035    0.217391                 0.100359
# [22 rows x 6 columns]

# %%
lb = h2o.automl.get_leaderboard(aml, extra_columns = "ALL")
lb
# Out:
# model_id                                                     rmse        mse       mae     rmsle    mean_residual_deviance    training_time_ms    predict_time_per_row_ms  algo
# -------------------------------------------------------  --------  ---------  --------  --------  ------------------------  ------------------  -------------------------  ---------------
# StackedEnsemble_BestOfFamily_1_AutoML_2_20240919_153059  0.200601  0.0402407  0.116869  0.132378                 0.0402407                 567                   0.542475  StackedEnsemble
# DeepLearning_grid_3_AutoML_2_20240919_153059_model_1     0.201104  0.0404427  0.116424  0.134147                 0.0404427               46004                   0.569063  DeepLearning
# DeepLearning_grid_2_AutoML_2_20240919_153059_model_1     0.206905  0.0428097  0.118279  0.141467                 0.0428097               37355                   0.465517  DeepLearning
# StackedEnsemble_AllModels_1_AutoML_2_20240919_153059     0.207517  0.0430631  0.116398  0.13661                  0.0430631                 866                   0.856074  StackedEnsemble
# DeepLearning_grid_1_AutoML_2_20240919_153059_model_1     0.216816  0.0470094  0.128037  0.145016                 0.0470094               31066                   0.469517  DeepLearning
# XRT_1_AutoML_2_20240919_153059                           0.229925  0.0528655  0.133518  0.149807                 0.0528655                3609                   0.054998  DRF
# XGBoost_2_AutoML_2_20240919_153059                       0.230018  0.0529082  0.141173  0.157696                 0.0529082                 626                   0.023949  XGBoost
# DeepLearning_1_AutoML_2_20240919_153059                  0.230595  0.0531739  0.141048  0.156579                 0.0531739                 461                   0.075759  DeepLearning
# XGBoost_grid_1_AutoML_2_20240919_153059_model_2          0.23124   0.0534719  0.135693  0.155729                 0.0534719                 671                   0.024454  XGBoost
# XGBoost_3_AutoML_2_20240919_153059                       0.235916  0.0556561  0.13353   0.157817                 0.0556561                 459                   0.020494  XGBoost
# [22 rows x 9 columns]

# %%
# Get the best model using the metric
m = aml.leader
print(m)
# Out:
# Model Details
# =============
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_BestOfFamily_1_AutoML_2_20240919_153059
#
#
# Model Summary for Stacked Ensemble:
# key                                        value
# -----------------------------------------  ----------------
# Stacking strategy                          cross_validation
# Number of base models (used / total)       4/6
# # GBM base models (used / total)           0/1
# # XGBoost base models (used / total)       1/1
# # DeepLearning base models (used / total)  1/1
# # DRF base models (used / total)           1/2
# # GLM base models (used / total)           1/1
# Metalearner algorithm                      GLM
# Metalearner fold assignment scheme         Random
# Metalearner nfolds                         5
# Metalearner fold_column
# Custom metalearner hyperparameters         None
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.0020057967365714087
# RMSE: 0.04478612214259467
# MAE: 0.03418601904525478
# RMSLE: 0.03764324159687379
# Mean Residual Deviance: 0.0020057967365714087
# R^2: 0.9788422431018726
# Null degrees of freedom: 360
# Residual degrees of freedom: 356
# Null deviance: 34.22350608283844
# Residual deviance: 0.7240926219022785
# AIC: -1205.9551049792326
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.04024065734280354
# RMSE: 0.20060074113223894
# MAE: 0.11686875449013695
# RMSLE: 0.13237753860860532
# Mean Residual Deviance: 0.04024065734280354
# R^2: 0.5755292498205886
# Null degrees of freedom: 360
# Residual degrees of freedom: 356
# Null deviance: 34.56909087427962
# Residual deviance: 14.526877300752078
# AIC: -123.37512684023207
#
# Cross-Validation Metrics Summary:
#                         mean       sd         cv_1_valid    cv_2_valid    cv_3_valid    cv_4_valid    cv_5_valid
# ----------------------  ---------  ---------  ------------  ------------  ------------  ------------  ------------
# aic                     -26.98     40.2798    36.6988       -48.4107      -15.122       -67.6575      -40.4087
# loglikelihood           0          0          0             0             0             0             0
# mae                     0.117001   0.0236944  0.152084      0.106079      0.123779      0.0879104     0.115154
# mean_residual_deviance  0.0400663  0.0253755  0.0829094     0.0289664     0.0406822     0.0170682     0.0307051
# mse                     0.0400663  0.0253755  0.0829094     0.0289664     0.0406822     0.0170682     0.0307051
# null_deviance           6.91382    3.02859    11.0207       5.29238       6.49765       3.15156       8.60682
# r2                      0.580924   0.100991   0.454246      0.533602      0.566115      0.628068      0.722588
# residual_deviance       2.89521    1.79304    5.88656       2.40421       2.80707       1.0753        2.30288
# rmse                    0.193141   0.0587646  0.28794       0.170195      0.201698      0.130645      0.175229
# rmsle                   0.130537   0.0224755  0.159587      0.12573       0.143959      0.100213      0.123197

# %%
# this is equivalent to
m = aml.get_best_model()
print(m)
# Out:
# Model Details
# =============
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_BestOfFamily_1_AutoML_2_20240919_153059
#
#
# Model Summary for Stacked Ensemble:
# key                                        value
# -----------------------------------------  ----------------
# Stacking strategy                          cross_validation
# Number of base models (used / total)       4/6
# # GBM base models (used / total)           0/1
# # XGBoost base models (used / total)       1/1
# # DeepLearning base models (used / total)  1/1
# # DRF base models (used / total)           1/2
# # GLM base models (used / total)           1/1
# Metalearner algorithm                      GLM
# Metalearner fold assignment scheme         Random
# Metalearner nfolds                         5
# Metalearner fold_column
# Custom metalearner hyperparameters         None
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.0020057967365714087
# RMSE: 0.04478612214259467
# MAE: 0.03418601904525478
# RMSLE: 0.03764324159687379
# Mean Residual Deviance: 0.0020057967365714087
# R^2: 0.9788422431018726
# Null degrees of freedom: 360
# Residual degrees of freedom: 356
# Null deviance: 34.22350608283844
# Residual deviance: 0.7240926219022785
# AIC: -1205.9551049792326
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.04024065734280354
# RMSE: 0.20060074113223894
# MAE: 0.11686875449013695
# RMSLE: 0.13237753860860532
# Mean Residual Deviance: 0.04024065734280354
# R^2: 0.5755292498205886
# Null degrees of freedom: 360
# Residual degrees of freedom: 356
# Null deviance: 34.56909087427962
# Residual deviance: 14.526877300752078
# AIC: -123.37512684023207
#
# Cross-Validation Metrics Summary:
#                         mean       sd         cv_1_valid    cv_2_valid    cv_3_valid    cv_4_valid    cv_5_valid
# ----------------------  ---------  ---------  ------------  ------------  ------------  ------------  ------------
# aic                     -26.98     40.2798    36.6988       -48.4107      -15.122       -67.6575      -40.4087
# loglikelihood           0          0          0             0             0             0             0
# mae                     0.117001   0.0236944  0.152084      0.106079      0.123779      0.0879104     0.115154
# mean_residual_deviance  0.0400663  0.0253755  0.0829094     0.0289664     0.0406822     0.0170682     0.0307051
# mse                     0.0400663  0.0253755  0.0829094     0.0289664     0.0406822     0.0170682     0.0307051
# null_deviance           6.91382    3.02859    11.0207       5.29238       6.49765       3.15156       8.60682
# r2                      0.580924   0.100991   0.454246      0.533602      0.566115      0.628068      0.722588
# residual_deviance       2.89521    1.79304    5.88656       2.40421       2.80707       1.0753        2.30288
# rmse                    0.193141   0.0587646  0.28794       0.170195      0.201698      0.130645      0.175229
# rmsle                   0.130537   0.0224755  0.159587      0.12573       0.143959      0.100213      0.123197

# %%
# Get the best model using a non-default metric
# m = aml.get_best_model(criterion="logloss")
# print(m)

# %%
log = aml.event_log
print(log)
# Get training timing info
info = aml.training_info
print(info)
# Out:
# timestamp     level    stage       message                                                                                                                                                           name    value
# 15:30:59.239  INFO     Workflow    Project: AutoML_2_20240919_153059
# 15:30:59.239  INFO     Validation  5-fold cross-validation will be used.
# 15:30:59.239  INFO     Validation  Setting stopping tolerance adaptively based on the training frame: 0.05
# 15:30:59.239  INFO     Validation  Build control seed: 1
# 15:30:59.240  INFO     DataImport  training frame: Frame key: AutoML_2_20240919_153059_training_py_32_sid_a926    cols: 175    rows: 361  chunks: 1    size: 496351  checksum: -1911186634377354190
# 15:30:59.240  INFO     DataImport  validation frame: NULL
# 15:30:59.240  INFO     DataImport  leaderboard frame: NULL
# 15:30:59.240  INFO     DataImport  blending frame: NULL
# 15:30:59.240  INFO     DataImport  response column: Success_Open
# 15:30:59.240  INFO     DataImport  fold column: null
# [153 rows x 6 columns]
#
# {'creation_epoch': '1726759859', 'start_epoch': '1726759859', 'start_XGBoost_def_2': '1726759859', 'start_GLM_def_1': '1726759867', 'start_GBM_def_5': '1726759877', 'start_XGBoost_def_1': '1726759879', 'start_DRF_def_1': '1726759883', 'start_GBM_def_2': '1726759897', 'start_GBM_def_3': '1726759900', 'start_GBM_def_4': '1726759907', 'start_XGBoost_def_3': '1726759911', 'start_DRF_XRT': '1726759915', 'start_GBM_def_1': '1726759935', 'start_DeepLearning_def_1': '1726759941', 'start_XGBoost_grid_1': '1726759944', 'start_GBM_grid_1': '1726759958', 'start_DeepLearning_grid_1': '1726759964', 'start_DeepLearning_grid_2': '1726760128', 'start_DeepLearning_grid_3': '1726760324', 'start_StackedEnsemble_best_of_family_xglm': '1726760561', 'start_StackedEnsemble_all_xglm': '1726760562', 'stop_epoch': '1726760563', 'duration_secs': '703'}

# %%
aml.leader.model_id
# Out:
# 'StackedEnsemble_BestOfFamily_1_AutoML_2_20240919_153059'

# %%
# aml.leader.confusion_matrix()

# %%
cols = ['3_assets',  '3_revenue', 'Share Holding Post Issue', 'Share Holding Pre Issue', 'S-HNI (Max)_Shares',  'B-HNI (Min)_Shares', 'S-HNI (Min)_Amount', 'B-HNI (Min)_Amount', 'S-HNI (Min)_Shares', 'S-HNI (Max)_Amount', 'B-HNI (Min)_Lots', 'S-HNI (Max)_Lots', 'S-HNI (Min)_Lots', '0_net worth',  '3_net worth', '1_net worth', '2_net worth']
for col in cols:
  h2o_test[col] = h2o_test[col].ascharacter().asfactor()

# %%
preds_leader = aml.leader.predict(h2o_test)
preds_leader
# Out:
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'day_3_qib' has levels not trained on: ["1.05", "1.28", "5.79", "64.1"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'day_3_nii' has levels not trained on: ["1.52", "1.92", "132.99", "6.49", "64.88", "9.01"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'day_3_retail' has levels not trained on: ["0.55", "16.53", "225.37", "3.14", "4.44", "64.84"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'day_3_total' has levels not trained on: ["0.98", "2.19", "5.35", "5.5", "50.38", "62.83"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'S-HNI (Min)_Lots' has levels not trained on: ["14", "15"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'S-HNI (Min)_Shares' has levels not trained on: ["1064", "1232", "1260", "1470", "1498", "1500", "1666", "1764", "195", "1950", ...25 not listed..., "686", "700", "714", "728", "742", "784", "8400", "938", "966", "980"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'S-HNI (Min)_Amount' has levels not trained on: ["202300", "202860", "203280", "204750", "204820", "205030", "205408", "205800", "206080", "206250", ...18 not listed..., "209160", "209244", "209300", "209412", "209608", "209720", "209916", "210000", "210600", "213300"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'S-HNI (Max)_Lots' has levels not trained on: ["66", "67", "68", "69", "70", "71", "72"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'S-HNI (Max)_Shares' has levels not trained on: ["10050", "10200", "1173", "1260", "1340", "1360", "1474", "1496", "15180", "1541", ...35 not listed..., "7035", "7062", "7100", "7140", "7854", "8316", "923", "9230", "966", "9900"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'S-HNI (Max)_Amount' has levels not trained on: ["986040", "986240", "986436", "986700", "987228", "987360", "988152", "988250", "988680", "988920", ...18 not listed..., "996826", "996840", "997050", "997696", "998032", "998233", "998568", "998970", "999600", "999810"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'B-HNI (Min)_Lots' has levels not trained on: ["67", "68", "69", "70", "71", "72", "73"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'B-HNI (Min)_Shares' has levels not trained on: ["10050", "10200", "10350", "1190", "1278", "1360", "1380", "1496", "1518", "15410", ...35 not listed..., "6120", "7140", "7169", "7200", "7245", "7973", "8442", "936", "9360", "980"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'B-HNI (Min)_Amount' has levels not trained on: ["1000960", "1000980", "1001382", "1001650", "1001880", "1002186", "1003000", "1003124", "1003660", "1003680", ...18 not listed..., "1011296", "1011432", "1011500", "1011704", "1012368", "1012928", "1013132", "1013472", "1013880", "1014300"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Share Holding Pre Issue' has levels not trained on: ["0.3337", "0.3741", "0.4408", "0.4665", "0.4979", "0.5675", "0.5791", "0.6642", "0.6666", "0.6679", ...21 not listed..., "0.918", "0.9284", "0.9523", "0.9642", "0.9749", "0.978", "0.9859", "0.993", "0.9935", "1"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Share Holding Post Issue' has levels not trained on: ["0.3019", "0.3534", "0.4091", "0.416", "0.4408", "0.4817", "0.5124", "0.5366", "0.5539", "0.5547", ...21 not listed..., "0.7494", "0.7495", "0.7497", "0.7545", "0.765", "0.7859", "0.792", "0.8561", "64.46", "78.06"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '0_net worth' has levels not trained on: ["-259.28", "-93.07", "1019.5", "104.57", "1103.33", "113.61", "1226.56", "123.49", "1374.97", "1414.9", ...23 not listed..., "56.58", "638.26", "6580.61", "725.68", "752.09", "810.79", "86.11", "875.07", "88.58", "999.37"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '1_net worth' has levels not trained on: ["-206.87", "-702.63", "100.93", "1033.38", "1103.22", "1240.53", "1336.58", "1355.68", "1368.35", "137.4", ...23 not listed..., "65.97", "665.73", "681.49", "71.39", "71.46", "75.2", "760.21", "92.47", "944.72", "988.31"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '2_net worth' has levels not trained on: ["-352.22", "-871.43", "100.49", "1026.78", "106.05", "107.25", "1076.13", "115.45", "1153.52", "1237.05", ...23 not listed..., "5268.11", "560.71", "631.91", "70.03", "705.62", "714", "72.46", "787.62", "86.22", "889.89"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '3_assets' has levels not trained on: ["1077.86", "1097.7", "1146.51", "123.74", "12338.65", "19117.54", "213.98", "2462.64", "256.05", "2633.62", ...11 not listed..., "5746.44", "5999.13", "6210.92", "638.72", "687.2", "692.76", "792", "876.38", "9450.66", "948.25"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '3_revenue' has levels not trained on: ["10311.01", "1059.58", "107.71", "1178.62", "125.03", "1567.77", "1585.88", "1768.42", "2031.3", "2069.58", ...11 not listed..., "402.59", "408.79", "412.03", "472.1", "543.28", "5633.64", "590.81", "608.99", "697.57", "740.36"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '3_net worth' has levels not trained on: ["-1765.14", "100.96", "114.09", "116.89", "117.6", "1352.06", "1390.47", "144.78", "1466.88", "192.33", ...10 not listed..., "375.76", "3934.64", "47.54", "487.83", "55.55", "622.23", "645.16", "723.55", "834.73", "937.27"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '4_assets' has levels not trained on: ["1082.82", "267.16", "485.97"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '4_revenue' has levels not trained on: ["166.13", "510.21", "523.1"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '4_profit after tax' has levels not trained on: ["19.24", "21.07", "65.77"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column '4_net worth' has levels not trained on: ["182.96", "363.65", "74.74"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Industry' has levels not trained on: ["Computer Peripherals", "Integrated Oil", "Office Equipment/Supplies"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Fresh Issue' has levels not trained on: ["1,700,680 shares (aggregating up to 75.00 Cr)", "1,739,131 shares (aggregating up to 180.00 Cr)", "10,000,000 shares (aggregating up to 100.00 Cr)", "10,200,000 shares (aggregating up to 66.30 Cr)", "10,800,000 shares (aggregating up to 545.40 Cr)", "10,890,000 shares (aggregating up to 152.46 Cr)", "11,111,111 shares (aggregating up to 400.00 Cr)", "11,268,580 shares (aggregating up to 365.00 Cr)", "12,280,701 shares (aggregating up to 350.00 Cr)", "13,200,158 shares (aggregating up to 71.28 Cr)", ...27 not listed..., "6,930,806 shares (aggregating up to 146.24 Cr)", "65,116,667 shares (aggregating up to 390.70 Cr)", "7,142,857 shares (aggregating up to 320.00 Cr)", "7,339,450 shares (aggregating up to 320.00 Cr)", "7,374,163 shares (aggregating up to 542.00 Cr)", "8,517,350 shares (aggregating up to 270.00 Cr)", "8,520,000 shares (aggregating up to 119.28 Cr)", "9,605,263 shares (aggregating up to 292.00 Cr)", "9,767,442 shares (aggregating up to 210.00 Cr)", "95,238,095 shares (aggregating up to 1,200.00 Cr)"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Offer for Sale' has levels not trained on: ["10,449,816 shares of 1 (aggregating up to 171.38 Cr)", "10,759,493 shares of 10 (aggregating up to 850.00 Cr)", "11,756,910 shares of 2 (aggregating up to 198.69 Cr)", "12,050,000 shares of 10 (aggregating up to 72.30 Cr)", "12,183,099 shares of 1 (aggregating up to 173.00 Cr)", "12,500,000 shares of 2 (aggregating up to 545.00 Cr)", "13,500,000 shares of 1 (aggregating up to 170.10 Cr)", "14,213,198 shares of 1 (aggregating up to 280.00 Cr)", "17,236,808 shares of 5 (aggregating up to 1,784.01 Cr)", "17,500,000 shares of 2 (aggregating up to 189.00 Cr)", ...25 not listed..., "7,159,920 shares of 2 (aggregating up to 608.59 Cr)", "8,000,000 shares of 10 (aggregating up to 240.00 Cr)", "8,113,590 shares of 5 (aggregating up to 400.00 Cr)", "8,294,118 shares of 10 (aggregating up to 175.00 Cr)", "8,500,000 shares of 2 (aggregating up to 425.00 Cr)", "9,000,000 shares of 10 (aggregating up to 256.50 Cr)", "9,428,178 shares of 10 (aggregating up to 415.78 Cr)", "9,541,985 shares of 2 (aggregating up to 500.00 Cr)", "9,901,315 shares of 5 (aggregating up to 301.00 Cr)", "[.] shares of 10 (aggregating up to 425.00 Cr)"]
#   warnings.warn(w)
# /usr/local/lib/python3.10/dist-packages/h2o/job.py:81: UserWarning: Test/Validation dataset column 'Price Band' has levels not trained on: ["102 to 108 per share", "1026 to 1080 per share", "113 to 119 per share", "119 to 126 per share", "133 to 140 per share", "135 to 142 per share", "151 to 166 per share", "156 to 164 per share", "160 to 169 per share", "187 to 197 per share", ...30 not listed..., "617 to 648 per share", "627 to 660 per share", "638 to 672 per share", "695 to 735 per share", "705 to 741 per share", "750 to 790 per share", "808 to 850 per share", "93 to 98 per share", "95 to 100 per share", "983 to 1035 per share"]
#   warnings.warn(w)
#   predict
# ---------
# 0.0637177
# 0.0283796
# 0.0222489
# 0.0692512
# 0.0732594
# 0.0501552
# 0.142077
# 0.0373159
# 0.123122
# 0.623209
# [57 rows x 1 column]

# %%
best_model = aml.get_best_model()
model_path = h2o.save_model(model=best_model, path="/content/drive/MyDrive/datasets/Indian_IPO_Prediction/mainboard_h2o_best_stacked_model_" + y + "_ALL_features_with_text_emb_predprobab_plus_news_underpricing/", force=True)
print(model_path)
# Out:
# /content/drive/MyDrive/datasets/Indian_IPO_Prediction/mainboard_h2o_best_stacked_model_Success_Open_ALL_features_with_text_emb_predprobab_plus_news_underpricing/StackedEnsemble_BestOfFamily_1_AutoML_2_20240919_153059

# %%
performance = best_model.model_performance(test_data=h2o_test)
print("MAE:", performance.mae())
print(f"RMSE: {performance.rmse()}")
print(f"MSE: {performance.mse()}")
print("\n")
# Out:
# MAE: 0.1718795186659868
# RMSE: 0.23032546755489625
# MSE: 0.05304982100438156

# %%
for model_id in lb['model_id'].as_data_frame()['model_id']:
    model = h2o.get_model(model_id)
    performance = model.model_performance(test_data=h2o_test)
    print(f"Performance for model {model_id}:")
    print("MAE:", performance.mae())
    print(f"RMSE: {performance.rmse()}")
    print(f"MSE: {performance.mse()}")
    print("\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/h2o/frame.py:1981: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# Performance for model StackedEnsemble_BestOfFamily_1_AutoML_2_20240919_153059:
# MAE: 0.1718795186659868
# RMSE: 0.23032546755489625
# MSE: 0.05304982100438156
#
#
# Performance for model DeepLearning_grid_3_AutoML_2_20240919_153059_model_1:
# MAE: 0.18173452610884966
# RMSE: 0.2560795845769998
# MSE: 0.0655767536371288
#
#
# Performance for model DeepLearning_grid_2_AutoML_2_20240919_153059_model_1:
# MAE: 0.2091708820237792
# RMSE: 0.278312449339031
# MSE: 0.07745781945709068
#
#
# Performance for model StackedEnsemble_AllModels_1_AutoML_2_20240919_153059:
# MAE: 0.17123118037313312
# RMSE: 0.2266571504179167
# MSE: 0.05137346383557012
#
#
# Performance for model DeepLearning_grid_1_AutoML_2_20240919_153059_model_1:
# MAE: 0.20131382691364152
# RMSE: 0.2857307959478294
# MSE: 0.08164208775298012
#
#
# Performance for model XRT_1_AutoML_2_20240919_153059:
# MAE: 0.1733472213204896
# RMSE: 0.2295830429332594
# MSE: 0.05270837360249483
#
#
# Performance for model XGBoost_2_AutoML_2_20240919_153059:
# MAE: 0.3073038539538781
# RMSE: 0.38926963961572997
# MSE: 0.15153085232656027
#
#
# Performance for model DeepLearning_1_AutoML_2_20240919_153059:
# MAE: 0.17671984380508574
# RMSE: 0.238820295049377
# MSE: 0.057035133327471475
#
#
# Performance for model XGBoost_grid_1_AutoML_2_20240919_153059_model_2:
# MAE: 0.19555392871169666
# RMSE: 0.258122690963226
# MSE: 0.06662732359009707
#
#
# Performance for model XGBoost_3_AutoML_2_20240919_153059:
# MAE: 0.23468633641880987
# RMSE: 0.3380059195604974
# MSE: 0.11424800165793746
#
#
# Performance for model XGBoost_grid_1_AutoML_2_20240919_153059_model_1:
# MAE: 0.23759632503711864
# RMSE: 0.3126342311635913
# MSE: 0.09774016249524983
#
#
# Performance for model XGBoost_1_AutoML_2_20240919_153059:
# MAE: 0.28480997184912366
# RMSE: 0.37836046414361557
# MSE: 0.1431566408269722
#
#
# Performance for model XGBoost_grid_1_AutoML_2_20240919_153059_model_3:
# MAE: 0.31194653665941013
# RMSE: 0.4215741368609519
# MSE: 0.17772475287005662
#
#
# Performance for model GLM_1_AutoML_2_20240919_153059:
# MAE: 0.20128377481393686
# RMSE: 0.28728656982548784
# MSE: 0.08253357320209491
#
#
# Performance for model GBM_grid_1_AutoML_2_20240919_153059_model_1:
# MAE: 0.2541469016100907
# RMSE: 0.37031688411572106
# MSE: 0.13713459466117636
#
#
# Performance for model GBM_1_AutoML_2_20240919_153059:
# MAE: 0.24783357885310112
# RMSE: 0.3514853672655842
# MSE: 0.12354196340182262
#
#
# Performance for model DRF_1_AutoML_2_20240919_153059:
# MAE: 0.263967790786353
# RMSE: 0.37414706437311074
# MSE: 0.13998602577901667
#
#
# Performance for model GBM_2_AutoML_2_20240919_153059:
# MAE: 0.26396731796425715
# RMSE: 0.38192665563246886
# MSE: 0.14586797028260245
#
#
# Performance for model GBM_3_AutoML_2_20240919_153059:
# MAE: 0.2730413921836901
# RMSE: 0.3980839383847709
# MSE: 0.15847082199993007
#
#
# Performance for model GBM_grid_1_AutoML_2_20240919_153059_model_2:
# MAE: 0.2827477926269715
# RMSE: 0.40656288402310314
# MSE: 0.16529337866518323
#
#
# Performance for model GBM_4_AutoML_2_20240919_153059:
# MAE: 0.27788337911570976
# RMSE: 0.4026124814310855
# MSE: 0.16209681020409616
#
#
# Performance for model GBM_5_AutoML_2_20240919_153059:
# MAE: 0.2794501444752263
# RMSE: 0.4023371781816368
# MSE: 0.16187520494716215
